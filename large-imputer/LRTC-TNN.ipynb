# %% [markdown]
# # About This Notebook
#
# This notebook shows how to implement **Low-Rank Tensor Completion with Truncated Nuclear Norm minimization (LRTC-TNN)** on some real-world data sets. For an in-depth discussion of LRTC-TNN, please see our article [1].
#
# <div class="alert alert-block alert-info">
# <font color="black">
# <b>[1]</b> Xinyu Chen, Jinming Yang, Lijun Sun (2020). <b>A Nonconvex Low-Rank Tensor Completion Model for Spatiotemporal Traffic Data Imputation</b>. arXiv.2003.10271. <a href="https://arxiv.org/abs/2003.10271" title="PDF"><b>[PDF]</b></a>
# </font>
# </div>
#
#
# ## Quick Run
#
# This notebook is publicly available at [https://github.com/xinychen/tensor-learning](https://github.com/xinychen/tensor-learning).

# %% [markdown]
# ## Low-Rank Tensor Completion

# %% [markdown]
# We start by importing the necessary dependencies.

# %%
import numpy as np
from numpy.linalg import inv as inv

# %% [markdown]
# ### Tensor Unfolding (`ten2mat`) and Matrix Folding (`mat2ten`)
#
# Using numpy reshape to perform 3rd rank tensor unfold operation. [[**link**](https://stackoverflow.com/questions/49970141/using-numpy-reshape-to-perform-3rd-rank-tensor-unfold-operation)]

# %%
def ten2mat(tensor, mode):
    return np.reshape(np.moveaxis(tensor, mode, 0), (tensor.shape[mode], -1), order = 'F')

def mat2ten(mat, tensor_size, mode):
    index = list()
    index.append(mode)
    for i in range(tensor_size.shape[0]):
        if i != mode:
            index.append(i)
    return np.moveaxis(np.reshape(mat, list(tensor_size[index]), order = 'F'), 0, mode)

# %% [markdown]
# ### Singular Value Thresholding (SVT) for TNN

# %%
def svt_tnn(mat, alpha, rho, theta):
    """This is a Numpy dependent singular value thresholding (SVT) process."""
    u, s, v = np.linalg.svd(mat, full_matrices = False)
    vec = s.copy()
    vec[theta :] = s[theta :] - alpha / rho
    vec[vec < 0] = 0
    return np.matmul(np.matmul(u, np.diag(vec)), v)

# %% [markdown]
# **Potential alternative for this**:
#
# This is a competitively efficient algorithm for implementing SVT-TNN.

# %%
def svt_tnn(mat, alpha, rho, theta):
    tau = alpha / rho
    [m, n] = mat.shape
    if 2 * m < n:
        u, s, v = np.linalg.svd(mat @ mat.T, full_matrices = False)
        s = np.sqrt(s)
        idx = np.sum(s > tau)
        mid = np.zeros(idx)
        mid[:theta] = 1
        mid[theta:idx] = (s[theta : idx] - tau) / s[theta : idx]
        return (u[:,:idx] @ np.diag(mid)) @ (u[:, :idx].T @ mat)
    elif m > 2 * n:
        return svt_tnn(mat.T, alpha, rho, theta).T
    u, s, v = np.linalg.svd(mat, full_matrices = 0)
    idx = np.sum(s > tau)
    vec = s[:idx].copy()
    vec[theta : idx] = s[theta : idx] - tau
    return u[:, :idx] @ np.diag(vec) @ v[:idx, :]

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <ul>
# <li><b><code>compute_mape</code>:</b> <font color="black">Compute the value of Mean Absolute Percentage Error (MAPE).</font></li>
# <li><b><code>compute_rmse</code>:</b> <font color="black">Compute the value of Root Mean Square Error (RMSE).</font></li>
# </ul>
# </div>
#
# > Note that $$\mathrm{MAPE}=\frac{1}{n} \sum_{i=1}^{n} \frac{\left|y_{i}-\hat{y}_{i}\right|}{y_{i}} \times 100, \quad\mathrm{RMSE}=\sqrt{\frac{1}{n} \sum_{i=1}^{n}\left(y_{i}-\hat{y}_{i}\right)^{2}},$$ where $n$ is the total number of estimated values, and $y_i$ and $\hat{y}_i$ are the actual value and its estimation, respectively.

# %%
def compute_rmse(var, var_hat):
    return np.sqrt(np.sum((var - var_hat) ** 2) / var.shape[0])

def compute_mape(var, var_hat):
    return np.sum(np.abs(var - var_hat) / var) / var.shape[0]

# %% [markdown]
# ### Define LRTC-TNN Function with `Numpy`

# %%
def LRTC(dense_tensor, sparse_tensor, alpha, rho, theta, epsilon, maxiter):
    """Low-Rank Tenor Completion with Truncated Nuclear Norm, LRTC-TNN."""
    dim = np.array(sparse_tensor.shape)
    pos_missing = np.where(sparse_tensor == 0)
    pos_test = np.where((dense_tensor != 0) & (sparse_tensor == 0))
    
    X = np.zeros(np.insert(dim, 0, len(dim))) # \boldsymbol{\mathcal{X}}
    T = np.zeros(np.insert(dim, 0, len(dim))) # \boldsymbol{\mathcal{T}}
    Z = sparse_tensor.copy()
    last_tensor = sparse_tensor.copy()
    snorm = np.sqrt(np.sum(sparse_tensor ** 2))
    it = 0
    while True:
        rho = min(rho * 1.05, 1e5)
        for k in range(len(dim)):
            X[k] = mat2ten(svt_tnn(ten2mat(Z - T[k] / rho, k), alpha[k], rho, np.int(np.ceil(theta * dim[k]))), dim, k)
        Z[pos_missing] = np.mean(X + T / rho, axis = 0)[pos_missing]
        T = T + rho * (X - np.broadcast_to(Z, np.insert(dim, 0, len(dim))))
        tensor_hat = np.einsum('k, kmnt -> mnt', alpha, X)
        tol = np.sqrt(np.sum((tensor_hat - last_tensor) ** 2)) / snorm
        last_tensor = tensor_hat.copy()
        it += 1
        print('Iter: {}'.format(it))
        print('Tolerance: {:.6}'.format(tol))
        print('MAPE: {:.6}'.format(compute_mape(dense_tensor[pos_test], tensor_hat[pos_test])))
        print('RMSE: {:.6}'.format(compute_rmse(dense_tensor[pos_test], tensor_hat[pos_test])))
        print()
        if (tol < epsilon) or (it >= maxiter):
            break
    
    print('Total iteration: {}'.format(it))
    print('Tolerance: {:.6}'.format(tol))
    print('Imputation MAPE: {:.6}'.format(compute_mape(dense_tensor[pos_test], tensor_hat[pos_test])))
    print('Imputation RMSE: {:.6}'.format(compute_rmse(dense_tensor[pos_test], tensor_hat[pos_test])))
    print()
    
    return tensor_hat

# %%
import time
import numpy as np
import scipy.io
np.random.seed(1000)

missing_rate = 0.3

## Random Missing (RM)
dense_tensor = scipy.io.loadmat('../datasets/Guangzhou-data-set/tensor.mat')['tensor'].transpose(0, 2, 1)
dim1, dim2, dim3 = dense_tensor.shape
sparse_tensor = dense_tensor * np.round(np.random.rand(dim1, dim2, dim3) + 0.5 - missing_rate)

start = time.time()
alpha = np.ones(3) / 3
rho = 1e-5
theta = 0.30
epsilon = 1e-3
maxiter = 100
tensor_hat = LRTC(dense_tensor, sparse_tensor, alpha, rho, theta, epsilon, maxiter)
end = time.time()
print('Running time: %.2f minutes' % ((end - start)/60.0))
# Out:
# Iter: 1
# Tolerance: 0.553985
# MAPE: 0.321826
# RMSE: 13.5421
#
# Iter: 2
# Tolerance: 0.481035
# MAPE: 0.183707
# RMSE: 6.90845
#
# Iter: 3
# Tolerance: 0.0689438
# MAPE: 0.222953
# RMSE: 8.20973
#
# Iter: 4
# Tolerance: 0.111374
# MAPE: 0.157234
# RMSE: 5.97984
#
# Iter: 5
# Tolerance: 0.0819003
# MAPE: 0.143751
# RMSE: 5.4756
#
# Iter: 6
# Tolerance: 0.0188061
# MAPE: 0.145837
# RMSE: 5.54376
#
# Iter: 7
# Tolerance: 0.0171874
# MAPE: 0.143576
# RMSE: 5.46624
#
# Iter: 8
# Tolerance: 0.165942
# MAPE: 0.134324
# RMSE: 5.65469
#
# Iter: 9
# Tolerance: 0.12562
# MAPE: 0.160029
# RMSE: 6.85603
#
# Iter: 10
# Tolerance: 0.208524
# MAPE: 0.134461
# RMSE: 5.76843
#
# Iter: 11
# Tolerance: 0.186198
# MAPE: 0.147891
# RMSE: 6.11242
#
# Iter: 12
# Tolerance: 0.183558
# MAPE: 0.170106
# RMSE: 7.50426
#
# Iter: 13
# Tolerance: 0.24486
# MAPE: 0.122516
# RMSE: 5.11533
#
# Iter: 14
# Tolerance: 0.183071
# MAPE: 0.166406
# RMSE: 7.24701
#
# Iter: 15
# Tolerance: 0.210898
# MAPE: 0.132615
# RMSE: 5.16953
#
# Iter: 16
# Tolerance: 0.119997
# MAPE: 0.13901
# RMSE: 5.61382
#
# Iter: 17
# Tolerance: 0.195039
# MAPE: 0.134017
# RMSE: 5.78268
#
# Iter: 18
# Tolerance: 0.226812
# MAPE: 0.16818
# RMSE: 7.34252
#
# Iter: 19
# Tolerance: 0.249498
# MAPE: 0.131967
# RMSE: 5.5291
#
# Iter: 20
# Tolerance: 0.190759
# MAPE: 0.146079
# RMSE: 6.20187
#
# Iter: 21
# Tolerance: 0.256635
# MAPE: 0.170283
# RMSE: 7.47416
#
# Iter: 22
# Tolerance: 0.286086
# MAPE: 0.159039
# RMSE: 7.04298
#
# Iter: 23
# Tolerance: 0.246743
# MAPE: 0.148912
# RMSE: 6.52501
#
# Iter: 24
# Tolerance: 0.262369
# MAPE: 0.159409
# RMSE: 6.92543
#
# Iter: 25
# Tolerance: 0.294373
# MAPE: 0.178331
# RMSE: 7.84569
#
# Iter: 26
# Tolerance: 0.317646
# MAPE: 0.168631
# RMSE: 7.48714
#
# Iter: 27
# Tolerance: 0.342189
# MAPE: 0.188945
# RMSE: 8.33652
#
# Iter: 28
# Tolerance: 0.335945
# MAPE: 0.17518
# RMSE: 7.72995
#
# Iter: 29
# Tolerance: 0.354267
# MAPE: 0.189244
# RMSE: 8.34681
#
# Iter: 30
# Tolerance: 0.345745
# MAPE: 0.182008
# RMSE: 7.83651
#
# Iter: 31
# Tolerance: 0.330138
# MAPE: 0.174157
# RMSE: 7.66695
#
# Iter: 32
# Tolerance: 0.320744
# MAPE: 0.161384
# RMSE: 7.1092
#
# Iter: 33
# Tolerance: 0.291261
# MAPE: 0.160326
# RMSE: 6.98228
#
# Iter: 34
# Tolerance: 0.274431
# MAPE: 0.154114
# RMSE: 6.68417
#
# Iter: 35
# Tolerance: 0.278704
# MAPE: 0.158374
# RMSE: 6.95213
#
# Iter: 36
# Tolerance: 0.28678
# MAPE: 0.16118
# RMSE: 6.98161
#
# Iter: 37
# Tolerance: 0.283068
# MAPE: 0.154778
# RMSE: 6.69476
#
# Iter: 38
# Tolerance: 0.289092
# MAPE: 0.168978
# RMSE: 7.26647
#
# Iter: 39
# Tolerance: 0.287236
# MAPE: 0.157877
# RMSE: 6.76111
#
# Iter: 40
# Tolerance: 0.294574
# MAPE: 0.174614
# RMSE: 7.40711
#
# Iter: 41
# Tolerance: 0.29962
# MAPE: 0.16577
# RMSE: 7.0378
#
# Iter: 42
# Tolerance: 0.294506
# MAPE: 0.165119
# RMSE: 6.98503
#
# Iter: 43
# Tolerance: 0.275861
# MAPE: 0.157971
# RMSE: 6.64617
#
# Iter: 44
# Tolerance: 0.26697
# MAPE: 0.164074
# RMSE: 6.85205
#
# Iter: 45
# Tolerance: 0.260777
# MAPE: 0.148317
# RMSE: 6.22218
#
# Iter: 46
# Tolerance: 0.251127
# MAPE: 0.151421
# RMSE: 6.34179
#
# Iter: 47
# Tolerance: 0.245198
# MAPE: 0.1439
# RMSE: 6.02449
#
# Iter: 48
# Tolerance: 0.237808
# MAPE: 0.136899
# RMSE: 5.72005
#
# Iter: 49
# Tolerance: 0.224687
# MAPE: 0.132212
# RMSE: 5.51797
#
# Iter: 50
# Tolerance: 0.218838
# MAPE: 0.13012
# RMSE: 5.44382
#
# Iter: 51
# Tolerance: 0.208325
# MAPE: 0.125179
# RMSE: 5.22714
#
# Iter: 52
# Tolerance: 0.205853
# MAPE: 0.125494
# RMSE: 5.24027
#
# Iter: 53
# Tolerance: 0.201577
# MAPE: 0.118908
# RMSE: 4.97228
#
# Iter: 54
# Tolerance: 0.19235
# MAPE: 0.121127
# RMSE: 5.05932
#
# Iter: 55
# Tolerance: 0.192226
# MAPE: 0.117922
# RMSE: 4.93055
#
# Iter: 56
# Tolerance: 0.184972
# MAPE: 0.114541
# RMSE: 4.76257
#
# Iter: 57
# Tolerance: 0.179398
# MAPE: 0.112872
# RMSE: 4.70763
#
# Iter: 58
# Tolerance: 0.17653
# MAPE: 0.112415
# RMSE: 4.6714
#
# Iter: 59
# Tolerance: 0.172715
# MAPE: 0.109612
# RMSE: 4.55944
#
# Iter: 60
# Tolerance: 0.168336
# MAPE: 0.108207
# RMSE: 4.48157
#
# Iter: 61
# Tolerance: 0.162497
# MAPE: 0.105222
# RMSE: 4.36608
#
# Iter: 62
# Tolerance: 0.160173
# MAPE: 0.105125
# RMSE: 4.35802
#
# Iter: 63
# Tolerance: 0.154648
# MAPE: 0.102029
# RMSE: 4.22721
#
# Iter: 64
# Tolerance: 0.150091
# MAPE: 0.100912
# RMSE: 4.19402
#
# Iter: 65
# Tolerance: 0.146458
# MAPE: 0.098435
# RMSE: 4.08512
#
# Iter: 66
# Tolerance: 0.141733
# MAPE: 0.0972947
# RMSE: 4.04437
#
# Iter: 67
# Tolerance: 0.1357
# MAPE: 0.0952125
# RMSE: 3.9592
#
# Iter: 68
# Tolerance: 0.132807
# MAPE: 0.0935711
# RMSE: 3.89159
#
# Iter: 69
# Tolerance: 0.129557
# MAPE: 0.0923524
# RMSE: 3.83842
#
# Iter: 70
# Tolerance: 0.123381
# MAPE: 0.090585
# RMSE: 3.77082
#
# Iter: 71
# Tolerance: 0.120057
# MAPE: 0.0895073
# RMSE: 3.72324
#
# Iter: 72
# Tolerance: 0.117106
# MAPE: 0.0880358
# RMSE: 3.67265
#
# Iter: 73
# Tolerance: 0.113951
# MAPE: 0.0875542
# RMSE: 3.65215
#
# Iter: 74
# Tolerance: 0.110205
# MAPE: 0.086365
# RMSE: 3.60501
#
# Iter: 75
# Tolerance: 0.1069
# MAPE: 0.0852164
# RMSE: 3.56168
#
# Iter: 76
# Tolerance: 0.104039
# MAPE: 0.0846608
# RMSE: 3.54236
#
# Iter: 77
# Tolerance: 0.101084
# MAPE: 0.0840511
# RMSE: 3.51403
#
# Iter: 78
# Tolerance: 0.0983767
# MAPE: 0.0831223
# RMSE: 3.478
#
# Iter: 79
# Tolerance: 0.0948197
# MAPE: 0.08169
# RMSE: 3.42277
#
# Iter: 80
# Tolerance: 0.0915406
# MAPE: 0.0813654
# RMSE: 3.41088
#
# Iter: 81
# Tolerance: 0.0877781
# MAPE: 0.0799144
# RMSE: 3.35503
#
# Iter: 82
# Tolerance: 0.0842571
# MAPE: 0.0790634
# RMSE: 3.32891
#
# Iter: 83
# Tolerance: 0.0805569
# MAPE: 0.0778914
# RMSE: 3.27906
#
# Iter: 84
# Tolerance: 0.0769908
# MAPE: 0.0772261
# RMSE: 3.26375
#
# Iter: 85
# Tolerance: 0.0735873
# MAPE: 0.0763044
# RMSE: 3.21906
#
# Iter: 86
# Tolerance: 0.0705609
# MAPE: 0.0755938
# RMSE: 3.20001
#
# Iter: 87
# Tolerance: 0.0678416
# MAPE: 0.0748122
# RMSE: 3.16854
#
# Iter: 88
# Tolerance: 0.0650272
# MAPE: 0.0744516
# RMSE: 3.1586
#
# Iter: 89
# Tolerance: 0.0624916
# MAPE: 0.0738694
# RMSE: 3.13381
#
# Iter: 90
# Tolerance: 0.0598682
# MAPE: 0.0731942
# RMSE: 3.11373
#
# Iter: 91
# Tolerance: 0.0573986
# MAPE: 0.0730344
# RMSE: 3.1027
#
# Iter: 92
# Tolerance: 0.0551386
# MAPE: 0.0724432
# RMSE: 3.08535
#
# Iter: 93
# Tolerance: 0.0525187
# MAPE: 0.0721914
# RMSE: 3.07289
#
# Iter: 94
# Tolerance: 0.0504116
# MAPE: 0.0717209
# RMSE: 3.05891
#
# Iter: 95
# Tolerance: 0.0479374
# MAPE: 0.0715225
# RMSE: 3.04824
#
# Iter: 96
# Tolerance: 0.0457236
# MAPE: 0.0710557
# RMSE: 3.03435
#
# Iter: 97
# Tolerance: 0.0432301
# MAPE: 0.0709482
# RMSE: 3.02806
#
# Iter: 98
# Tolerance: 0.04107
# MAPE: 0.0705909
# RMSE: 3.01784
#
# Iter: 99
# Tolerance: 0.0387888
# MAPE: 0.0704986
# RMSE: 3.01247
#
# Iter: 100
# Tolerance: 0.0366576
# MAPE: 0.0701864
# RMSE: 3.00373
#
# Total iteration: 100
# Tolerance: 0.0366576
# Imputation MAPE: 0.0701864
# Imputation RMSE: 3.00373
#
# Running time: 0.42 minutes

# %%
import time
import numpy as np
import scipy.io
np.random.seed(1000)

missing_rate = 0.7

## Random Missing (RM)
dense_tensor = scipy.io.loadmat('../datasets/Guangzhou-data-set/tensor.mat')['tensor'].transpose(0, 2, 1)
dim1, dim2, dim3 = dense_tensor.shape
sparse_tensor = dense_tensor * np.round(np.random.rand(dim1, dim2, dim3) + 0.5 - missing_rate)

start = time.time()
alpha = np.ones(3) / 3
rho = 1e-5
theta = 0.30
epsilon = 1e-3
maxiter = 100
tensor_hat = LRTC(dense_tensor, sparse_tensor, alpha, rho, theta, epsilon, maxiter)
end = time.time()
print('Running time: %.2f minutes' % ((end - start)/60.0))
# Out:
# Iter: 1
# Tolerance: 1.0
# MAPE: 1.0
# RMSE: 40.486
#
# Iter: 2
# Tolerance: 1.06086
# MAPE: 0.419618
# RMSE: 17.8861
#
# Iter: 3
# Tolerance: 0.91566
# MAPE: 0.179018
# RMSE: 6.83372
#
# Iter: 4
# Tolerance: 0.566301
# MAPE: 0.480006
# RMSE: 17.1711
#
# Iter: 5
# Tolerance: 0.174255
# MAPE: 0.576447
# RMSE: 20.6776
#
# Iter: 6
# Tolerance: 0.160295
# MAPE: 0.488713
# RMSE: 17.4629
#
# Iter: 7
# Tolerance: 0.32132
# MAPE: 0.306034
# RMSE: 11.0476
#
# Iter: 8
# Tolerance: 0.33789
# MAPE: 0.163258
# RMSE: 6.23032
#
# Iter: 9
# Tolerance: 0.250301
# MAPE: 0.183872
# RMSE: 7.04097
#
# Iter: 10
# Tolerance: 0.119789
# MAPE: 0.220789
# RMSE: 8.69015
#
# Iter: 11
# Tolerance: 0.0297147
# MAPE: 0.217193
# RMSE: 8.55532
#
# Iter: 12
# Tolerance: 0.0918136
# MAPE: 0.1873
# RMSE: 7.22997
#
# Iter: 13
# Tolerance: 0.118631
# MAPE: 0.158874
# RMSE: 6.034
#
# Iter: 14
# Tolerance: 0.217339
# MAPE: 0.128521
# RMSE: 5.27145
#
# Iter: 15
# Tolerance: 0.192803
# MAPE: 0.166683
# RMSE: 6.98412
#
# Iter: 16
# Tolerance: 0.191586
# MAPE: 0.181288
# RMSE: 7.74248
#
# Iter: 17
# Tolerance: 0.207365
# MAPE: 0.164114
# RMSE: 6.99953
#
# Iter: 18
# Tolerance: 0.212784
# MAPE: 0.14462
# RMSE: 6.25012
#
# Iter: 19
# Tolerance: 0.240364
# MAPE: 0.145409
# RMSE: 6.18474
#
# Iter: 20
# Tolerance: 0.19733
# MAPE: 0.161356
# RMSE: 6.75163
#
# Iter: 21
# Tolerance: 0.203361
# MAPE: 0.162716
# RMSE: 6.95658
#
# Iter: 22
# Tolerance: 0.234446
# MAPE: 0.144316
# RMSE: 5.61219
#
# Iter: 23
# Tolerance: 0.1871
# MAPE: 0.136612
# RMSE: 5.56085
#
# Iter: 24
# Tolerance: 0.131665
# MAPE: 0.135462
# RMSE: 5.48192
#
# Iter: 25
# Tolerance: 0.14188
# MAPE: 0.133624
# RMSE: 5.52785
#
# Iter: 26
# Tolerance: 0.196011
# MAPE: 0.139504
# RMSE: 5.88599
#
# Iter: 27
# Tolerance: 0.246628
# MAPE: 0.148585
# RMSE: 6.4094
#
# Iter: 28
# Tolerance: 0.271178
# MAPE: 0.144068
# RMSE: 6.1975
#
# Iter: 29
# Tolerance: 0.280709
# MAPE: 0.148705
# RMSE: 6.56203
#
# Iter: 30
# Tolerance: 0.270346
# MAPE: 0.147282
# RMSE: 6.48631
#
# Iter: 31
# Tolerance: 0.275442
# MAPE: 0.14433
# RMSE: 6.28666
#
# Iter: 32
# Tolerance: 0.289781
# MAPE: 0.140517
# RMSE: 5.96889
#
# Iter: 33
# Tolerance: 0.300358
# MAPE: 0.154786
# RMSE: 6.60584
#
# Iter: 34
# Tolerance: 0.31005
# MAPE: 0.148855
# RMSE: 6.36083
#
# Iter: 35
# Tolerance: 0.356498
# MAPE: 0.162822
# RMSE: 7.01431
#
# Iter: 36
# Tolerance: 0.334418
# MAPE: 0.141307
# RMSE: 5.96873
#
# Iter: 37
# Tolerance: 0.357032
# MAPE: 0.160099
# RMSE: 6.90231
#
# Iter: 38
# Tolerance: 0.347872
# MAPE: 0.136421
# RMSE: 5.85052
#
# Iter: 39
# Tolerance: 0.297092
# MAPE: 0.138799
# RMSE: 6.01841
#
# Iter: 40
# Tolerance: 0.30334
# MAPE: 0.141888
# RMSE: 6.1412
#
# Iter: 41
# Tolerance: 0.286807
# MAPE: 0.135541
# RMSE: 5.85202
#
# Iter: 42
# Tolerance: 0.306001
# MAPE: 0.148289
# RMSE: 6.40854
#
# Iter: 43
# Tolerance: 0.306093
# MAPE: 0.14021
# RMSE: 6.00919
#
# Iter: 44
# Tolerance: 0.306989
# MAPE: 0.14902
# RMSE: 6.35649
#
# Iter: 45
# Tolerance: 0.29701
# MAPE: 0.136599
# RMSE: 5.77158
#
# Iter: 46
# Tolerance: 0.310199
# MAPE: 0.148408
# RMSE: 6.28192
#
# Iter: 47
# Tolerance: 0.29353
# MAPE: 0.133892
# RMSE: 5.58931
#
# Iter: 48
# Tolerance: 0.299561
# MAPE: 0.147817
# RMSE: 6.19763
#
# Iter: 49
# Tolerance: 0.277896
# MAPE: 0.125554
# RMSE: 5.22293
#
# Iter: 50
# Tolerance: 0.275942
# MAPE: 0.141431
# RMSE: 5.90231
#
# Iter: 51
# Tolerance: 0.258188
# MAPE: 0.120961
# RMSE: 5.06679
#
# Iter: 52
# Tolerance: 0.254378
# MAPE: 0.133096
# RMSE: 5.55112
#
# Iter: 53
# Tolerance: 0.240076
# MAPE: 0.123102
# RMSE: 5.15211
#
# Iter: 54
# Tolerance: 0.242695
# MAPE: 0.12854
# RMSE: 5.35383
#
# Iter: 55
# Tolerance: 0.23361
# MAPE: 0.123276
# RMSE: 5.12628
#
# Iter: 56
# Tolerance: 0.225691
# MAPE: 0.121679
# RMSE: 5.06179
#
# Iter: 57
# Tolerance: 0.216471
# MAPE: 0.120105
# RMSE: 4.96595
#
# Iter: 58
# Tolerance: 0.217933
# MAPE: 0.119331
# RMSE: 4.94367
#
# Iter: 59
# Tolerance: 0.204688
# MAPE: 0.114272
# RMSE: 4.7333
#
# Iter: 60
# Tolerance: 0.201553
# MAPE: 0.115951
# RMSE: 4.80062
#
# Iter: 61
# Tolerance: 0.193179
# MAPE: 0.111215
# RMSE: 4.6123
#
# Iter: 62
# Tolerance: 0.188142
# MAPE: 0.112036
# RMSE: 4.63872
#
# Iter: 63
# Tolerance: 0.183796
# MAPE: 0.110121
# RMSE: 4.56637
#
# Iter: 64
# Tolerance: 0.177821
# MAPE: 0.107983
# RMSE: 4.481
#
# Iter: 65
# Tolerance: 0.169388
# MAPE: 0.106071
# RMSE: 4.40037
#
# Iter: 66
# Tolerance: 0.167192
# MAPE: 0.105999
# RMSE: 4.40549
#
# Iter: 67
# Tolerance: 0.161469
# MAPE: 0.104287
# RMSE: 4.33439
#
# Iter: 68
# Tolerance: 0.15833
# MAPE: 0.104074
# RMSE: 4.31863
#
# Iter: 69
# Tolerance: 0.151712
# MAPE: 0.102121
# RMSE: 4.24576
#
# Iter: 70
# Tolerance: 0.148073
# MAPE: 0.101364
# RMSE: 4.21841
#
# Iter: 71
# Tolerance: 0.142951
# MAPE: 0.100024
# RMSE: 4.16525
#
# Iter: 72
# Tolerance: 0.138099
# MAPE: 0.0989761
# RMSE: 4.11976
#
# Iter: 73
# Tolerance: 0.133192
# MAPE: 0.0980267
# RMSE: 4.09297
#
# Iter: 74
# Tolerance: 0.128717
# MAPE: 0.0969629
# RMSE: 4.05118
#
# Iter: 75
# Tolerance: 0.123934
# MAPE: 0.095912
# RMSE: 4.01126
#
# Iter: 76
# Tolerance: 0.120172
# MAPE: 0.0951914
# RMSE: 3.97912
#
# Iter: 77
# Tolerance: 0.116939
# MAPE: 0.0942742
# RMSE: 3.95094
#
# Iter: 78
# Tolerance: 0.111859
# MAPE: 0.0930587
# RMSE: 3.90825
#
# Iter: 79
# Tolerance: 0.107613
# MAPE: 0.0922198
# RMSE: 3.87682
#
# Iter: 80
# Tolerance: 0.10414
# MAPE: 0.0916876
# RMSE: 3.85657
#
# Iter: 81
# Tolerance: 0.0999753
# MAPE: 0.0907376
# RMSE: 3.82308
#
# Iter: 82
# Tolerance: 0.0969174
# MAPE: 0.0903802
# RMSE: 3.80893
#
# Iter: 83
# Tolerance: 0.0933127
# MAPE: 0.0896836
# RMSE: 3.78515
#
# Iter: 84
# Tolerance: 0.0898368
# MAPE: 0.0892825
# RMSE: 3.76928
#
# Iter: 85
# Tolerance: 0.0863402
# MAPE: 0.0886765
# RMSE: 3.74863
#
# Iter: 86
# Tolerance: 0.0828768
# MAPE: 0.0882466
# RMSE: 3.73212
#
# Iter: 87
# Tolerance: 0.0794601
# MAPE: 0.0875765
# RMSE: 3.70927
#
# Iter: 88
# Tolerance: 0.0762736
# MAPE: 0.0872364
# RMSE: 3.69919
#
# Iter: 89
# Tolerance: 0.073578
# MAPE: 0.0867215
# RMSE: 3.68201
#
# Iter: 90
# Tolerance: 0.0712582
# MAPE: 0.0864299
# RMSE: 3.67265
#
# Iter: 91
# Tolerance: 0.0692096
# MAPE: 0.0859853
# RMSE: 3.65851
#
# Iter: 92
# Tolerance: 0.0671035
# MAPE: 0.0856478
# RMSE: 3.64637
#
# Iter: 93
# Tolerance: 0.0650437
# MAPE: 0.0854394
# RMSE: 3.64008
#
# Iter: 94
# Tolerance: 0.0630487
# MAPE: 0.0851494
# RMSE: 3.63013
#
# Iter: 95
# Tolerance: 0.0609968
# MAPE: 0.0849502
# RMSE: 3.6241
#
# Iter: 96
# Tolerance: 0.0587888
# MAPE: 0.0846793
# RMSE: 3.61478
#
# Iter: 97
# Tolerance: 0.0565114
# MAPE: 0.0845706
# RMSE: 3.61148
#
# Iter: 98
# Tolerance: 0.0540818
# MAPE: 0.0844027
# RMSE: 3.60539
#
# Iter: 99
# Tolerance: 0.0515247
# MAPE: 0.0842956
# RMSE: 3.60262
#
# Iter: 100
# Tolerance: 0.0488821
# MAPE: 0.0841551
# RMSE: 3.59786
#
# Total iteration: 100
# Tolerance: 0.0488821
# Imputation MAPE: 0.0841551
# Imputation RMSE: 3.59786
#
# Running time: 0.48 minutes

# %%
import time
import numpy as np
import scipy.io
np.random.seed(1000)

missing_rate = 0.3

## Non-random Missing (NM)
dense_tensor = scipy.io.loadmat('../datasets/Guangzhou-data-set/tensor.mat')['tensor'].transpose(0, 2, 1)
dim1, dim2, dim3 = dense_tensor.shape
sparse_tensor = dense_tensor * np.round(np.random.rand(dim1, dim3) + 0.5 - missing_rate)[:, None, :]

start = time.time()
alpha = np.ones(3) / 3
rho = 1e-5
theta = 0.05
epsilon = 1e-3
maxiter = 100
tensor_hat = LRTC(dense_tensor, sparse_tensor, alpha, rho, theta, epsilon, maxiter)
end = time.time()
print('Running time: %.2f minutes' % ((end - start)/60.0))
# Out:
# Iter: 1
# Tolerance: 0.37918
# MAPE: 0.533876
# RMSE: 22.353
#
# Iter: 2
# Tolerance: 0.353986
# MAPE: 0.165107
# RMSE: 6.46655
#
# Iter: 3
# Tolerance: 0.20406
# MAPE: 0.28282
# RMSE: 10.1567
#
# Iter: 4
# Tolerance: 0.0563174
# MAPE: 0.327222
# RMSE: 11.6503
#
# Iter: 5
# Tolerance: 0.0736269
# MAPE: 0.241519
# RMSE: 8.83887
#
# Iter: 6
# Tolerance: 0.0883408
# MAPE: 0.163517
# RMSE: 6.19368
#
# Iter: 7
# Tolerance: 0.0619152
# MAPE: 0.155775
# RMSE: 5.88726
#
# Iter: 8
# Tolerance: 0.185033
# MAPE: 0.149812
# RMSE: 5.77681
#
# Iter: 9
# Tolerance: 0.141997
# MAPE: 0.158168
# RMSE: 6.56669
#
# Iter: 10
# Tolerance: 0.207219
# MAPE: 0.133853
# RMSE: 5.19757
#
# Iter: 11
# Tolerance: 0.203058
# MAPE: 0.147319
# RMSE: 6.14923
#
# Iter: 12
# Tolerance: 0.218047
# MAPE: 0.151963
# RMSE: 6.28579
#
# Iter: 13
# Tolerance: 0.233732
# MAPE: 0.125168
# RMSE: 5.0695
#
# Iter: 14
# Tolerance: 0.0981918
# MAPE: 0.141322
# RMSE: 5.79293
#
# Iter: 15
# Tolerance: 0.241205
# MAPE: 0.155668
# RMSE: 6.63688
#
# Iter: 16
# Tolerance: 0.214494
# MAPE: 0.139863
# RMSE: 5.60026
#
# Iter: 17
# Tolerance: 0.234984
# MAPE: 0.127191
# RMSE: 5.44396
#
# Iter: 18
# Tolerance: 0.221788
# MAPE: 0.14164
# RMSE: 5.93674
#
# Iter: 19
# Tolerance: 0.263856
# MAPE: 0.144242
# RMSE: 6.02208
#
# Iter: 20
# Tolerance: 0.212776
# MAPE: 0.136492
# RMSE: 5.52424
#
# Iter: 21
# Tolerance: 0.241439
# MAPE: 0.15785
# RMSE: 6.6762
#
# Iter: 22
# Tolerance: 0.265083
# MAPE: 0.152
# RMSE: 6.61163
#
# Iter: 23
# Tolerance: 0.278147
# MAPE: 0.163799
# RMSE: 7.20422
#
# Iter: 24
# Tolerance: 0.284449
# MAPE: 0.16194
# RMSE: 6.95173
#
# Iter: 25
# Tolerance: 0.28929
# MAPE: 0.163823
# RMSE: 7.14227
#
# Iter: 26
# Tolerance: 0.291994
# MAPE: 0.150132
# RMSE: 6.47984
#
# Iter: 27
# Tolerance: 0.290036
# MAPE: 0.16896
# RMSE: 7.33946
#
# Iter: 28
# Tolerance: 0.291711
# MAPE: 0.15848
# RMSE: 6.81979
#
# Iter: 29
# Tolerance: 0.280359
# MAPE: 0.16091
# RMSE: 6.87401
#
# Iter: 30
# Tolerance: 0.295827
# MAPE: 0.164743
# RMSE: 7.13882
#
# Iter: 31
# Tolerance: 0.283564
# MAPE: 0.164103
# RMSE: 6.89845
#
# Iter: 32
# Tolerance: 0.276985
# MAPE: 0.162074
# RMSE: 6.94561
#
# Iter: 33
# Tolerance: 0.277493
# MAPE: 0.155147
# RMSE: 6.6628
#
# Iter: 34
# Tolerance: 0.270768
# MAPE: 0.162355
# RMSE: 6.95116
#
# Iter: 35
# Tolerance: 0.277369
# MAPE: 0.156611
# RMSE: 6.61744
#
# Iter: 36
# Tolerance: 0.267131
# MAPE: 0.158839
# RMSE: 6.68928
#
# Iter: 37
# Tolerance: 0.259988
# MAPE: 0.152968
# RMSE: 6.40513
#
# Iter: 38
# Tolerance: 0.248426
# MAPE: 0.147692
# RMSE: 6.23514
#
# Iter: 39
# Tolerance: 0.239221
# MAPE: 0.148549
# RMSE: 6.21943
#
# Iter: 40
# Tolerance: 0.23014
# MAPE: 0.144034
# RMSE: 6.02536
#
# Iter: 41
# Tolerance: 0.220982
# MAPE: 0.138248
# RMSE: 5.79953
#
# Iter: 42
# Tolerance: 0.211481
# MAPE: 0.137494
# RMSE: 5.69572
#
# Iter: 43
# Tolerance: 0.201785
# MAPE: 0.132198
# RMSE: 5.53344
#
# Iter: 44
# Tolerance: 0.19225
# MAPE: 0.132915
# RMSE: 5.52673
#
# Iter: 45
# Tolerance: 0.184481
# MAPE: 0.131135
# RMSE: 5.44145
#
# Iter: 46
# Tolerance: 0.172067
# MAPE: 0.126806
# RMSE: 5.2681
#
# Iter: 47
# Tolerance: 0.164347
# MAPE: 0.123676
# RMSE: 5.1638
#
# Iter: 48
# Tolerance: 0.156813
# MAPE: 0.120237
# RMSE: 5.03974
#
# Iter: 49
# Tolerance: 0.151138
# MAPE: 0.121526
# RMSE: 5.06925
#
# Iter: 50
# Tolerance: 0.146647
# MAPE: 0.119092
# RMSE: 4.9722
#
# Iter: 51
# Tolerance: 0.139354
# MAPE: 0.116577
# RMSE: 4.85027
#
# Iter: 52
# Tolerance: 0.13099
# MAPE: 0.11396
# RMSE: 4.74458
#
# Iter: 53
# Tolerance: 0.124546
# MAPE: 0.113256
# RMSE: 4.72873
#
# Iter: 54
# Tolerance: 0.118849
# MAPE: 0.110245
# RMSE: 4.62549
#
# Iter: 55
# Tolerance: 0.115246
# MAPE: 0.10834
# RMSE: 4.53088
#
# Iter: 56
# Tolerance: 0.110508
# MAPE: 0.10753
# RMSE: 4.50499
#
# Iter: 57
# Tolerance: 0.104483
# MAPE: 0.106456
# RMSE: 4.45159
#
# Iter: 58
# Tolerance: 0.100566
# MAPE: 0.105994
# RMSE: 4.43459
#
# Iter: 59
# Tolerance: 0.0957464
# MAPE: 0.104002
# RMSE: 4.36439
#
# Iter: 60
# Tolerance: 0.0894323
# MAPE: 0.104115
# RMSE: 4.3436
#
# Iter: 61
# Tolerance: 0.0878636
# MAPE: 0.102492
# RMSE: 4.29513
#
# Iter: 62
# Tolerance: 0.0837565
# MAPE: 0.101893
# RMSE: 4.26054
#
# Iter: 63
# Tolerance: 0.0797772
# MAPE: 0.101378
# RMSE: 4.24469
#
# Iter: 64
# Tolerance: 0.0754815
# MAPE: 0.100454
# RMSE: 4.21437
#
# Iter: 65
# Tolerance: 0.0714011
# MAPE: 0.0999019
# RMSE: 4.19949
#
# Iter: 66
# Tolerance: 0.0687537
# MAPE: 0.099603
# RMSE: 4.17944
#
# Iter: 67
# Tolerance: 0.0650027
# MAPE: 0.0990974
# RMSE: 4.17004
#
# Iter: 68
# Tolerance: 0.063056
# MAPE: 0.0988417
# RMSE: 4.15398
#
# Iter: 69
# Tolerance: 0.059237
# MAPE: 0.0983426
# RMSE: 4.13932
#
# Iter: 70
# Tolerance: 0.0572065
# MAPE: 0.0980885
# RMSE: 4.13033
#
# Iter: 71
# Tolerance: 0.0546641
# MAPE: 0.0978587
# RMSE: 4.1221
#
# Iter: 72
# Tolerance: 0.052466
# MAPE: 0.0979155
# RMSE: 4.12412
#
# Iter: 73
# Tolerance: 0.0499571
# MAPE: 0.0975887
# RMSE: 4.11286
#
# Iter: 74
# Tolerance: 0.0475371
# MAPE: 0.0977084
# RMSE: 4.11273
#
# Iter: 75
# Tolerance: 0.0455817
# MAPE: 0.0972044
# RMSE: 4.10146
#
# Iter: 76
# Tolerance: 0.0430646
# MAPE: 0.0974119
# RMSE: 4.10406
#
# Iter: 77
# Tolerance: 0.041971
# MAPE: 0.0970762
# RMSE: 4.09578
#
# Iter: 78
# Tolerance: 0.0397702
# MAPE: 0.0972663
# RMSE: 4.1012
#
# Iter: 79
# Tolerance: 0.0376977
# MAPE: 0.0969612
# RMSE: 4.09332
#
# Iter: 80
# Tolerance: 0.0358077
# MAPE: 0.0970975
# RMSE: 4.09583
#
# Iter: 81
# Tolerance: 0.0338029
# MAPE: 0.0968573
# RMSE: 4.09031
#
# Iter: 82
# Tolerance: 0.0320672
# MAPE: 0.0969478
# RMSE: 4.09178
#
# Iter: 83
# Tolerance: 0.0301389
# MAPE: 0.0967913
# RMSE: 4.08911
#
# Iter: 84
# Tolerance: 0.0284734
# MAPE: 0.0968389
# RMSE: 4.08869
#
# Iter: 85
# Tolerance: 0.0268313
# MAPE: 0.0967229
# RMSE: 4.08766
#
# Iter: 86
# Tolerance: 0.0253217
# MAPE: 0.0967562
# RMSE: 4.08659
#
# Iter: 87
# Tolerance: 0.0239211
# MAPE: 0.0966673
# RMSE: 4.08647
#
# Iter: 88
# Tolerance: 0.0225438
# MAPE: 0.0966994
# RMSE: 4.08546
#
# Iter: 89
# Tolerance: 0.0212723
# MAPE: 0.0966251
# RMSE: 4.08568
#
# Iter: 90
# Tolerance: 0.0200162
# MAPE: 0.096658
# RMSE: 4.08495
#
# Iter: 91
# Tolerance: 0.0188434
# MAPE: 0.0965915
# RMSE: 4.0852
#
# Iter: 92
# Tolerance: 0.0177019
# MAPE: 0.0966231
# RMSE: 4.0847
#
# Iter: 93
# Tolerance: 0.0166229
# MAPE: 0.0965637
# RMSE: 4.08491
#
# Iter: 94
# Tolerance: 0.0155783
# MAPE: 0.0965921
# RMSE: 4.0846
#
# Iter: 95
# Tolerance: 0.0145847
# MAPE: 0.0965401
# RMSE: 4.08477
#
# Iter: 96
# Tolerance: 0.0136227
# MAPE: 0.0965654
# RMSE: 4.08464
#
# Iter: 97
# Tolerance: 0.0127159
# MAPE: 0.0965207
# RMSE: 4.08479
#
# Iter: 98
# Tolerance: 0.0118393
# MAPE: 0.0965429
# RMSE: 4.08484
#
# Iter: 99
# Tolerance: 0.0110303
# MAPE: 0.0965053
# RMSE: 4.08494
#
# Iter: 100
# Tolerance: 0.0102471
# MAPE: 0.0965249
# RMSE: 4.08516
#
# Total iteration: 100
# Tolerance: 0.0102471
# Imputation MAPE: 0.0965249
# Imputation RMSE: 4.08516
#
# Running time: 0.45 minutes

# %%
import numpy as np
import scipy.io
np.random.seed(1000)

missing_rate = 0.7

## Non-random Missing (NM)
dense_tensor = scipy.io.loadmat('../datasets/Guangzhou-data-set/tensor.mat')['tensor'].transpose(0, 2, 1)
dim1, dim2, dim3 = dense_tensor.shape
sparse_tensor = dense_tensor * np.round(np.random.rand(dim1, dim3) + 0.5 - missing_rate)[:, None, :]

import time
start = time.time()
alpha = np.ones(3) / 3
rho = 1e-5
theta = 0.05
epsilon = 1e-3
maxiter = 100
tensor_hat = LRTC(dense_tensor, sparse_tensor, alpha, rho, theta, epsilon, maxiter)
end = time.time()
print('Running time: %.2f minutes' % ((end - start)/60.0))
# Out:
# Iter: 1
# Tolerance: 1.0
# MAPE: 1.0
# RMSE: 40.4194
#
# Iter: 2
# Tolerance: 1.20977
# MAPE: 0.607054
# RMSE: 25.4008
#
# Iter: 3
# Tolerance: 0.640007
# MAPE: 0.262731
# RMSE: 11.3674
#
# Iter: 4
# Tolerance: 0.555859
# MAPE: 0.252884
# RMSE: 9.92456
#
# Iter: 5
# Tolerance: 0.376262
# MAPE: 0.450062
# RMSE: 16.5054
#
# Iter: 6
# Tolerance: 0.200597
# MAPE: 0.553107
# RMSE: 19.8403
#
# Iter: 7
# Tolerance: 0.135598
# MAPE: 0.539164
# RMSE: 19.3619
#
# Iter: 8
# Tolerance: 0.19185
# MAPE: 0.44325
# RMSE: 16.3151
#
# Iter: 9
# Tolerance: 0.232838
# MAPE: 0.32133
# RMSE: 12.388
#
# Iter: 10
# Tolerance: 0.231055
# MAPE: 0.236936
# RMSE: 9.31461
#
# Iter: 11
# Tolerance: 0.306719
# MAPE: 0.201839
# RMSE: 7.96835
#
# Iter: 12
# Tolerance: 0.268616
# MAPE: 0.210674
# RMSE: 8.35135
#
# Iter: 13
# Tolerance: 0.11366
# MAPE: 0.223274
# RMSE: 8.85254
#
# Iter: 14
# Tolerance: 0.215304
# MAPE: 0.217746
# RMSE: 8.71707
#
# Iter: 15
# Tolerance: 0.327489
# MAPE: 0.193223
# RMSE: 8.04524
#
# Iter: 16
# Tolerance: 0.221779
# MAPE: 0.183803
# RMSE: 7.74406
#
# Iter: 17
# Tolerance: 0.18173
# MAPE: 0.175597
# RMSE: 7.44621
#
# Iter: 18
# Tolerance: 0.202937
# MAPE: 0.16661
# RMSE: 7.01871
#
# Iter: 19
# Tolerance: 0.223724
# MAPE: 0.151579
# RMSE: 5.86668
#
# Iter: 20
# Tolerance: 0.184755
# MAPE: 0.173127
# RMSE: 6.6032
#
# Iter: 21
# Tolerance: 0.191747
# MAPE: 0.165473
# RMSE: 6.3546
#
# Iter: 22
# Tolerance: 0.252001
# MAPE: 0.161425
# RMSE: 6.49932
#
# Iter: 23
# Tolerance: 0.349853
# MAPE: 0.147808
# RMSE: 6.20772
#
# Iter: 24
# Tolerance: 0.300805
# MAPE: 0.141531
# RMSE: 5.73254
#
# Iter: 25
# Tolerance: 0.216465
# MAPE: 0.139997
# RMSE: 5.69518
#
# Iter: 26
# Tolerance: 0.244796
# MAPE: 0.144632
# RMSE: 6.18777
#
# Iter: 27
# Tolerance: 0.250798
# MAPE: 0.143914
# RMSE: 6.13001
#
# Iter: 28
# Tolerance: 0.259688
# MAPE: 0.143885
# RMSE: 6.20674
#
# Iter: 29
# Tolerance: 0.278582
# MAPE: 0.135575
# RMSE: 5.82848
#
# Iter: 30
# Tolerance: 0.280281
# MAPE: 0.140134
# RMSE: 6.11704
#
# Iter: 31
# Tolerance: 0.294941
# MAPE: 0.138953
# RMSE: 6.0124
#
# Iter: 32
# Tolerance: 0.297179
# MAPE: 0.141715
# RMSE: 6.03283
#
# Iter: 33
# Tolerance: 0.301458
# MAPE: 0.146566
# RMSE: 6.13293
#
# Iter: 34
# Tolerance: 0.295554
# MAPE: 0.14899
# RMSE: 6.21962
#
# Iter: 35
# Tolerance: 0.299498
# MAPE: 0.149744
# RMSE: 6.21297
#
# Iter: 36
# Tolerance: 0.29911
# MAPE: 0.14796
# RMSE: 6.17579
#
# Iter: 37
# Tolerance: 0.27494
# MAPE: 0.142017
# RMSE: 5.85362
#
# Iter: 38
# Tolerance: 0.275377
# MAPE: 0.147866
# RMSE: 6.23332
#
# Iter: 39
# Tolerance: 0.274975
# MAPE: 0.130945
# RMSE: 5.47748
#
# Iter: 40
# Tolerance: 0.270512
# MAPE: 0.138049
# RMSE: 5.83885
#
# Iter: 41
# Tolerance: 0.266935
# MAPE: 0.133328
# RMSE: 5.65823
#
# Iter: 42
# Tolerance: 0.259686
# MAPE: 0.135329
# RMSE: 5.71752
#
# Iter: 43
# Tolerance: 0.257497
# MAPE: 0.133392
# RMSE: 5.64209
#
# Iter: 44
# Tolerance: 0.249151
# MAPE: 0.133417
# RMSE: 5.60067
#
# Iter: 45
# Tolerance: 0.242218
# MAPE: 0.131602
# RMSE: 5.50819
#
# Iter: 46
# Tolerance: 0.233182
# MAPE: 0.131874
# RMSE: 5.50465
#
# Iter: 47
# Tolerance: 0.222713
# MAPE: 0.127721
# RMSE: 5.31845
#
# Iter: 48
# Tolerance: 0.214222
# MAPE: 0.127288
# RMSE: 5.26418
#
# Iter: 49
# Tolerance: 0.202509
# MAPE: 0.124245
# RMSE: 5.14929
#
# Iter: 50
# Tolerance: 0.195319
# MAPE: 0.125042
# RMSE: 5.17134
#
# Iter: 51
# Tolerance: 0.182944
# MAPE: 0.122003
# RMSE: 5.05138
#
# Iter: 52
# Tolerance: 0.174119
# MAPE: 0.120706
# RMSE: 4.98948
#
# Iter: 53
# Tolerance: 0.163948
# MAPE: 0.118094
# RMSE: 4.91292
#
# Iter: 54
# Tolerance: 0.154733
# MAPE: 0.116286
# RMSE: 4.84282
#
# Iter: 55
# Tolerance: 0.144838
# MAPE: 0.115136
# RMSE: 4.81378
#
# Iter: 56
# Tolerance: 0.137273
# MAPE: 0.113951
# RMSE: 4.775
#
# Iter: 57
# Tolerance: 0.130966
# MAPE: 0.112139
# RMSE: 4.71507
#
# Iter: 58
# Tolerance: 0.123716
# MAPE: 0.110552
# RMSE: 4.66571
#
# Iter: 59
# Tolerance: 0.11578
# MAPE: 0.109305
# RMSE: 4.61765
#
# Iter: 60
# Tolerance: 0.111039
# MAPE: 0.108954
# RMSE: 4.60638
#
# Iter: 61
# Tolerance: 0.104099
# MAPE: 0.107801
# RMSE: 4.55045
#
# Iter: 62
# Tolerance: 0.0996528
# MAPE: 0.107446
# RMSE: 4.52746
#
# Iter: 63
# Tolerance: 0.094805
# MAPE: 0.106299
# RMSE: 4.47551
#
# Iter: 64
# Tolerance: 0.0903317
# MAPE: 0.106037
# RMSE: 4.45789
#
# Iter: 65
# Tolerance: 0.0859714
# MAPE: 0.105258
# RMSE: 4.42377
#
# Iter: 66
# Tolerance: 0.0805776
# MAPE: 0.104595
# RMSE: 4.40088
#
# Iter: 67
# Tolerance: 0.0769124
# MAPE: 0.103982
# RMSE: 4.37394
#
# Iter: 68
# Tolerance: 0.0738813
# MAPE: 0.104051
# RMSE: 4.37694
#
# Iter: 69
# Tolerance: 0.0697398
# MAPE: 0.103686
# RMSE: 4.35972
#
# Iter: 70
# Tolerance: 0.0664202
# MAPE: 0.10331
# RMSE: 4.34851
#
# Iter: 71
# Tolerance: 0.0626772
# MAPE: 0.103006
# RMSE: 4.33567
#
# Iter: 72
# Tolerance: 0.059573
# MAPE: 0.102683
# RMSE: 4.32798
#
# Iter: 73
# Tolerance: 0.0559774
# MAPE: 0.102974
# RMSE: 4.33701
#
# Iter: 74
# Tolerance: 0.0546383
# MAPE: 0.102542
# RMSE: 4.32153
#
# Iter: 75
# Tolerance: 0.0512821
# MAPE: 0.102665
# RMSE: 4.32487
#
# Iter: 76
# Tolerance: 0.0499541
# MAPE: 0.102377
# RMSE: 4.3162
#
# Iter: 77
# Tolerance: 0.0451007
# MAPE: 0.102314
# RMSE: 4.31497
#
# Iter: 78
# Tolerance: 0.0442265
# MAPE: 0.102032
# RMSE: 4.3056
#
# Iter: 79
# Tolerance: 0.0416516
# MAPE: 0.102073
# RMSE: 4.30793
#
# Iter: 80
# Tolerance: 0.039704
# MAPE: 0.101931
# RMSE: 4.30311
#
# Iter: 81
# Tolerance: 0.0377921
# MAPE: 0.101968
# RMSE: 4.30566
#
# Iter: 82
# Tolerance: 0.036118
# MAPE: 0.101821
# RMSE: 4.29969
#
# Iter: 83
# Tolerance: 0.0345845
# MAPE: 0.101879
# RMSE: 4.303
#
# Iter: 84
# Tolerance: 0.0329333
# MAPE: 0.101838
# RMSE: 4.30099
#
# Iter: 85
# Tolerance: 0.0311737
# MAPE: 0.101853
# RMSE: 4.303
#
# Iter: 86
# Tolerance: 0.0292848
# MAPE: 0.101807
# RMSE: 4.30095
#
# Iter: 87
# Tolerance: 0.0279031
# MAPE: 0.101816
# RMSE: 4.30226
#
# Iter: 88
# Tolerance: 0.0263134
# MAPE: 0.101786
# RMSE: 4.30133
#
# Iter: 89
# Tolerance: 0.0248131
# MAPE: 0.101767
# RMSE: 4.30162
#
# Iter: 90
# Tolerance: 0.0232041
# MAPE: 0.101735
# RMSE: 4.30117
#
# Iter: 91
# Tolerance: 0.0215981
# MAPE: 0.101702
# RMSE: 4.30078
#
# Iter: 92
# Tolerance: 0.0201503
# MAPE: 0.101673
# RMSE: 4.30063
#
# Iter: 93
# Tolerance: 0.0186703
# MAPE: 0.101639
# RMSE: 4.30022
#
# Iter: 94
# Tolerance: 0.0172722
# MAPE: 0.101605
# RMSE: 4.30008
#
# Iter: 95
# Tolerance: 0.0159374
# MAPE: 0.10158
# RMSE: 4.30001
#
# Iter: 96
# Tolerance: 0.0146508
# MAPE: 0.101546
# RMSE: 4.29988
#
# Iter: 97
# Tolerance: 0.0134758
# MAPE: 0.101532
# RMSE: 4.30022
#
# Iter: 98
# Tolerance: 0.0123388
# MAPE: 0.101504
# RMSE: 4.30022
#
# Iter: 99
# Tolerance: 0.0113518
# MAPE: 0.101499
# RMSE: 4.30086
#
# Iter: 100
# Tolerance: 0.0104249
# MAPE: 0.101477
# RMSE: 4.30102
#
# Total iteration: 100
# Tolerance: 0.0104249
# Imputation MAPE: 0.101477
# Imputation RMSE: 4.30102
#
# Running time: 0.51 minutes

# %%
import numpy as np
np.random.seed(1000)

missing_rate = 0.3

dense_mat = np.load('../datasets/London-data-set/hourly_speed_mat.npy')
binary_mat = dense_mat.copy()
binary_mat[binary_mat != 0] = 1
pos = np.where(np.sum(binary_mat, axis = 1) > 0.7 * binary_mat.shape[1])
dense_mat = dense_mat[pos[0], :]
dim1, dim2 = dense_mat.shape
del binary_mat

## Random missing (RM)
sparse_mat = dense_mat * np.round(np.random.rand(dim1, dim2) + 0.5 - missing_rate)
dense_tensor = dense_mat.reshape([dim1, 30, 24]).transpose(0, 2, 1)
sparse_tensor = sparse_mat.reshape([dim1, 30, 24]).transpose(0, 2, 1)
del dense_mat, sparse_mat

# %%
import time
start = time.time()
alpha = np.ones(3) / 3
rho = 1e-5
theta = 0.05
epsilon = 1e-3
maxiter = 100
tensor_hat = LRTC(dense_tensor, sparse_tensor, alpha, rho, theta, epsilon, maxiter)
end = time.time()
print('Running time: %.2f minutes' % ((end - start)/60.0))
# Out:
# Iter: 1
# Tolerance: 0.594796
# MAPE: 0.376063
# RMSE: 9.93682
#
# Iter: 2
# Tolerance: 0.540654
# MAPE: 0.172872
# RMSE: 3.8003
#
# Iter: 3
# Tolerance: 0.211804
# MAPE: 0.2424
# RMSE: 5.17444
#
# Iter: 4
# Tolerance: 0.115913
# MAPE: 0.19401
# RMSE: 4.47153
#
# Iter: 5
# Tolerance: 0.223191
# MAPE: 0.166439
# RMSE: 4.20404
#
# Iter: 6
# Tolerance: 0.186403
# MAPE: 0.122799
# RMSE: 3.04614
#
# Iter: 7
# Tolerance: 0.122955
# MAPE: 0.134474
# RMSE: 3.18168
#
# Iter: 8
# Tolerance: 0.189031
# MAPE: 0.118989
# RMSE: 2.96094
#
# Iter: 9
# Tolerance: 0.153591
# MAPE: 0.126882
# RMSE: 3.13082
#
# Iter: 10
# Tolerance: 0.13652
# MAPE: 0.118765
# RMSE: 3.03668
#
# Iter: 11
# Tolerance: 0.172052
# MAPE: 0.124037
# RMSE: 3.11938
#
# Iter: 12
# Tolerance: 0.155647
# MAPE: 0.130492
# RMSE: 3.15162
#
# Iter: 13
# Tolerance: 0.159646
# MAPE: 0.123041
# RMSE: 3.03678
#
# Iter: 14
# Tolerance: 0.163752
# MAPE: 0.118314
# RMSE: 2.93933
#
# Iter: 15
# Tolerance: 0.146654
# MAPE: 0.11701
# RMSE: 2.88581
#
# Iter: 16
# Tolerance: 0.13477
# MAPE: 0.115592
# RMSE: 2.80077
#
# Iter: 17
# Tolerance: 0.11093
# MAPE: 0.107163
# RMSE: 2.60861
#
# Iter: 18
# Tolerance: 0.128716
# MAPE: 0.117361
# RMSE: 2.85439
#
# Iter: 19
# Tolerance: 0.127726
# MAPE: 0.113531
# RMSE: 2.77043
#
# Iter: 20
# Tolerance: 0.127434
# MAPE: 0.109287
# RMSE: 2.67163
#
# Iter: 21
# Tolerance: 0.124904
# MAPE: 0.111436
# RMSE: 2.73953
#
# Iter: 22
# Tolerance: 0.121983
# MAPE: 0.110793
# RMSE: 2.72589
#
# Iter: 23
# Tolerance: 0.125327
# MAPE: 0.111492
# RMSE: 2.7382
#
# Iter: 24
# Tolerance: 0.129057
# MAPE: 0.111473
# RMSE: 2.70828
#
# Iter: 25
# Tolerance: 0.125929
# MAPE: 0.108627
# RMSE: 2.6817
#
# Iter: 26
# Tolerance: 0.13104
# MAPE: 0.113073
# RMSE: 2.7768
#
# Iter: 27
# Tolerance: 0.126381
# MAPE: 0.105965
# RMSE: 2.62473
#
# Iter: 28
# Tolerance: 0.132993
# MAPE: 0.111995
# RMSE: 2.75376
#
# Iter: 29
# Tolerance: 0.136157
# MAPE: 0.11054
# RMSE: 2.74077
#
# Iter: 30
# Tolerance: 0.138419
# MAPE: 0.113081
# RMSE: 2.77686
#
# Iter: 31
# Tolerance: 0.137954
# MAPE: 0.112696
# RMSE: 2.76524
#
# Iter: 32
# Tolerance: 0.14717
# MAPE: 0.118592
# RMSE: 2.89892
#
# Iter: 33
# Tolerance: 0.154788
# MAPE: 0.118737
# RMSE: 2.89949
#
# Iter: 34
# Tolerance: 0.1548
# MAPE: 0.121528
# RMSE: 2.95359
#
# Iter: 35
# Tolerance: 0.165863
# MAPE: 0.12749
# RMSE: 3.08945
#
# Iter: 36
# Tolerance: 0.175068
# MAPE: 0.129991
# RMSE: 3.12723
#
# Iter: 37
# Tolerance: 0.175269
# MAPE: 0.130213
# RMSE: 3.11846
#
# Iter: 38
# Tolerance: 0.17584
# MAPE: 0.134234
# RMSE: 3.18987
#
# Iter: 39
# Tolerance: 0.174916
# MAPE: 0.131485
# RMSE: 3.1121
#
# Iter: 40
# Tolerance: 0.172783
# MAPE: 0.131742
# RMSE: 3.11045
#
# Iter: 41
# Tolerance: 0.165512
# MAPE: 0.127519
# RMSE: 3.00327
#
# Iter: 42
# Tolerance: 0.16073
# MAPE: 0.127747
# RMSE: 3.0056
#
# Iter: 43
# Tolerance: 0.156319
# MAPE: 0.123986
# RMSE: 2.91261
#
# Iter: 44
# Tolerance: 0.146852
# MAPE: 0.120095
# RMSE: 2.82565
#
# Iter: 45
# Tolerance: 0.142114
# MAPE: 0.119211
# RMSE: 2.80004
#
# Iter: 46
# Tolerance: 0.137757
# MAPE: 0.117043
# RMSE: 2.75177
#
# Iter: 47
# Tolerance: 0.136929
# MAPE: 0.116843
# RMSE: 2.7418
#
# Iter: 48
# Tolerance: 0.133794
# MAPE: 0.114439
# RMSE: 2.68994
#
# Iter: 49
# Tolerance: 0.129699
# MAPE: 0.113296
# RMSE: 2.66403
#
# Iter: 50
# Tolerance: 0.126668
# MAPE: 0.112268
# RMSE: 2.63895
#
# Iter: 51
# Tolerance: 0.122766
# MAPE: 0.110592
# RMSE: 2.59921
#
# Iter: 52
# Tolerance: 0.117908
# MAPE: 0.108155
# RMSE: 2.54812
#
# Iter: 53
# Tolerance: 0.111177
# MAPE: 0.106262
# RMSE: 2.50094
#
# Iter: 54
# Tolerance: 0.107623
# MAPE: 0.105264
# RMSE: 2.48218
#
# Iter: 55
# Tolerance: 0.105545
# MAPE: 0.103615
# RMSE: 2.44614
#
# Iter: 56
# Tolerance: 0.102324
# MAPE: 0.102671
# RMSE: 2.42281
#
# Iter: 57
# Tolerance: 0.101972
# MAPE: 0.102466
# RMSE: 2.41501
#
# Iter: 58
# Tolerance: 0.100634
# MAPE: 0.101427
# RMSE: 2.39052
#
# Iter: 59
# Tolerance: 0.0981091
# MAPE: 0.10066
# RMSE: 2.37341
#
# Iter: 60
# Tolerance: 0.0967157
# MAPE: 0.099788
# RMSE: 2.35321
#
# Iter: 61
# Tolerance: 0.0936625
# MAPE: 0.0987996
# RMSE: 2.33161
#
# Iter: 62
# Tolerance: 0.0914864
# MAPE: 0.0978058
# RMSE: 2.31045
#
# Iter: 63
# Tolerance: 0.0888939
# MAPE: 0.0966765
# RMSE: 2.28729
#
# Iter: 64
# Tolerance: 0.0857462
# MAPE: 0.0957764
# RMSE: 2.26571
#
# Iter: 65
# Tolerance: 0.0834103
# MAPE: 0.0948581
# RMSE: 2.24799
#
# Iter: 66
# Tolerance: 0.081228
# MAPE: 0.0940573
# RMSE: 2.22997
#
# Iter: 67
# Tolerance: 0.0791968
# MAPE: 0.0934376
# RMSE: 2.21817
#
# Iter: 68
# Tolerance: 0.0772549
# MAPE: 0.0929187
# RMSE: 2.20602
#
# Iter: 69
# Tolerance: 0.0756045
# MAPE: 0.0923449
# RMSE: 2.19481
#
# Iter: 70
# Tolerance: 0.0735952
# MAPE: 0.0918591
# RMSE: 2.1838
#
# Iter: 71
# Tolerance: 0.0714322
# MAPE: 0.09129
# RMSE: 2.17325
#
# Iter: 72
# Tolerance: 0.0695084
# MAPE: 0.0908805
# RMSE: 2.16492
#
# Iter: 73
# Tolerance: 0.0673667
# MAPE: 0.090475
# RMSE: 2.15659
#
# Iter: 74
# Tolerance: 0.0655925
# MAPE: 0.0901375
# RMSE: 2.14923
#
# Iter: 75
# Tolerance: 0.0642138
# MAPE: 0.0898904
# RMSE: 2.14443
#
# Iter: 76
# Tolerance: 0.0626951
# MAPE: 0.0896179
# RMSE: 2.13913
#
# Iter: 77
# Tolerance: 0.060907
# MAPE: 0.089321
# RMSE: 2.13318
#
# Iter: 78
# Tolerance: 0.0586746
# MAPE: 0.089124
# RMSE: 2.12925
#
# Iter: 79
# Tolerance: 0.0574774
# MAPE: 0.0889643
# RMSE: 2.12536
#
# Iter: 80
# Tolerance: 0.0561905
# MAPE: 0.0888123
# RMSE: 2.12306
#
# Iter: 81
# Tolerance: 0.0544498
# MAPE: 0.0886657
# RMSE: 2.1195
#
# Iter: 82
# Tolerance: 0.0531219
# MAPE: 0.0885685
# RMSE: 2.11811
#
# Iter: 83
# Tolerance: 0.0517005
# MAPE: 0.088415
# RMSE: 2.11449
#
# Iter: 84
# Tolerance: 0.0503635
# MAPE: 0.0883602
# RMSE: 2.11347
#
# Iter: 85
# Tolerance: 0.0491134
# MAPE: 0.0882531
# RMSE: 2.11129
#
# Iter: 86
# Tolerance: 0.0475749
# MAPE: 0.0881955
# RMSE: 2.11003
#
# Iter: 87
# Tolerance: 0.0462962
# MAPE: 0.088125
# RMSE: 2.10839
#
# Iter: 88
# Tolerance: 0.0452329
# MAPE: 0.0880866
# RMSE: 2.10724
#
# Iter: 89
# Tolerance: 0.0437336
# MAPE: 0.0880217
# RMSE: 2.10551
#
# Iter: 90
# Tolerance: 0.0423862
# MAPE: 0.0880042
# RMSE: 2.10437
#
# Iter: 91
# Tolerance: 0.0412725
# MAPE: 0.0879588
# RMSE: 2.10302
#
# Iter: 92
# Tolerance: 0.0398421
# MAPE: 0.0879543
# RMSE: 2.102
#
# Iter: 93
# Tolerance: 0.0382026
# MAPE: 0.087928
# RMSE: 2.10093
#
# Iter: 94
# Tolerance: 0.0365566
# MAPE: 0.0879664
# RMSE: 2.10087
#
# Iter: 95
# Tolerance: 0.0347926
# MAPE: 0.0879994
# RMSE: 2.10128
#
# Iter: 96
# Tolerance: 0.0327565
# MAPE: 0.0880973
# RMSE: 2.10277
#
# Iter: 97
# Tolerance: 0.0306931
# MAPE: 0.0882119
# RMSE: 2.10517
#
# Iter: 98
# Tolerance: 0.028506
# MAPE: 0.0883648
# RMSE: 2.10837
#
# Iter: 99
# Tolerance: 0.0263512
# MAPE: 0.0885363
# RMSE: 2.11227
#
# Iter: 100
# Tolerance: 0.0242999
# MAPE: 0.0887372
# RMSE: 2.11676
#
# Total iteration: 100
# Tolerance: 0.0242999
# Imputation MAPE: 0.0887372
# Imputation RMSE: 2.11676
#
# Running time: 9.14 minutes

# %%
import numpy as np
np.random.seed(1000)

missing_rate = 0.7

dense_mat = np.load('../datasets/London-data-set/hourly_speed_mat.npy')
binary_mat = dense_mat.copy()
binary_mat[binary_mat != 0] = 1
pos = np.where(np.sum(binary_mat, axis = 1) > 0.7 * binary_mat.shape[1])
dense_mat = dense_mat[pos[0], :]
dim1, dim2 = dense_mat.shape
del binary_mat

## Random missing (RM)
sparse_mat = dense_mat * np.round(np.random.rand(dim1, dim2) + 0.5 - missing_rate)
dense_tensor = dense_mat.reshape([dim1, 30, 24]).transpose(0, 2, 1)
sparse_tensor = sparse_mat.reshape([dim1, 30, 24]).transpose(0, 2, 1)
del dense_mat, sparse_mat

# %%
import time
start = time.time()
alpha = np.ones(3) / 3
rho = 1e-5
theta = 0.05
epsilon = 1e-3
maxiter = 100
tensor_hat = LRTC(dense_tensor, sparse_tensor, alpha, rho, theta, epsilon, maxiter)
end = time.time()
print('Running time: %.2f minutes' % ((end - start)/60.0))
# Out:
# Iter: 1
# Tolerance: 0.83619
# MAPE: 0.723064
# RMSE: 18.0079
#
# Iter: 2
# Tolerance: 0.706661
# MAPE: 0.36246
# RMSE: 9.59087
#
# Iter: 3
# Tolerance: 0.664945
# MAPE: 0.172871
# RMSE: 4.04806
#
# Iter: 4
# Tolerance: 0.481564
# MAPE: 0.309997
# RMSE: 6.6263
#
# Iter: 5
# Tolerance: 0.259395
# MAPE: 0.41343
# RMSE: 8.79255
#
# Iter: 6
# Tolerance: 0.137026
# MAPE: 0.399503
# RMSE: 8.60932
#
# Iter: 7
# Tolerance: 0.190635
# MAPE: 0.307362
# RMSE: 6.95946
#
# Iter: 8
# Tolerance: 0.262789
# MAPE: 0.196155
# RMSE: 4.99706
#
# Iter: 9
# Tolerance: 0.245024
# MAPE: 0.166012
# RMSE: 4.25843
#
# Iter: 10
# Tolerance: 0.208759
# MAPE: 0.165443
# RMSE: 4.15261
#
# Iter: 11
# Tolerance: 0.174727
# MAPE: 0.16892
# RMSE: 4.21834
#
# Iter: 12
# Tolerance: 0.151707
# MAPE: 0.1504
# RMSE: 3.79153
#
# Iter: 13
# Tolerance: 0.182851
# MAPE: 0.132283
# RMSE: 3.34923
#
# Iter: 14
# Tolerance: 0.165312
# MAPE: 0.121576
# RMSE: 3.06316
#
# Iter: 15
# Tolerance: 0.152098
# MAPE: 0.130689
# RMSE: 3.23769
#
# Iter: 16
# Tolerance: 0.148996
# MAPE: 0.130396
# RMSE: 3.1909
#
# Iter: 17
# Tolerance: 0.168163
# MAPE: 0.130411
# RMSE: 3.12465
#
# Iter: 18
# Tolerance: 0.154857
# MAPE: 0.125053
# RMSE: 2.98738
#
# Iter: 19
# Tolerance: 0.154037
# MAPE: 0.125654
# RMSE: 3.05151
#
# Iter: 20
# Tolerance: 0.126846
# MAPE: 0.116846
# RMSE: 2.82721
#
# Iter: 21
# Tolerance: 0.12189
# MAPE: 0.116619
# RMSE: 2.82588
#
# Iter: 22
# Tolerance: 0.118873
# MAPE: 0.112445
# RMSE: 2.72525
#
# Iter: 23
# Tolerance: 0.127665
# MAPE: 0.113356
# RMSE: 2.76113
#
# Iter: 24
# Tolerance: 0.108222
# MAPE: 0.111714
# RMSE: 2.72863
#
# Iter: 25
# Tolerance: 0.124695
# MAPE: 0.111426
# RMSE: 2.68363
#
# Iter: 26
# Tolerance: 0.098367
# MAPE: 0.108513
# RMSE: 2.62459
#
# Iter: 27
# Tolerance: 0.111427
# MAPE: 0.109684
# RMSE: 2.64562
#
# Iter: 28
# Tolerance: 0.101547
# MAPE: 0.105139
# RMSE: 2.54085
#
# Iter: 29
# Tolerance: 0.104347
# MAPE: 0.106364
# RMSE: 2.59805
#
# Iter: 30
# Tolerance: 0.0871797
# MAPE: 0.103899
# RMSE: 2.52708
#
# Iter: 31
# Tolerance: 0.102177
# MAPE: 0.104519
# RMSE: 2.54179
#
# Iter: 32
# Tolerance: 0.107235
# MAPE: 0.104603
# RMSE: 2.54843
#
# Iter: 33
# Tolerance: 0.102289
# MAPE: 0.103129
# RMSE: 2.49873
#
# Iter: 34
# Tolerance: 0.10765
# MAPE: 0.103962
# RMSE: 2.5306
#
# Iter: 35
# Tolerance: 0.11441
# MAPE: 0.104167
# RMSE: 2.54041
#
# Iter: 36
# Tolerance: 0.111591
# MAPE: 0.104372
# RMSE: 2.55004
#
# Iter: 37
# Tolerance: 0.114237
# MAPE: 0.104012
# RMSE: 2.54298
#
# Iter: 38
# Tolerance: 0.128663
# MAPE: 0.106744
# RMSE: 2.6243
#
# Iter: 39
# Tolerance: 0.128339
# MAPE: 0.105764
# RMSE: 2.58895
#
# Iter: 40
# Tolerance: 0.131776
# MAPE: 0.1076
# RMSE: 2.63398
#
# Iter: 41
# Tolerance: 0.145888
# MAPE: 0.110469
# RMSE: 2.701
#
# Iter: 42
# Tolerance: 0.146042
# MAPE: 0.110797
# RMSE: 2.70137
#
# Iter: 43
# Tolerance: 0.146594
# MAPE: 0.111376
# RMSE: 2.70346
#
# Iter: 44
# Tolerance: 0.151775
# MAPE: 0.112769
# RMSE: 2.72837
#
# Iter: 45
# Tolerance: 0.146585
# MAPE: 0.111656
# RMSE: 2.68571
#
# Iter: 46
# Tolerance: 0.150978
# MAPE: 0.113515
# RMSE: 2.72202
#
# Iter: 47
# Tolerance: 0.144716
# MAPE: 0.111716
# RMSE: 2.67055
#
# Iter: 48
# Tolerance: 0.149854
# MAPE: 0.113412
# RMSE: 2.70052
#
# Iter: 49
# Tolerance: 0.137974
# MAPE: 0.11034
# RMSE: 2.62708
#
# Iter: 50
# Tolerance: 0.143146
# MAPE: 0.112256
# RMSE: 2.66496
#
# Iter: 51
# Tolerance: 0.13099
# MAPE: 0.108858
# RMSE: 2.58899
#
# Iter: 52
# Tolerance: 0.139572
# MAPE: 0.111077
# RMSE: 2.63564
#
# Iter: 53
# Tolerance: 0.122391
# MAPE: 0.106744
# RMSE: 2.53855
#
# Iter: 54
# Tolerance: 0.132764
# MAPE: 0.109269
# RMSE: 2.59236
#
# Iter: 55
# Tolerance: 0.116957
# MAPE: 0.105474
# RMSE: 2.51051
#
# Iter: 56
# Tolerance: 0.125601
# MAPE: 0.107067
# RMSE: 2.54239
#
# Iter: 57
# Tolerance: 0.109551
# MAPE: 0.103759
# RMSE: 2.47105
#
# Iter: 58
# Tolerance: 0.120007
# MAPE: 0.105455
# RMSE: 2.50739
#
# Iter: 59
# Tolerance: 0.102094
# MAPE: 0.102214
# RMSE: 2.43789
#
# Iter: 60
# Tolerance: 0.116318
# MAPE: 0.104171
# RMSE: 2.47914
#
# Iter: 61
# Tolerance: 0.091675
# MAPE: 0.10037
# RMSE: 2.39799
#
# Iter: 62
# Tolerance: 0.115822
# MAPE: 0.103173
# RMSE: 2.45643
#
# Iter: 63
# Tolerance: 0.0845166
# MAPE: 0.0990007
# RMSE: 2.37004
#
# Iter: 64
# Tolerance: 0.113158
# MAPE: 0.101736
# RMSE: 2.42553
#
# Iter: 65
# Tolerance: 0.0813654
# MAPE: 0.098108
# RMSE: 2.35181
#
# Iter: 66
# Tolerance: 0.105619
# MAPE: 0.100116
# RMSE: 2.39119
#
# Iter: 67
# Tolerance: 0.0786866
# MAPE: 0.0974773
# RMSE: 2.33826
#
# Iter: 68
# Tolerance: 0.0968049
# MAPE: 0.0988283
# RMSE: 2.36398
#
# Iter: 69
# Tolerance: 0.0761965
# MAPE: 0.0970216
# RMSE: 2.32821
#
# Iter: 70
# Tolerance: 0.0892328
# MAPE: 0.0977853
# RMSE: 2.34226
#
# Iter: 71
# Tolerance: 0.0717751
# MAPE: 0.0964597
# RMSE: 2.31653
#
# Iter: 72
# Tolerance: 0.0851805
# MAPE: 0.0970342
# RMSE: 2.32718
#
# Iter: 73
# Tolerance: 0.0686509
# MAPE: 0.0959766
# RMSE: 2.30665
#
# Iter: 74
# Tolerance: 0.0791427
# MAPE: 0.0963315
# RMSE: 2.31267
#
# Iter: 75
# Tolerance: 0.0658065
# MAPE: 0.095649
# RMSE: 2.29995
#
# Iter: 76
# Tolerance: 0.072063
# MAPE: 0.0957301
# RMSE: 2.30078
#
# Iter: 77
# Tolerance: 0.0621855
# MAPE: 0.0953745
# RMSE: 2.29509
#
# Iter: 78
# Tolerance: 0.0650843
# MAPE: 0.0953118
# RMSE: 2.29268
#
# Iter: 79
# Tolerance: 0.0583273
# MAPE: 0.0951896
# RMSE: 2.29171
#
# Iter: 80
# Tolerance: 0.0586472
# MAPE: 0.0950198
# RMSE: 2.28754
#
# Iter: 81
# Tolerance: 0.0547105
# MAPE: 0.0950676
# RMSE: 2.28948
#
# Iter: 82
# Tolerance: 0.0537011
# MAPE: 0.094878
# RMSE: 2.28504
#
# Iter: 83
# Tolerance: 0.0513345
# MAPE: 0.0949966
# RMSE: 2.2885
#
# Iter: 84
# Tolerance: 0.0497384
# MAPE: 0.0948083
# RMSE: 2.28431
#
# Iter: 85
# Tolerance: 0.0479403
# MAPE: 0.0949303
# RMSE: 2.28743
#
# Iter: 86
# Tolerance: 0.0465638
# MAPE: 0.0948288
# RMSE: 2.28519
#
# Iter: 87
# Tolerance: 0.0451713
# MAPE: 0.0949397
# RMSE: 2.28806
#
# Iter: 88
# Tolerance: 0.043668
# MAPE: 0.0949213
# RMSE: 2.28753
#
# Iter: 89
# Tolerance: 0.0428219
# MAPE: 0.095013
# RMSE: 2.28985
#
# Iter: 90
# Tolerance: 0.0416747
# MAPE: 0.0950305
# RMSE: 2.29037
#
# Iter: 91
# Tolerance: 0.0408462
# MAPE: 0.0951418
# RMSE: 2.2929
#
# Iter: 92
# Tolerance: 0.0400743
# MAPE: 0.0951965
# RMSE: 2.29415
#
# Iter: 93
# Tolerance: 0.0393975
# MAPE: 0.0953144
# RMSE: 2.29693
#
# Iter: 94
# Tolerance: 0.0386503
# MAPE: 0.0954015
# RMSE: 2.2989
#
# Iter: 95
# Tolerance: 0.0379718
# MAPE: 0.0955429
# RMSE: 2.30209
#
# Iter: 96
# Tolerance: 0.0372451
# MAPE: 0.095656
# RMSE: 2.30457
#
# Iter: 97
# Tolerance: 0.0363966
# MAPE: 0.0958207
# RMSE: 2.30826
#
# Iter: 98
# Tolerance: 0.0355063
# MAPE: 0.0959588
# RMSE: 2.31136
#
# Iter: 99
# Tolerance: 0.0345502
# MAPE: 0.0961377
# RMSE: 2.31531
#
# Iter: 100
# Tolerance: 0.0335123
# MAPE: 0.096303
# RMSE: 2.31896
#
# Total iteration: 100
# Tolerance: 0.0335123
# Imputation MAPE: 0.096303
# Imputation RMSE: 2.31896
#
# Running time: 9.88 minutes

# %%
import numpy as np
np.random.seed(1000)

missing_rate = 0.3

dense_mat = np.load('../datasets/London-data-set/hourly_speed_mat.npy')
binary_mat = dense_mat.copy()
binary_mat[binary_mat != 0] = 1
pos = np.where(np.sum(binary_mat, axis = 1) > 0.7 * binary_mat.shape[1])
dense_mat = dense_mat[pos[0], :]
dim1, dim2 = dense_mat.shape
del binary_mat

## Non-random missing (NM)
dense_tensor = dense_mat.reshape([dim1, 30, 24]).transpose(0, 2, 1)
sparse_tensor = dense_tensor * np.round(np.random.rand(dim1, 30) + 0.5 - missing_rate)[:, None, :]
del dense_mat

# %%
import time
start = time.time()
alpha = np.ones(3) / 3
rho = 1e-5
theta = 0.05
epsilon = 1e-3
maxiter = 100
tensor_hat = LRTC(dense_tensor, sparse_tensor, alpha, rho, theta, epsilon, maxiter)
end = time.time()
print('Running time: %.2f minutes' % ((end - start)/60.0))
# Out:
# Iter: 1
# Tolerance: 0.462486
# MAPE: 0.575285
# RMSE: 14.6067
#
# Iter: 2
# Tolerance: 0.431005
# MAPE: 0.183526
# RMSE: 4.7571
#
# Iter: 3
# Tolerance: 0.274165
# MAPE: 0.253887
# RMSE: 5.47007
#
# Iter: 4
# Tolerance: 0.159628
# MAPE: 0.335471
# RMSE: 7.22953
#
# Iter: 5
# Tolerance: 0.102257
# MAPE: 0.261863
# RMSE: 6.23517
#
# Iter: 6
# Tolerance: 0.190787
# MAPE: 0.176908
# RMSE: 4.2935
#
# Iter: 7
# Tolerance: 0.183531
# MAPE: 0.132081
# RMSE: 3.18496
#
# Iter: 8
# Tolerance: 0.144973
# MAPE: 0.12345
# RMSE: 3.08101
#
# Iter: 9
# Tolerance: 0.150581
# MAPE: 0.129057
# RMSE: 3.18794
#
# Iter: 10
# Tolerance: 0.149484
# MAPE: 0.13117
# RMSE: 3.25158
#
# Iter: 11
# Tolerance: 0.185699
# MAPE: 0.123085
# RMSE: 3.06191
#
# Iter: 12
# Tolerance: 0.157056
# MAPE: 0.120778
# RMSE: 2.94206
#
# Iter: 13
# Tolerance: 0.152408
# MAPE: 0.126825
# RMSE: 3.14873
#
# Iter: 14
# Tolerance: 0.15411
# MAPE: 0.11625
# RMSE: 2.84266
#
# Iter: 15
# Tolerance: 0.136577
# MAPE: 0.121619
# RMSE: 3.01488
#
# Iter: 16
# Tolerance: 0.155688
# MAPE: 0.120687
# RMSE: 2.90498
#
# Iter: 17
# Tolerance: 0.112422
# MAPE: 0.114617
# RMSE: 2.79377
#
# Iter: 18
# Tolerance: 0.13099
# MAPE: 0.115969
# RMSE: 2.81484
#
# Iter: 19
# Tolerance: 0.125654
# MAPE: 0.116519
# RMSE: 2.82792
#
# Iter: 20
# Tolerance: 0.147428
# MAPE: 0.11285
# RMSE: 2.7993
#
# Iter: 21
# Tolerance: 0.136597
# MAPE: 0.115848
# RMSE: 2.84316
#
# Iter: 22
# Tolerance: 0.120627
# MAPE: 0.112397
# RMSE: 2.75147
#
# Iter: 23
# Tolerance: 0.136867
# MAPE: 0.114802
# RMSE: 2.83637
#
# Iter: 24
# Tolerance: 0.126227
# MAPE: 0.11192
# RMSE: 2.72586
#
# Iter: 25
# Tolerance: 0.119381
# MAPE: 0.111881
# RMSE: 2.75075
#
# Iter: 26
# Tolerance: 0.133274
# MAPE: 0.115631
# RMSE: 2.86532
#
# Iter: 27
# Tolerance: 0.134264
# MAPE: 0.113122
# RMSE: 2.75979
#
# Iter: 28
# Tolerance: 0.136111
# MAPE: 0.116007
# RMSE: 2.85157
#
# Iter: 29
# Tolerance: 0.14259
# MAPE: 0.116239
# RMSE: 2.85969
#
# Iter: 30
# Tolerance: 0.144521
# MAPE: 0.116932
# RMSE: 2.88758
#
# Iter: 31
# Tolerance: 0.141885
# MAPE: 0.119029
# RMSE: 2.90929
#
# Iter: 32
# Tolerance: 0.151484
# MAPE: 0.123331
# RMSE: 3.00402
#
# Iter: 33
# Tolerance: 0.157881
# MAPE: 0.124894
# RMSE: 3.03131
#
# Iter: 34
# Tolerance: 0.162593
# MAPE: 0.126543
# RMSE: 3.07983
#
# Iter: 35
# Tolerance: 0.170889
# MAPE: 0.130882
# RMSE: 3.17119
#
# Iter: 36
# Tolerance: 0.173042
# MAPE: 0.131668
# RMSE: 3.15816
#
# Iter: 37
# Tolerance: 0.179783
# MAPE: 0.135372
# RMSE: 3.22884
#
# Iter: 38
# Tolerance: 0.176921
# MAPE: 0.133025
# RMSE: 3.15692
#
# Iter: 39
# Tolerance: 0.17537
# MAPE: 0.135054
# RMSE: 3.19252
#
# Iter: 40
# Tolerance: 0.174723
# MAPE: 0.132518
# RMSE: 3.12441
#
# Iter: 41
# Tolerance: 0.167
# MAPE: 0.130947
# RMSE: 3.0805
#
# Iter: 42
# Tolerance: 0.163687
# MAPE: 0.12898
# RMSE: 3.02974
#
# Iter: 43
# Tolerance: 0.155435
# MAPE: 0.125977
# RMSE: 2.9553
#
# Iter: 44
# Tolerance: 0.149281
# MAPE: 0.124604
# RMSE: 2.92389
#
# Iter: 45
# Tolerance: 0.144291
# MAPE: 0.121785
# RMSE: 2.85825
#
# Iter: 46
# Tolerance: 0.139004
# MAPE: 0.120616
# RMSE: 2.83087
#
# Iter: 47
# Tolerance: 0.13848
# MAPE: 0.119993
# RMSE: 2.81542
#
# Iter: 48
# Tolerance: 0.134364
# MAPE: 0.118048
# RMSE: 2.77097
#
# Iter: 49
# Tolerance: 0.131333
# MAPE: 0.116591
# RMSE: 2.73797
#
# Iter: 50
# Tolerance: 0.126962
# MAPE: 0.115093
# RMSE: 2.70208
#
# Iter: 51
# Tolerance: 0.121262
# MAPE: 0.113373
# RMSE: 2.66867
#
# Iter: 52
# Tolerance: 0.116862
# MAPE: 0.111661
# RMSE: 2.62983
#
# Iter: 53
# Tolerance: 0.113162
# MAPE: 0.109831
# RMSE: 2.59088
#
# Iter: 54
# Tolerance: 0.10756
# MAPE: 0.108635
# RMSE: 2.55995
#
# Iter: 55
# Tolerance: 0.105023
# MAPE: 0.107495
# RMSE: 2.53667
#
# Iter: 56
# Tolerance: 0.104531
# MAPE: 0.107041
# RMSE: 2.52291
#
# Iter: 57
# Tolerance: 0.102603
# MAPE: 0.106422
# RMSE: 2.50838
#
# Iter: 58
# Tolerance: 0.100993
# MAPE: 0.105741
# RMSE: 2.49077
#
# Iter: 59
# Tolerance: 0.099125
# MAPE: 0.104815
# RMSE: 2.47219
#
# Iter: 60
# Tolerance: 0.0965331
# MAPE: 0.103933
# RMSE: 2.45234
#
# Iter: 61
# Tolerance: 0.0940931
# MAPE: 0.102928
# RMSE: 2.43033
#
# Iter: 62
# Tolerance: 0.0920347
# MAPE: 0.102051
# RMSE: 2.41337
#
# Iter: 63
# Tolerance: 0.0893788
# MAPE: 0.100898
# RMSE: 2.389
#
# Iter: 64
# Tolerance: 0.0861879
# MAPE: 0.100135
# RMSE: 2.37309
#
# Iter: 65
# Tolerance: 0.0831206
# MAPE: 0.0993937
# RMSE: 2.35807
#
# Iter: 66
# Tolerance: 0.0813243
# MAPE: 0.0987014
# RMSE: 2.34256
#
# Iter: 67
# Tolerance: 0.0801192
# MAPE: 0.0981108
# RMSE: 2.33107
#
# Iter: 68
# Tolerance: 0.0782336
# MAPE: 0.0977048
# RMSE: 2.32224
#
# Iter: 69
# Tolerance: 0.0759945
# MAPE: 0.0970886
# RMSE: 2.30963
#
# Iter: 70
# Tolerance: 0.0740227
# MAPE: 0.0967168
# RMSE: 2.30295
#
# Iter: 71
# Tolerance: 0.0720358
# MAPE: 0.0961342
# RMSE: 2.29169
#
# Iter: 72
# Tolerance: 0.0698744
# MAPE: 0.0958416
# RMSE: 2.28554
#
# Iter: 73
# Tolerance: 0.0680632
# MAPE: 0.0954437
# RMSE: 2.27763
#
# Iter: 74
# Tolerance: 0.0664574
# MAPE: 0.0951832
# RMSE: 2.27268
#
# Iter: 75
# Tolerance: 0.0646311
# MAPE: 0.0949037
# RMSE: 2.2671
#
# Iter: 76
# Tolerance: 0.0630687
# MAPE: 0.0946942
# RMSE: 2.26275
#
# Iter: 77
# Tolerance: 0.0614651
# MAPE: 0.0944322
# RMSE: 2.25822
#
# Iter: 78
# Tolerance: 0.0594634
# MAPE: 0.0942921
# RMSE: 2.25481
#
# Iter: 79
# Tolerance: 0.0580468
# MAPE: 0.0941252
# RMSE: 2.25141
#
# Iter: 80
# Tolerance: 0.0567812
# MAPE: 0.0940447
# RMSE: 2.24994
#
# Iter: 81
# Tolerance: 0.0553469
# MAPE: 0.0938807
# RMSE: 2.24685
#
# Iter: 82
# Tolerance: 0.0539058
# MAPE: 0.0938079
# RMSE: 2.24525
#
# Iter: 83
# Tolerance: 0.0525219
# MAPE: 0.0937122
# RMSE: 2.24354
#
# Iter: 84
# Tolerance: 0.051165
# MAPE: 0.0936603
# RMSE: 2.24214
#
# Iter: 85
# Tolerance: 0.0499203
# MAPE: 0.0936006
# RMSE: 2.24103
#
# Iter: 86
# Tolerance: 0.0485161
# MAPE: 0.0935648
# RMSE: 2.24001
#
# Iter: 87
# Tolerance: 0.047144
# MAPE: 0.0935404
# RMSE: 2.23933
#
# Iter: 88
# Tolerance: 0.0461065
# MAPE: 0.0935414
# RMSE: 2.23905
#
# Iter: 89
# Tolerance: 0.0448717
# MAPE: 0.0935315
# RMSE: 2.23852
#
# Iter: 90
# Tolerance: 0.0435737
# MAPE: 0.0935508
# RMSE: 2.23839
#
# Iter: 91
# Tolerance: 0.0424942
# MAPE: 0.0935516
# RMSE: 2.23802
#
# Iter: 92
# Tolerance: 0.0411824
# MAPE: 0.0935909
# RMSE: 2.23809
#
# Iter: 93
# Tolerance: 0.0397318
# MAPE: 0.0936236
# RMSE: 2.23826
#
# Iter: 94
# Tolerance: 0.0380464
# MAPE: 0.0936922
# RMSE: 2.23915
#
# Iter: 95
# Tolerance: 0.0361081
# MAPE: 0.0937878
# RMSE: 2.24081
#
# Iter: 96
# Tolerance: 0.0339702
# MAPE: 0.093919
# RMSE: 2.24348
#
# Iter: 97
# Tolerance: 0.0317744
# MAPE: 0.0940808
# RMSE: 2.24683
#
# Iter: 98
# Tolerance: 0.0295024
# MAPE: 0.0942515
# RMSE: 2.25077
#
# Iter: 99
# Tolerance: 0.0272723
# MAPE: 0.0944519
# RMSE: 2.25525
#
# Iter: 100
# Tolerance: 0.0251016
# MAPE: 0.0946469
# RMSE: 2.25999
#
# Total iteration: 100
# Tolerance: 0.0251016
# Imputation MAPE: 0.0946469
# Imputation RMSE: 2.25999
#
# Running time: 8.53 minutes

# %%
import numpy as np
np.random.seed(1000)

missing_rate = 0.7

dense_mat = np.load('../datasets/London-data-set/hourly_speed_mat.npy')
binary_mat = dense_mat.copy()
binary_mat[binary_mat != 0] = 1
pos = np.where(np.sum(binary_mat, axis = 1) > 0.7 * binary_mat.shape[1])
dense_mat = dense_mat[pos[0], :]
dim1, dim2 = dense_mat.shape
del binary_mat

## Non-random missing (NM)
dense_tensor = dense_mat.reshape([dim1, 30, 24]).transpose(0, 2, 1)
sparse_tensor = dense_tensor * np.round(np.random.rand(dim1, 30) + 0.5 - missing_rate)[:, None, :]
del dense_mat

# %%
import time
start = time.time()
alpha = np.ones(3) / 3
rho = 1e-5
theta = 0.05
epsilon = 1e-3
maxiter = 100
tensor_hat = LRTC(dense_tensor, sparse_tensor, alpha, rho, theta, epsilon, maxiter)
end = time.time()
print('Running time: %.2f minutes' % ((end - start)/60.0))
# Out:
# Iter: 1
# Tolerance: 0.61093
# MAPE: 0.815609
# RMSE: 20.0953
#
# Iter: 2
# Tolerance: 0.513516
# MAPE: 0.532671
# RMSE: 13.7514
#
# Iter: 3
# Tolerance: 0.541258
# MAPE: 0.277075
# RMSE: 7.67951
#
# Iter: 4
# Tolerance: 0.476985
# MAPE: 0.224449
# RMSE: 5.36902
#
# Iter: 5
# Tolerance: 0.386449
# MAPE: 0.326423
# RMSE: 7.25669
#
# Iter: 6
# Tolerance: 0.261234
# MAPE: 0.414577
# RMSE: 8.97826
#
# Iter: 7
# Tolerance: 0.194105
# MAPE: 0.418278
# RMSE: 9.32123
#
# Iter: 8
# Tolerance: 0.189291
# MAPE: 0.375928
# RMSE: 8.64799
#
# Iter: 9
# Tolerance: 0.230311
# MAPE: 0.304162
# RMSE: 7.44639
#
# Iter: 10
# Tolerance: 0.246236
# MAPE: 0.239882
# RMSE: 6.20592
#
# Iter: 11
# Tolerance: 0.21578
# MAPE: 0.201786
# RMSE: 5.2982
#
# Iter: 12
# Tolerance: 0.197809
# MAPE: 0.183872
# RMSE: 4.78763
#
# Iter: 13
# Tolerance: 0.181371
# MAPE: 0.170779
# RMSE: 4.40921
#
# Iter: 14
# Tolerance: 0.170338
# MAPE: 0.166571
# RMSE: 4.26474
#
# Iter: 15
# Tolerance: 0.201802
# MAPE: 0.161258
# RMSE: 4.13143
#
# Iter: 16
# Tolerance: 0.177015
# MAPE: 0.150231
# RMSE: 3.85023
#
# Iter: 17
# Tolerance: 0.158831
# MAPE: 0.149444
# RMSE: 3.80018
#
# Iter: 18
# Tolerance: 0.152453
# MAPE: 0.148991
# RMSE: 3.76157
#
# Iter: 19
# Tolerance: 0.160819
# MAPE: 0.145193
# RMSE: 3.58244
#
# Iter: 20
# Tolerance: 0.166818
# MAPE: 0.139919
# RMSE: 3.43121
#
# Iter: 21
# Tolerance: 0.154979
# MAPE: 0.132141
# RMSE: 3.25465
#
# Iter: 22
# Tolerance: 0.11856
# MAPE: 0.127767
# RMSE: 3.12476
#
# Iter: 23
# Tolerance: 0.114076
# MAPE: 0.127619
# RMSE: 3.11624
#
# Iter: 24
# Tolerance: 0.121967
# MAPE: 0.120898
# RMSE: 2.95347
#
# Iter: 25
# Tolerance: 0.116887
# MAPE: 0.117679
# RMSE: 2.85977
#
# Iter: 26
# Tolerance: 0.0943554
# MAPE: 0.114084
# RMSE: 2.78621
#
# Iter: 27
# Tolerance: 0.110115
# MAPE: 0.116402
# RMSE: 2.83834
#
# Iter: 28
# Tolerance: 0.109159
# MAPE: 0.113781
# RMSE: 2.78562
#
# Iter: 29
# Tolerance: 0.105462
# MAPE: 0.112262
# RMSE: 2.73868
#
# Iter: 30
# Tolerance: 0.109538
# MAPE: 0.111637
# RMSE: 2.74146
#
# Iter: 31
# Tolerance: 0.115467
# MAPE: 0.111312
# RMSE: 2.71454
#
# Iter: 32
# Tolerance: 0.113742
# MAPE: 0.111415
# RMSE: 2.74289
#
# Iter: 33
# Tolerance: 0.10829
# MAPE: 0.110602
# RMSE: 2.70825
#
# Iter: 34
# Tolerance: 0.105683
# MAPE: 0.11033
# RMSE: 2.7007
#
# Iter: 35
# Tolerance: 0.122014
# MAPE: 0.110798
# RMSE: 2.72078
#
# Iter: 36
# Tolerance: 0.116027
# MAPE: 0.110436
# RMSE: 2.71118
#
# Iter: 37
# Tolerance: 0.125057
# MAPE: 0.111942
# RMSE: 2.74193
#
# Iter: 38
# Tolerance: 0.127776
# MAPE: 0.112647
# RMSE: 2.75457
#
# Iter: 39
# Tolerance: 0.127054
# MAPE: 0.112181
# RMSE: 2.73768
#
# Iter: 40
# Tolerance: 0.134841
# MAPE: 0.114126
# RMSE: 2.78513
#
# Iter: 41
# Tolerance: 0.139548
# MAPE: 0.114999
# RMSE: 2.80002
#
# Iter: 42
# Tolerance: 0.144633
# MAPE: 0.116178
# RMSE: 2.81651
#
# Iter: 43
# Tolerance: 0.150946
# MAPE: 0.117364
# RMSE: 2.83934
#
# Iter: 44
# Tolerance: 0.148516
# MAPE: 0.116956
# RMSE: 2.82257
#
# Iter: 45
# Tolerance: 0.151496
# MAPE: 0.117475
# RMSE: 2.83138
#
# Iter: 46
# Tolerance: 0.150766
# MAPE: 0.117518
# RMSE: 2.82208
#
# Iter: 47
# Tolerance: 0.149471
# MAPE: 0.117162
# RMSE: 2.80801
#
# Iter: 48
# Tolerance: 0.149109
# MAPE: 0.117169
# RMSE: 2.80255
#
# Iter: 49
# Tolerance: 0.142872
# MAPE: 0.115533
# RMSE: 2.76321
#
# Iter: 50
# Tolerance: 0.145345
# MAPE: 0.116569
# RMSE: 2.78013
#
# Iter: 51
# Tolerance: 0.136612
# MAPE: 0.114386
# RMSE: 2.73068
#
# Iter: 52
# Tolerance: 0.137347
# MAPE: 0.114887
# RMSE: 2.73893
#
# Iter: 53
# Tolerance: 0.130584
# MAPE: 0.113424
# RMSE: 2.70606
#
# Iter: 54
# Tolerance: 0.129665
# MAPE: 0.113118
# RMSE: 2.69753
#
# Iter: 55
# Tolerance: 0.125205
# MAPE: 0.112116
# RMSE: 2.67521
#
# Iter: 56
# Tolerance: 0.121508
# MAPE: 0.111298
# RMSE: 2.65607
#
# Iter: 57
# Tolerance: 0.119216
# MAPE: 0.110819
# RMSE: 2.64524
#
# Iter: 58
# Tolerance: 0.114592
# MAPE: 0.10958
# RMSE: 2.62109
#
# Iter: 59
# Tolerance: 0.112988
# MAPE: 0.109167
# RMSE: 2.61313
#
# Iter: 60
# Tolerance: 0.107671
# MAPE: 0.108081
# RMSE: 2.5911
#
# Iter: 61
# Tolerance: 0.106443
# MAPE: 0.107863
# RMSE: 2.5852
#
# Iter: 62
# Tolerance: 0.101937
# MAPE: 0.106902
# RMSE: 2.56582
#
# Iter: 63
# Tolerance: 0.0996314
# MAPE: 0.106528
# RMSE: 2.55797
#
# Iter: 64
# Tolerance: 0.0971595
# MAPE: 0.105992
# RMSE: 2.54701
#
# Iter: 65
# Tolerance: 0.0933562
# MAPE: 0.105403
# RMSE: 2.53472
#
# Iter: 66
# Tolerance: 0.0917333
# MAPE: 0.105
# RMSE: 2.52692
#
# Iter: 67
# Tolerance: 0.089077
# MAPE: 0.104639
# RMSE: 2.51915
#
# Iter: 68
# Tolerance: 0.0862363
# MAPE: 0.104254
# RMSE: 2.5119
#
# Iter: 69
# Tolerance: 0.0849424
# MAPE: 0.103958
# RMSE: 2.50543
#
# Iter: 70
# Tolerance: 0.082442
# MAPE: 0.103574
# RMSE: 2.49805
#
# Iter: 71
# Tolerance: 0.0802704
# MAPE: 0.103252
# RMSE: 2.49216
#
# Iter: 72
# Tolerance: 0.0777812
# MAPE: 0.102995
# RMSE: 2.48667
#
# Iter: 73
# Tolerance: 0.0753303
# MAPE: 0.102716
# RMSE: 2.48179
#
# Iter: 74
# Tolerance: 0.0730347
# MAPE: 0.102498
# RMSE: 2.47776
#
# Iter: 75
# Tolerance: 0.0710967
# MAPE: 0.102321
# RMSE: 2.47455
#
# Iter: 76
# Tolerance: 0.0684574
# MAPE: 0.102119
# RMSE: 2.47094
#
# Iter: 77
# Tolerance: 0.0669771
# MAPE: 0.101985
# RMSE: 2.46882
#
# Iter: 78
# Tolerance: 0.0643788
# MAPE: 0.101872
# RMSE: 2.46699
#
# Iter: 79
# Tolerance: 0.0627081
# MAPE: 0.101777
# RMSE: 2.46603
#
# Iter: 80
# Tolerance: 0.060575
# MAPE: 0.101678
# RMSE: 2.46412
#
# Iter: 81
# Tolerance: 0.0588042
# MAPE: 0.101623
# RMSE: 2.46367
#
# Iter: 82
# Tolerance: 0.0569314
# MAPE: 0.101597
# RMSE: 2.4634
#
# Iter: 83
# Tolerance: 0.0552375
# MAPE: 0.101547
# RMSE: 2.46295
#
# Iter: 84
# Tolerance: 0.0533839
# MAPE: 0.101575
# RMSE: 2.46382
#
# Iter: 85
# Tolerance: 0.0521882
# MAPE: 0.101547
# RMSE: 2.46382
#
# Iter: 86
# Tolerance: 0.0507182
# MAPE: 0.101581
# RMSE: 2.46488
#
# Iter: 87
# Tolerance: 0.049118
# MAPE: 0.101599
# RMSE: 2.46556
#
# Iter: 88
# Tolerance: 0.0480155
# MAPE: 0.101643
# RMSE: 2.46693
#
# Iter: 89
# Tolerance: 0.0465981
# MAPE: 0.101686
# RMSE: 2.46812
#
# Iter: 90
# Tolerance: 0.0453766
# MAPE: 0.101757
# RMSE: 2.46984
#
# Iter: 91
# Tolerance: 0.0448
# MAPE: 0.101803
# RMSE: 2.4711
#
# Iter: 92
# Tolerance: 0.0438361
# MAPE: 0.101887
# RMSE: 2.47307
#
# Iter: 93
# Tolerance: 0.0427962
# MAPE: 0.101959
# RMSE: 2.47481
#
# Iter: 94
# Tolerance: 0.0423176
# MAPE: 0.102047
# RMSE: 2.47685
#
# Iter: 95
# Tolerance: 0.0416585
# MAPE: 0.102135
# RMSE: 2.47896
#
# Iter: 96
# Tolerance: 0.0408379
# MAPE: 0.102248
# RMSE: 2.48141
#
# Iter: 97
# Tolerance: 0.0401815
# MAPE: 0.102359
# RMSE: 2.484
#
# Iter: 98
# Tolerance: 0.0393387
# MAPE: 0.10249
# RMSE: 2.48674
#
# Iter: 99
# Tolerance: 0.0384966
# MAPE: 0.102635
# RMSE: 2.48993
#
# Iter: 100
# Tolerance: 0.037665
# MAPE: 0.102775
# RMSE: 2.4929
#
# Total iteration: 100
# Tolerance: 0.037665
# Imputation MAPE: 0.102775
# Imputation RMSE: 2.4929
#
# Running time: 10.18 minutes

# %% [markdown]
# ## Missing Data Imputation
#
# In the following, we apply the above defined LRTC-TNN function to the task of missing data imputation on the following spatiotemporal multivariate time series datasets/matrices:
#
# - **PeMS data set**: [PeMS traffic speed data set](https://doi.org/10.5281/zenodo.3939793).

# %% [markdown]
# ### PeMS-4W
#
# We generate **random missing (RM)** values on PeMS data set.

# %%
import time
import numpy as np
import pandas as pd
np.random.seed(1000)

data = pd.read_csv('../datasets/California-data-set/pems-4w.csv', header = None)
dense_tensor = mat2ten(data.values, np.array([data.values.shape[0], 288, 4 * 7]), 0)
random_tensor = np.random.rand(data.values.shape[0], 288, 4 * 7)

missing_rate = 0.3

### Random missing (RM) scenario:
sparse_tensor = np.multiply(dense_tensor, np.round(random_tensor + 0.5 - missing_rate))
del data, random_tensor

start = time.time()
alpha = np.ones(3) / 3
rho = 1e-4
theta = 0.05
epsilon = 1e-3
maxiter = 100
tensor_hat = LRTC(dense_tensor, sparse_tensor, alpha, rho, theta, epsilon, maxiter)
end = time.time()
print('Running time: %.2f minutes' % ((end - start)/60.0))
# Out:
# Iter: 1
# Tolerance: 0.181052
# MAPE: 0.782707
# RMSE: 50.2879
#
# Iter: 2
# Tolerance: 0.195387
# MAPE: 0.560058
# RMSE: 36.5057
#
# Iter: 3
# Tolerance: 0.168308
# MAPE: 0.359063
# RMSE: 24.2606
#
# Iter: 4
# Tolerance: 0.145435
# MAPE: 0.184398
# RMSE: 13.4393
#
# Iter: 5
# Tolerance: 0.115872
# MAPE: 0.0784202
# RMSE: 6.07173
#
# Iter: 6
# Tolerance: 0.0789183
# MAPE: 0.0665844
# RMSE: 4.76338
#
# Iter: 7
# Tolerance: 0.0458254
# MAPE: 0.0847863
# RMSE: 5.63931
#
# Iter: 8
# Tolerance: 0.0367108
# MAPE: 0.083127
# RMSE: 5.47457
#
# Iter: 9
# Tolerance: 0.0397892
# MAPE: 0.0670385
# RMSE: 4.48838
#
# Iter: 10
# Tolerance: 0.0411403
# MAPE: 0.0468935
# RMSE: 3.30249
#
# Iter: 11
# Tolerance: 0.0403542
# MAPE: 0.0317915
# RMSE: 2.43241
#
# Iter: 12
# Tolerance: 0.038941
# MAPE: 0.0248937
# RMSE: 2.03359
#
# Iter: 13
# Tolerance: 0.0377077
# MAPE: 0.0231981
# RMSE: 1.92444
#
# Iter: 14
# Tolerance: 0.0363331
# MAPE: 0.0224476
# RMSE: 1.87562
#
# Iter: 15
# Tolerance: 0.035165
# MAPE: 0.0219749
# RMSE: 1.8485
#
# Iter: 16
# Tolerance: 0.0342945
# MAPE: 0.0214996
# RMSE: 1.82146
#
# Iter: 17
# Tolerance: 0.0333032
# MAPE: 0.0212269
# RMSE: 1.80648
#
# Iter: 18
# Tolerance: 0.0323021
# MAPE: 0.0208163
# RMSE: 1.7821
#
# Iter: 19
# Tolerance: 0.0310908
# MAPE: 0.020449
# RMSE: 1.76103
#
# Iter: 20
# Tolerance: 0.029906
# MAPE: 0.0199756
# RMSE: 1.73296
#
# Iter: 21
# Tolerance: 0.0285751
# MAPE: 0.019515
# RMSE: 1.70605
#
# Iter: 22
# Tolerance: 0.0273291
# MAPE: 0.019065
# RMSE: 1.67881
#
# Iter: 23
# Tolerance: 0.0260706
# MAPE: 0.0186366
# RMSE: 1.65271
#
# Iter: 24
# Tolerance: 0.0249418
# MAPE: 0.0182744
# RMSE: 1.6305
#
# Iter: 25
# Tolerance: 0.0239075
# MAPE: 0.0179455
# RMSE: 1.61016
#
# Iter: 26
# Tolerance: 0.0229515
# MAPE: 0.0176879
# RMSE: 1.59467
#
# Iter: 27
# Tolerance: 0.0220945
# MAPE: 0.0174698
# RMSE: 1.58145
#
# Iter: 28
# Tolerance: 0.0212403
# MAPE: 0.0173032
# RMSE: 1.57139
#
# Iter: 29
# Tolerance: 0.0204259
# MAPE: 0.0171678
# RMSE: 1.56349
#
# Iter: 30
# Tolerance: 0.0195798
# MAPE: 0.0170616
# RMSE: 1.55742
#
# Iter: 31
# Tolerance: 0.0187406
# MAPE: 0.0169782
# RMSE: 1.55287
#
# Iter: 32
# Tolerance: 0.0178922
# MAPE: 0.01691
# RMSE: 1.54929
#
# Iter: 33
# Tolerance: 0.0170574
# MAPE: 0.0168575
# RMSE: 1.54685
#
# Iter: 34
# Tolerance: 0.0162399
# MAPE: 0.0168133
# RMSE: 1.54481
#
# Iter: 35
# Tolerance: 0.015451
# MAPE: 0.0167833
# RMSE: 1.54372
#
# Iter: 36
# Tolerance: 0.0147005
# MAPE: 0.0167532
# RMSE: 1.54256
#
# Iter: 37
# Tolerance: 0.0139669
# MAPE: 0.0167347
# RMSE: 1.54207
#
# Iter: 38
# Tolerance: 0.013248
# MAPE: 0.0167144
# RMSE: 1.54138
#
# Iter: 39
# Tolerance: 0.0125263
# MAPE: 0.0167026
# RMSE: 1.54119
#
# Iter: 40
# Tolerance: 0.0117971
# MAPE: 0.0166885
# RMSE: 1.54068
#
# Iter: 41
# Tolerance: 0.011063
# MAPE: 0.016678
# RMSE: 1.54045
#
# Iter: 42
# Tolerance: 0.0103474
# MAPE: 0.0166662
# RMSE: 1.53997
#
# Iter: 43
# Tolerance: 0.0096639
# MAPE: 0.0166573
# RMSE: 1.53976
#
# Iter: 44
# Tolerance: 0.00902005
# MAPE: 0.0166494
# RMSE: 1.53948
#
# Iter: 45
# Tolerance: 0.0084135
# MAPE: 0.0166435
# RMSE: 1.53942
#
# Iter: 46
# Tolerance: 0.00784465
# MAPE: 0.0166392
# RMSE: 1.53938
#
# Iter: 47
# Tolerance: 0.00731045
# MAPE: 0.0166363
# RMSE: 1.53946
#
# Iter: 48
# Tolerance: 0.0068099
# MAPE: 0.0166348
# RMSE: 1.5396
#
# Iter: 49
# Tolerance: 0.00634111
# MAPE: 0.016634
# RMSE: 1.5398
#
# Iter: 50
# Tolerance: 0.00590228
# MAPE: 0.0166345
# RMSE: 1.54006
#
# Iter: 51
# Tolerance: 0.00549218
# MAPE: 0.0166352
# RMSE: 1.54033
#
# Iter: 52
# Tolerance: 0.00510886
# MAPE: 0.016637
# RMSE: 1.54066
#
# Iter: 53
# Tolerance: 0.0047511
# MAPE: 0.0166388
# RMSE: 1.54099
#
# Iter: 54
# Tolerance: 0.00441706
# MAPE: 0.0166415
# RMSE: 1.54136
#
# Iter: 55
# Tolerance: 0.00410549
# MAPE: 0.0166441
# RMSE: 1.54171
#
# Iter: 56
# Tolerance: 0.00381464
# MAPE: 0.0166472
# RMSE: 1.54209
#
# Iter: 57
# Tolerance: 0.00354348
# MAPE: 0.0166504
# RMSE: 1.54246
#
# Iter: 58
# Tolerance: 0.00329043
# MAPE: 0.0166537
# RMSE: 1.54283
#
# Iter: 59
# Tolerance: 0.00305467
# MAPE: 0.0166571
# RMSE: 1.54321
#
# Iter: 60
# Tolerance: 0.00283487
# MAPE: 0.0166605
# RMSE: 1.54357
#
# Iter: 61
# Tolerance: 0.00263027
# MAPE: 0.016664
# RMSE: 1.54394
#
# Iter: 62
# Tolerance: 0.00243977
# MAPE: 0.0166673
# RMSE: 1.54428
#
# Iter: 63
# Tolerance: 0.0022626
# MAPE: 0.0166708
# RMSE: 1.54464
#
# Iter: 64
# Tolerance: 0.00209781
# MAPE: 0.0166741
# RMSE: 1.54496
#
# Iter: 65
# Tolerance: 0.00194452
# MAPE: 0.0166774
# RMSE: 1.5453
#
# Iter: 66
# Tolerance: 0.00180191
# MAPE: 0.0166805
# RMSE: 1.5456
#
# Iter: 67
# Tolerance: 0.00166916
# MAPE: 0.0166838
# RMSE: 1.54592
#
# Iter: 68
# Tolerance: 0.00154573
# MAPE: 0.0166867
# RMSE: 1.54621
#
# Iter: 69
# Tolerance: 0.00143094
# MAPE: 0.0166897
# RMSE: 1.5465
#
# Iter: 70
# Tolerance: 0.00132446
# MAPE: 0.0166925
# RMSE: 1.54676
#
# Iter: 71
# Tolerance: 0.00122563
# MAPE: 0.0166953
# RMSE: 1.54703
#
# Iter: 72
# Tolerance: 0.00113417
# MAPE: 0.0166978
# RMSE: 1.54728
#
# Iter: 73
# Tolerance: 0.00104939
# MAPE: 0.0167004
# RMSE: 1.54752
#
# Iter: 74
# Tolerance: 0.000970978
# MAPE: 0.0167027
# RMSE: 1.54775
#
# Total iteration: 74
# Tolerance: 0.000970978
# Imputation MAPE: 0.0167027
# Imputation RMSE: 1.54775
#
# Running time: 354.82 minutes

# %%
import time
import numpy as np
import pandas as pd
np.random.seed(1000)

data = pd.read_csv('../datasets/California-data-set/pems-4w.csv', header = None)
dense_tensor = mat2ten(data.values, np.array([data.values.shape[0], 288, 4 * 7]), 0)
random_tensor = np.random.rand(data.values.shape[0], 288, 4 * 7)

missing_rate = 0.7

### Random missing (RM) scenario:
sparse_tensor = np.multiply(dense_tensor, np.round(random_tensor + 0.5 - missing_rate))
del data, random_tensor

start = time.time()
alpha = np.ones(3) / 3
rho = 1e-4
theta = 0.05
epsilon = 1e-3
maxiter = 100
tensor_hat = LRTC(dense_tensor, sparse_tensor, alpha, rho, theta, epsilon, maxiter)
end = time.time()
print('Running time: %.2f minutes' % ((end - start)/60.0))
# Out:
# Iter: 1
# Tolerance: 0.276156
# MAPE: 0.906166
# RMSE: 58.0419
#
# Iter: 2
# Tolerance: 0.27572
# MAPE: 0.808607
# RMSE: 52.1791
#
# Iter: 3
# Tolerance: 0.189472
# MAPE: 0.71773
# RMSE: 46.9454
#
# Iter: 4
# Tolerance: 0.17281
# MAPE: 0.633354
# RMSE: 42.0687
#
# Iter: 5
# Tolerance: 0.155918
# MAPE: 0.557491
# RMSE: 37.7344
#
# Iter: 6
# Tolerance: 0.143533
# MAPE: 0.488646
# RMSE: 33.6451
#
# Iter: 7
# Tolerance: 0.130831
# MAPE: 0.427656
# RMSE: 29.9211
#
# Iter: 8
# Tolerance: 0.122855
# MAPE: 0.372287
# RMSE: 26.3898
#
# Iter: 9
# Tolerance: 0.113134
# MAPE: 0.322893
# RMSE: 23.1531
#
# Iter: 10
# Tolerance: 0.106687
# MAPE: 0.277548
# RMSE: 20.1011
#
# Iter: 11
# Tolerance: 0.0987406
# MAPE: 0.236777
# RMSE: 17.3062
#
# Iter: 12
# Tolerance: 0.0934201
# MAPE: 0.199142
# RMSE: 14.6872
#
# Iter: 13
# Tolerance: 0.0870086
# MAPE: 0.165301
# RMSE: 12.3019
#
# Iter: 14
# Tolerance: 0.0824562
# MAPE: 0.134294
# RMSE: 10.0958
#
# Iter: 15
# Tolerance: 0.0765782
# MAPE: 0.106987
# RMSE: 8.13265
#
# Iter: 16
# Tolerance: 0.0705283
# MAPE: 0.0832733
# RMSE: 6.41103
#
# Iter: 17
# Tolerance: 0.0633333
# MAPE: 0.064051
# RMSE: 4.98369
#
# Iter: 18
# Tolerance: 0.0560002
# MAPE: 0.0499696
# RMSE: 3.90909
#
# Iter: 19
# Tolerance: 0.0483189
# MAPE: 0.0414033
# RMSE: 3.24813
#
# Iter: 20
# Tolerance: 0.0404614
# MAPE: 0.0378192
# RMSE: 2.96059
#
# Iter: 21
# Tolerance: 0.033908
# MAPE: 0.0371827
# RMSE: 2.87034
#
# Iter: 22
# Tolerance: 0.0292072
# MAPE: 0.0370402
# RMSE: 2.82761
#
# Iter: 23
# Tolerance: 0.0263673
# MAPE: 0.0361661
# RMSE: 2.76457
#
# Iter: 24
# Tolerance: 0.0246727
# MAPE: 0.0344866
# RMSE: 2.67079
#
# Iter: 25
# Tolerance: 0.023647
# MAPE: 0.0323304
# RMSE: 2.55905
#
# Iter: 26
# Tolerance: 0.0227106
# MAPE: 0.0300906
# RMSE: 2.44673
#
# Iter: 27
# Tolerance: 0.0218068
# MAPE: 0.02809
# RMSE: 2.34917
#
# Iter: 28
# Tolerance: 0.0207915
# MAPE: 0.0264906
# RMSE: 2.2722
#
# Iter: 29
# Tolerance: 0.0197505
# MAPE: 0.0253538
# RMSE: 2.2172
#
# Iter: 30
# Tolerance: 0.0186916
# MAPE: 0.0246073
# RMSE: 2.17953
#
# Iter: 31
# Tolerance: 0.0176683
# MAPE: 0.0241641
# RMSE: 2.15556
#
# Iter: 32
# Tolerance: 0.0167035
# MAPE: 0.02389
# RMSE: 2.13942
#
# Iter: 33
# Tolerance: 0.0157869
# MAPE: 0.0237171
# RMSE: 2.12927
#
# Iter: 34
# Tolerance: 0.0149328
# MAPE: 0.0235805
# RMSE: 2.12177
#
# Iter: 35
# Tolerance: 0.0141035
# MAPE: 0.0234741
# RMSE: 2.11718
#
# Iter: 36
# Tolerance: 0.0133071
# MAPE: 0.0233746
# RMSE: 2.11345
#
# Iter: 37
# Tolerance: 0.0125121
# MAPE: 0.0232972
# RMSE: 2.11147
#
# Iter: 38
# Tolerance: 0.0117317
# MAPE: 0.0232309
# RMSE: 2.10996
#
# Iter: 39
# Tolerance: 0.010954
# MAPE: 0.0231845
# RMSE: 2.10949
#
# Iter: 40
# Tolerance: 0.0102013
# MAPE: 0.0231485
# RMSE: 2.10924
#
# Iter: 41
# Tolerance: 0.00947733
# MAPE: 0.023127
# RMSE: 2.10962
#
# Iter: 42
# Tolerance: 0.00879275
# MAPE: 0.0231118
# RMSE: 2.11006
#
# Iter: 43
# Tolerance: 0.00814639
# MAPE: 0.0231049
# RMSE: 2.11087
#
# Iter: 44
# Tolerance: 0.00753866
# MAPE: 0.0231005
# RMSE: 2.11165
#
# Iter: 45
# Tolerance: 0.00696893
# MAPE: 0.0231004
# RMSE: 2.11264
#
# Iter: 46
# Tolerance: 0.00643509
# MAPE: 0.0231011
# RMSE: 2.11357
#
# Iter: 47
# Tolerance: 0.00593673
# MAPE: 0.0231042
# RMSE: 2.11462
#
# Iter: 48
# Tolerance: 0.00547101
# MAPE: 0.0231076
# RMSE: 2.11561
#
# Iter: 49
# Tolerance: 0.00503743
# MAPE: 0.0231125
# RMSE: 2.11664
#
# Iter: 50
# Tolerance: 0.0046332
# MAPE: 0.0231178
# RMSE: 2.11764
#
# Iter: 51
# Tolerance: 0.00425794
# MAPE: 0.0231239
# RMSE: 2.11865
#
# Iter: 52
# Tolerance: 0.00390907
# MAPE: 0.0231304
# RMSE: 2.11963
#
# Iter: 53
# Tolerance: 0.00358639
# MAPE: 0.0231374
# RMSE: 2.12061
#
# Iter: 54
# Tolerance: 0.00328707
# MAPE: 0.0231445
# RMSE: 2.12155
#
# Iter: 55
# Tolerance: 0.00301113
# MAPE: 0.023152
# RMSE: 2.12249
#
# Iter: 56
# Tolerance: 0.00275551
# MAPE: 0.0231595
# RMSE: 2.12339
#
# Iter: 57
# Tolerance: 0.00252036
# MAPE: 0.0231671
# RMSE: 2.12428
#
# Iter: 58
# Tolerance: 0.00230284
# MAPE: 0.0231746
# RMSE: 2.12513
#
# Iter: 59
# Tolerance: 0.00210295
# MAPE: 0.0231823
# RMSE: 2.12596
#
# Iter: 60
# Tolerance: 0.00191835
# MAPE: 0.0231897
# RMSE: 2.12677
#
# Iter: 61
# Tolerance: 0.00174871
# MAPE: 0.0231971
# RMSE: 2.12755
#
# Iter: 62
# Tolerance: 0.00159246
# MAPE: 0.0232043
# RMSE: 2.1283
#
# Iter: 63
# Tolerance: 0.00144888
# MAPE: 0.0232114
# RMSE: 2.12903
#
# Iter: 64
# Tolerance: 0.00131732
# MAPE: 0.0232183
# RMSE: 2.12973
#
# Iter: 65
# Tolerance: 0.00119644
# MAPE: 0.0232251
# RMSE: 2.1304
#
# Iter: 66
# Tolerance: 0.00108635
# MAPE: 0.0232315
# RMSE: 2.13105
#
# Iter: 67
# Tolerance: 0.000985168
# MAPE: 0.0232379
# RMSE: 2.13167
#
# Total iteration: 67
# Tolerance: 0.000985168
# Imputation MAPE: 0.0232379
# Imputation RMSE: 2.13167
#
# Running time: 322.66 minutes

# %% [markdown]
# We generate **non-random missing (NM)** values on PeMS data set. Then, we conduct the imputation experiment.

# %%
import time
import numpy as np
import pandas as pd
np.random.seed(1000)

data = pd.read_csv('../datasets/California-data-set/pems-4w.csv', header = None)
dense_tensor = mat2ten(data.values, np.array([data.values.shape[0], 288, 4 * 7]), 0)
random_matrix = np.random.rand(data.values.shape[0], 4 * 7)

missing_rate = 0.3

### Non-random missing (NM) scenario:
binary_tensor = np.zeros(dense_tensor.shape)
for i1 in range(dense_tensor.shape[0]):
    for i2 in range(dense_tensor.shape[2]):
        binary_tensor[i1, :, i2] = np.round(random_matrix[i1, i2] + 0.5 - missing_rate)
sparse_tensor = np.multiply(dense_tensor, binary_tensor)
del data, random_matrix, binary_tensor

start = time.time()
alpha = np.ones(3) / 3
rho = 1e-5
theta = 0.05
epsilon = 1e-3
maxiter = 100
tensor_hat = LRTC(dense_tensor, sparse_tensor, alpha, rho, theta, epsilon, maxiter)
end = time.time()
print('Running time: %.2f minutes' % ((end - start)/60.0))
# Out:
# Iter: 1
# Tolerance: 0.125128
# MAPE: 0.867413
# RMSE: 55.4783
#
# Iter: 2
# Tolerance: 0.122031
# MAPE: 0.74696
# RMSE: 47.6661
#
# Iter: 3
# Tolerance: 0.103463
# MAPE: 0.630497
# RMSE: 40.3281
#
# Iter: 4
# Tolerance: 0.149923
# MAPE: 0.450316
# RMSE: 29.4888
#
# Iter: 5
# Tolerance: 0.142983
# MAPE: 0.328168
# RMSE: 21.6391
#
# Iter: 6
# Tolerance: 0.130813
# MAPE: 0.21113
# RMSE: 14.9015
#
# Iter: 7
# Tolerance: 0.112119
# MAPE: 0.109724
# RMSE: 9.14
#
# Iter: 8
# Tolerance: 0.0940634
# MAPE: 0.0820072
# RMSE: 7.15026
#
# Iter: 9
# Tolerance: 0.0820413
# MAPE: 0.0894765
# RMSE: 6.87678
#
# Iter: 10
# Tolerance: 0.0864565
# MAPE: 0.0843179
# RMSE: 6.15381
#
# Iter: 11
# Tolerance: 0.0910586
# MAPE: 0.0700316
# RMSE: 5.31845
#
# Iter: 12
# Tolerance: 0.0938788
# MAPE: 0.0609626
# RMSE: 4.8927
#
# Iter: 13
# Tolerance: 0.093614
# MAPE: 0.060151
# RMSE: 4.86196
#
# Iter: 14
# Tolerance: 0.0937059
# MAPE: 0.0603958
# RMSE: 4.88068
#
# Iter: 15
# Tolerance: 0.0930535
# MAPE: 0.0605985
# RMSE: 4.90473
#
# Iter: 16
# Tolerance: 0.0960272
# MAPE: 0.0591932
# RMSE: 4.84462
#
# Iter: 17
# Tolerance: 0.0949935
# MAPE: 0.0594277
# RMSE: 4.88214
#
# Iter: 18
# Tolerance: 0.0951128
# MAPE: 0.0588375
# RMSE: 4.85261
#
# Iter: 19
# Tolerance: 0.0948216
# MAPE: 0.0590977
# RMSE: 4.88637
#
# Iter: 20
# Tolerance: 0.0946628
# MAPE: 0.058614
# RMSE: 4.84603
#
# Iter: 21
# Tolerance: 0.0917223
# MAPE: 0.0586468
# RMSE: 4.84358
#
# Iter: 22
# Tolerance: 0.089512
# MAPE: 0.0581365
# RMSE: 4.80795
#
# Iter: 23
# Tolerance: 0.0887981
# MAPE: 0.0583873
# RMSE: 4.81068
#
# Iter: 24
# Tolerance: 0.0881141
# MAPE: 0.0579453
# RMSE: 4.77257
#
# Iter: 25
# Tolerance: 0.0864855
# MAPE: 0.0574576
# RMSE: 4.7338
#
# Iter: 26
# Tolerance: 0.0846214
# MAPE: 0.0574701
# RMSE: 4.73962
#
# Iter: 27
# Tolerance: 0.0829662
# MAPE: 0.0568085
# RMSE: 4.68431
#
# Iter: 28
# Tolerance: 0.0825193
# MAPE: 0.0566675
# RMSE: 4.67067
#
# Iter: 29
# Tolerance: 0.0820545
# MAPE: 0.0563893
# RMSE: 4.65055
#
# Iter: 30
# Tolerance: 0.0796935
# MAPE: 0.0558645
# RMSE: 4.60774
#
# Iter: 31
# Tolerance: 0.0778989
# MAPE: 0.0555052
# RMSE: 4.58092
#
# Iter: 32
# Tolerance: 0.0767726
# MAPE: 0.0551256
# RMSE: 4.55071
#
# Iter: 33
# Tolerance: 0.0758323
# MAPE: 0.054819
# RMSE: 4.52713
#
# Iter: 34
# Tolerance: 0.0744455
# MAPE: 0.0543455
# RMSE: 4.49157
#
# Iter: 35
# Tolerance: 0.0728274
# MAPE: 0.0539341
# RMSE: 4.46208
#
# Iter: 36
# Tolerance: 0.0713538
# MAPE: 0.0536519
# RMSE: 4.4391
#
# Iter: 37
# Tolerance: 0.0700077
# MAPE: 0.0532767
# RMSE: 4.40924
#
# Iter: 38
# Tolerance: 0.0686664
# MAPE: 0.0529634
# RMSE: 4.3866
#
# Iter: 39
# Tolerance: 0.0671702
# MAPE: 0.0525402
# RMSE: 4.35687
#
# Iter: 40
# Tolerance: 0.0659876
# MAPE: 0.0522589
# RMSE: 4.33436
#
# Iter: 41
# Tolerance: 0.0646917
# MAPE: 0.0519523
# RMSE: 4.30967
#
# Iter: 42
# Tolerance: 0.0634867
# MAPE: 0.0516195
# RMSE: 4.28578
#
# Iter: 43
# Tolerance: 0.06218
# MAPE: 0.051341
# RMSE: 4.26545
#
# Iter: 44
# Tolerance: 0.0610094
# MAPE: 0.0510763
# RMSE: 4.24405
#
# Iter: 45
# Tolerance: 0.0596481
# MAPE: 0.0507512
# RMSE: 4.22179
#
# Iter: 46
# Tolerance: 0.0582152
# MAPE: 0.0504888
# RMSE: 4.2032
#
# Iter: 47
# Tolerance: 0.0570661
# MAPE: 0.0502433
# RMSE: 4.18514
#
# Iter: 48
# Tolerance: 0.055947
# MAPE: 0.0499829
# RMSE: 4.16614
#
# Iter: 49
# Tolerance: 0.0546031
# MAPE: 0.049709
# RMSE: 4.14709
#
# Iter: 50
# Tolerance: 0.0533548
# MAPE: 0.0494817
# RMSE: 4.13168
#
# Iter: 51
# Tolerance: 0.0522026
# MAPE: 0.0492807
# RMSE: 4.11729
#
# Iter: 52
# Tolerance: 0.050939
# MAPE: 0.0490508
# RMSE: 4.10255
#
# Iter: 53
# Tolerance: 0.0496437
# MAPE: 0.0488433
# RMSE: 4.08719
#
# Iter: 54
# Tolerance: 0.0485255
# MAPE: 0.0486476
# RMSE: 4.07482
#
# Iter: 55
# Tolerance: 0.0472818
# MAPE: 0.0484542
# RMSE: 4.06176
#
# Iter: 56
# Tolerance: 0.0460377
# MAPE: 0.0482592
# RMSE: 4.0498
#
# Iter: 57
# Tolerance: 0.0449133
# MAPE: 0.0480841
# RMSE: 4.03824
#
# Iter: 58
# Tolerance: 0.0436573
# MAPE: 0.047882
# RMSE: 4.02609
#
# Iter: 59
# Tolerance: 0.042007
# MAPE: 0.0476288
# RMSE: 4.01243
#
# Iter: 60
# Tolerance: 0.040296
# MAPE: 0.0473637
# RMSE: 3.99804
#
# Iter: 61
# Tolerance: 0.0388596
# MAPE: 0.0471175
# RMSE: 3.98528
#
# Iter: 62
# Tolerance: 0.0375942
# MAPE: 0.0469006
# RMSE: 3.97325
#
# Iter: 63
# Tolerance: 0.0363703
# MAPE: 0.0467074
# RMSE: 3.96253
#
# Iter: 64
# Tolerance: 0.0351224
# MAPE: 0.0465265
# RMSE: 3.95228
#
# Iter: 65
# Tolerance: 0.0338615
# MAPE: 0.0463485
# RMSE: 3.94227
#
# Iter: 66
# Tolerance: 0.0326128
# MAPE: 0.0461891
# RMSE: 3.93296
#
# Iter: 67
# Tolerance: 0.0313647
# MAPE: 0.0460442
# RMSE: 3.92467
#
# Iter: 68
# Tolerance: 0.0301541
# MAPE: 0.0459074
# RMSE: 3.91677
#
# Iter: 69
# Tolerance: 0.0289855
# MAPE: 0.045784
# RMSE: 3.90966
#
# Iter: 70
# Tolerance: 0.027867
# MAPE: 0.045666
# RMSE: 3.90307
#
# Iter: 71
# Tolerance: 0.0267982
# MAPE: 0.0455701
# RMSE: 3.8972
#
# Iter: 72
# Tolerance: 0.0257785
# MAPE: 0.045474
# RMSE: 3.89198
#
# Iter: 73
# Tolerance: 0.0248062
# MAPE: 0.0454034
# RMSE: 3.88771
#
# Iter: 74
# Tolerance: 0.0238717
# MAPE: 0.0453455
# RMSE: 3.88469
#
# Iter: 75
# Tolerance: 0.0229819
# MAPE: 0.0453003
# RMSE: 3.88202
#
# Iter: 76
# Tolerance: 0.0221131
# MAPE: 0.0452713
# RMSE: 3.88052
#
# Iter: 77
# Tolerance: 0.0212837
# MAPE: 0.0452501
# RMSE: 3.87912
#
# Iter: 78
# Tolerance: 0.020462
# MAPE: 0.0452427
# RMSE: 3.87888
#
# Iter: 79
# Tolerance: 0.019642
# MAPE: 0.0452434
# RMSE: 3.87868
#
# Iter: 80
# Tolerance: 0.0188141
# MAPE: 0.0452537
# RMSE: 3.87934
#
# Iter: 81
# Tolerance: 0.0179832
# MAPE: 0.0452671
# RMSE: 3.87998
#
# Iter: 82
# Tolerance: 0.0171652
# MAPE: 0.0452938
# RMSE: 3.88144
#
# Iter: 83
# Tolerance: 0.0163596
# MAPE: 0.0453228
# RMSE: 3.88303
#
# Iter: 84
# Tolerance: 0.0155802
# MAPE: 0.0453615
# RMSE: 3.88516
#
# Iter: 85
# Tolerance: 0.0148165
# MAPE: 0.0454043
# RMSE: 3.88752
#
# Iter: 86
# Tolerance: 0.0140768
# MAPE: 0.0454539
# RMSE: 3.89027
#
# Iter: 87
# Tolerance: 0.013335
# MAPE: 0.0455063
# RMSE: 3.89328
#
# Iter: 88
# Tolerance: 0.0125936
# MAPE: 0.0455637
# RMSE: 3.89651
#
# Iter: 89
# Tolerance: 0.0118428
# MAPE: 0.0456223
# RMSE: 3.89992
#
# Iter: 90
# Tolerance: 0.0110871
# MAPE: 0.0456821
# RMSE: 3.90333
#
# Iter: 91
# Tolerance: 0.0103536
# MAPE: 0.0457415
# RMSE: 3.90686
#
# Iter: 92
# Tolerance: 0.00965287
# MAPE: 0.0458011
# RMSE: 3.91032
#
# Iter: 93
# Tolerance: 0.00899068
# MAPE: 0.0458599
# RMSE: 3.91388
#
# Iter: 94
# Tolerance: 0.00836619
# MAPE: 0.0459184
# RMSE: 3.91735
#
# Iter: 95
# Tolerance: 0.00777913
# MAPE: 0.0459759
# RMSE: 3.92089
#
# Iter: 96
# Tolerance: 0.00722799
# MAPE: 0.0460326
# RMSE: 3.92433
#
# Iter: 97
# Tolerance: 0.0067113
# MAPE: 0.0460884
# RMSE: 3.92783
#
# Iter: 98
# Tolerance: 0.0062278
# MAPE: 0.0461428
# RMSE: 3.93119
#
# Iter: 99
# Tolerance: 0.00577537
# MAPE: 0.0461963
# RMSE: 3.93459
#
# Iter: 100
# Tolerance: 0.00535295
# MAPE: 0.0462479
# RMSE: 3.93784
#
# Total iteration: 100
# Tolerance: 0.00535295
# Imputation MAPE: 0.0462479
# Imputation RMSE: 3.93784
#
# Running time: 468.25 minutes

# %%
import time
import numpy as np
import pandas as pd
np.random.seed(1000)

data = pd.read_csv('../datasets/California-data-set/pems-4w.csv', header = None)
dense_tensor = mat2ten(data.values, np.array([data.values.shape[0], 288, 4 * 7]), 0)
random_matrix = np.random.rand(data.values.shape[0], 4 * 7)

missing_rate = 0.7

### Non-random missing (NM) scenario:
binary_tensor = np.zeros(dense_tensor.shape)
for i1 in range(dense_tensor.shape[0]):
    for i2 in range(dense_tensor.shape[2]):
        binary_tensor[i1, :, i2] = np.round(random_matrix[i1, i2] + 0.5 - missing_rate)
sparse_tensor = np.multiply(dense_tensor, binary_tensor)
del data, random_matrix, binary_tensor

start = time.time()
alpha = np.ones(3) / 3
rho = 1e-6
theta = 0.05
epsilon = 1e-3
maxiter = 100
tensor_hat = LRTC(dense_tensor, sparse_tensor, alpha, rho, theta, epsilon, maxiter)
end = time.time()
print('Running time: %.2f minutes' % ((end - start)/60.0))
# Out:
# Iter: 1
# Tolerance: 0.670918
# MAPE: 1.0
# RMSE: 63.7516
#
# Iter: 2
# Tolerance: 0.740001
# MAPE: 0.619773
# RMSE: 40.608
#
# Iter: 3
# Tolerance: 0.633251
# MAPE: 0.272521
# RMSE: 19.7281
#
# Iter: 4
# Tolerance: 0.544303
# MAPE: 0.241767
# RMSE: 16.2671
#
# Iter: 5
# Tolerance: 0.371342
# MAPE: 0.395773
# RMSE: 24.6338
#
# Iter: 6
# Tolerance: 0.220667
# MAPE: 0.486655
# RMSE: 29.2177
#
# Iter: 7
# Tolerance: 0.170346
# MAPE: 0.478699
# RMSE: 28.8084
#
# Iter: 8
# Tolerance: 0.199537
# MAPE: 0.400068
# RMSE: 25.1451
#
# Iter: 9
# Tolerance: 0.221094
# MAPE: 0.303136
# RMSE: 20.3761
#
# Iter: 10
# Tolerance: 0.214256
# MAPE: 0.233673
# RMSE: 16.3231
#
# Iter: 11
# Tolerance: 0.187391
# MAPE: 0.20348
# RMSE: 13.9549
#
# Iter: 12
# Tolerance: 0.254431
# MAPE: 0.191135
# RMSE: 12.8224
#
# Iter: 13
# Tolerance: 0.229579
# MAPE: 0.191378
# RMSE: 12.543
#
# Iter: 14
# Tolerance: 0.106563
# MAPE: 0.186386
# RMSE: 12.2378
#
# Iter: 15
# Tolerance: 0.18921
# MAPE: 0.171756
# RMSE: 11.5291
#
# Iter: 16
# Tolerance: 0.243535
# MAPE: 0.150097
# RMSE: 10.6339
#
# Iter: 17
# Tolerance: 0.130325
# MAPE: 0.137108
# RMSE: 9.74656
#
# Iter: 18
# Tolerance: 0.200621
# MAPE: 0.125344
# RMSE: 9.21308
#
# Iter: 19
# Tolerance: 0.173939
# MAPE: 0.122609
# RMSE: 8.99572
#
# Iter: 20
# Tolerance: 0.147403
# MAPE: 0.116299
# RMSE: 8.43286
#
# Iter: 21
# Tolerance: 0.189472
# MAPE: 0.109648
# RMSE: 7.77193
#
# Iter: 22
# Tolerance: 0.138316
# MAPE: 0.117104
# RMSE: 8.18796
#
# Iter: 23
# Tolerance: 0.129617
# MAPE: 0.109757
# RMSE: 7.73398
#
# Iter: 24
# Tolerance: 0.174904
# MAPE: 0.0902812
# RMSE: 6.75705
#
# Iter: 25
# Tolerance: 0.159032
# MAPE: 0.0892612
# RMSE: 6.73828
#
# Iter: 26
# Tolerance: 0.172964
# MAPE: 0.096657
# RMSE: 7.40108
#
# Iter: 27
# Tolerance: 0.16065
# MAPE: 0.0955913
# RMSE: 7.35779
#
# Iter: 28
# Tolerance: 0.186437
# MAPE: 0.0905047
# RMSE: 6.98717
#
# Iter: 29
# Tolerance: 0.172748
# MAPE: 0.0803842
# RMSE: 6.27928
#
# Iter: 30
# Tolerance: 0.182399
# MAPE: 0.0786229
# RMSE: 6.00874
#
# Iter: 31
# Tolerance: 0.158857
# MAPE: 0.0877223
# RMSE: 6.75016
#
# Iter: 32
# Tolerance: 0.160448
# MAPE: 0.0878396
# RMSE: 6.71724
#
# Iter: 33
# Tolerance: 0.173283
# MAPE: 0.0894342
# RMSE: 6.67252
#
# Iter: 34
# Tolerance: 0.158774
# MAPE: 0.0924946
# RMSE: 6.94577
#
# Iter: 35
# Tolerance: 0.169442
# MAPE: 0.0819149
# RMSE: 6.22113
#
# Iter: 36
# Tolerance: 0.179947
# MAPE: 0.0776424
# RMSE: 6.17832
#
# Iter: 37
# Tolerance: 0.170483
# MAPE: 0.0720278
# RMSE: 5.77678
#
# Iter: 38
# Tolerance: 0.139124
# MAPE: 0.0744345
# RMSE: 5.98653
#
# Iter: 39
# Tolerance: 0.133861
# MAPE: 0.0751503
# RMSE: 6.08486
#
# Iter: 40
# Tolerance: 0.130655
# MAPE: 0.0742554
# RMSE: 6.04387
#
# Iter: 41
# Tolerance: 0.120922
# MAPE: 0.071996
# RMSE: 5.81424
#
# Iter: 42
# Tolerance: 0.132391
# MAPE: 0.0711318
# RMSE: 5.77577
#
# Iter: 43
# Tolerance: 0.122184
# MAPE: 0.0706192
# RMSE: 5.76335
#
# Iter: 44
# Tolerance: 0.124783
# MAPE: 0.0705864
# RMSE: 5.72711
#
# Iter: 45
# Tolerance: 0.144301
# MAPE: 0.071074
# RMSE: 5.75097
#
# Iter: 46
# Tolerance: 0.134482
# MAPE: 0.0672747
# RMSE: 5.44963
#
# Iter: 47
# Tolerance: 0.12445
# MAPE: 0.0688548
# RMSE: 5.53898
#
# Iter: 48
# Tolerance: 0.123968
# MAPE: 0.0693216
# RMSE: 5.58366
#
# Iter: 49
# Tolerance: 0.130789
# MAPE: 0.068486
# RMSE: 5.58682
#
# Iter: 50
# Tolerance: 0.131636
# MAPE: 0.0666753
# RMSE: 5.4801
#
# Iter: 51
# Tolerance: 0.118966
# MAPE: 0.0657902
# RMSE: 5.4315
#
# Iter: 52
# Tolerance: 0.123992
# MAPE: 0.064416
# RMSE: 5.39151
#
# Iter: 53
# Tolerance: 0.124075
# MAPE: 0.0649068
# RMSE: 5.45363
#
# Iter: 54
# Tolerance: 0.119945
# MAPE: 0.0636823
# RMSE: 5.3632
#
# Iter: 55
# Tolerance: 0.115451
# MAPE: 0.0627849
# RMSE: 5.29874
#
# Iter: 56
# Tolerance: 0.115869
# MAPE: 0.0622456
# RMSE: 5.25538
#
# Iter: 57
# Tolerance: 0.117314
# MAPE: 0.0634911
# RMSE: 5.34286
#
# Iter: 58
# Tolerance: 0.114536
# MAPE: 0.0626641
# RMSE: 5.27952
#
# Iter: 59
# Tolerance: 0.120708
# MAPE: 0.0627872
# RMSE: 5.28528
#
# Iter: 60
# Tolerance: 0.111064
# MAPE: 0.0616749
# RMSE: 5.20438
#
# Iter: 61
# Tolerance: 0.118307
# MAPE: 0.0624552
# RMSE: 5.25186
#
# Iter: 62
# Tolerance: 0.115275
# MAPE: 0.0618284
# RMSE: 5.21049
#
# Iter: 63
# Tolerance: 0.113926
# MAPE: 0.0613543
# RMSE: 5.17151
#
# Iter: 64
# Tolerance: 0.111972
# MAPE: 0.061532
# RMSE: 5.1761
#
# Iter: 65
# Tolerance: 0.110948
# MAPE: 0.0612091
# RMSE: 5.14737
#
# Iter: 66
# Tolerance: 0.108562
# MAPE: 0.061112
# RMSE: 5.14363
#
# Iter: 67
# Tolerance: 0.105444
# MAPE: 0.060352
# RMSE: 5.07518
#
# Iter: 68
# Tolerance: 0.106797
# MAPE: 0.0613361
# RMSE: 5.14693
#
# Iter: 69
# Tolerance: 0.101053
# MAPE: 0.0602298
# RMSE: 5.06317
#
# Iter: 70
# Tolerance: 0.0997715
# MAPE: 0.0601066
# RMSE: 5.05225
#
# Iter: 71
# Tolerance: 0.0991342
# MAPE: 0.0600738
# RMSE: 5.0527
#
# Iter: 72
# Tolerance: 0.0964656
# MAPE: 0.0598274
# RMSE: 5.03588
#
# Iter: 73
# Tolerance: 0.0920166
# MAPE: 0.0590341
# RMSE: 4.98124
#
# Iter: 74
# Tolerance: 0.0927477
# MAPE: 0.0591764
# RMSE: 4.99281
#
# Iter: 75
# Tolerance: 0.0882371
# MAPE: 0.0585845
# RMSE: 4.95518
#
# Iter: 76
# Tolerance: 0.0871242
# MAPE: 0.0583034
# RMSE: 4.9378
#
# Iter: 77
# Tolerance: 0.0856678
# MAPE: 0.0583441
# RMSE: 4.93995
#
# Iter: 78
# Tolerance: 0.083933
# MAPE: 0.057894
# RMSE: 4.91114
#
# Iter: 79
# Tolerance: 0.0815478
# MAPE: 0.0576963
# RMSE: 4.89984
#
# Iter: 80
# Tolerance: 0.0802596
# MAPE: 0.0574465
# RMSE: 4.88332
#
# Iter: 81
# Tolerance: 0.0780274
# MAPE: 0.0572131
# RMSE: 4.87004
#
# Iter: 82
# Tolerance: 0.0764375
# MAPE: 0.0569371
# RMSE: 4.85269
#
# Iter: 83
# Tolerance: 0.0750569
# MAPE: 0.056846
# RMSE: 4.844
#
# Iter: 84
# Tolerance: 0.072844
# MAPE: 0.0564537
# RMSE: 4.81719
#
# Iter: 85
# Tolerance: 0.0724091
# MAPE: 0.0564506
# RMSE: 4.81446
#
# Iter: 86
# Tolerance: 0.0697923
# MAPE: 0.0560779
# RMSE: 4.79182
#
# Iter: 87
# Tolerance: 0.0690357
# MAPE: 0.056086
# RMSE: 4.79084
#
# Iter: 88
# Tolerance: 0.0667988
# MAPE: 0.0557326
# RMSE: 4.76972
#
# Iter: 89
# Tolerance: 0.0662028
# MAPE: 0.0557661
# RMSE: 4.76979
#
# Iter: 90
# Tolerance: 0.0638298
# MAPE: 0.0554853
# RMSE: 4.75349
#
# Iter: 91
# Tolerance: 0.0628835
# MAPE: 0.0554571
# RMSE: 4.75014
#
# Iter: 92
# Tolerance: 0.0611451
# MAPE: 0.0552029
# RMSE: 4.73561
#
# Iter: 93
# Tolerance: 0.0603229
# MAPE: 0.0551958
# RMSE: 4.73495
#
# Iter: 94
# Tolerance: 0.0585315
# MAPE: 0.0550338
# RMSE: 4.72592
#
# Iter: 95
# Tolerance: 0.0571754
# MAPE: 0.0549582
# RMSE: 4.72191
#
# Iter: 96
# Tolerance: 0.0559275
# MAPE: 0.0548807
# RMSE: 4.71719
#
# Iter: 97
# Tolerance: 0.0544644
# MAPE: 0.0547972
# RMSE: 4.71333
#
# Iter: 98
# Tolerance: 0.0531994
# MAPE: 0.0547567
# RMSE: 4.71163
#
# Iter: 99
# Tolerance: 0.0522552
# MAPE: 0.0547345
# RMSE: 4.71082
#
# Iter: 100
# Tolerance: 0.0508328
# MAPE: 0.054685
# RMSE: 4.70843
#
# Total iteration: 100
# Tolerance: 0.0508328
# Imputation MAPE: 0.054685
# Imputation RMSE: 4.70843
#
# Running time: 465.34 minutes

# %% [markdown]
# ### PeMS-8W
#
# We generate **random missing (RM)** values on PeMS data set.

# %%
import time
import numpy as np
import pandas as pd
np.random.seed(1000)

data = pd.read_csv('../datasets/California-data-set/pems-8w.csv', header = None)
dense_tensor = mat2ten(data.values, np.array([data.values.shape[0], 288, 8 * 7]), 0)
random_tensor = np.random.rand(data.values.shape[0], 288, 8 * 7)

missing_rate = 0.3

### Random missing (RM) scenario:
sparse_tensor = np.multiply(dense_tensor, np.round(random_tensor + 0.5 - missing_rate))
del data, random_tensor

start = time.time()
alpha = np.ones(3) / 3
rho = 1e-4
theta = 0.05
epsilon = 1e-3
maxiter = 100
tensor_hat = LRTC(dense_tensor, sparse_tensor, alpha, rho, theta, epsilon, maxiter)
end = time.time()
print('Running time: %.2f minutes' % ((end - start)/60.0))
# Out:
# Iter: 1
# Tolerance: 0.15968
# MAPE: 0.806788
# RMSE: 51.8224
#
# Iter: 2
# Tolerance: 0.165518
# MAPE: 0.614269
# RMSE: 39.8896
#
# Iter: 3
# Tolerance: 0.14052
# MAPE: 0.435995
# RMSE: 28.9255
#
# Iter: 4
# Tolerance: 0.129915
# MAPE: 0.27316
# RMSE: 18.8238
#
# Iter: 5
# Tolerance: 0.111815
# MAPE: 0.141717
# RMSE: 10.4335
#
# Iter: 6
# Tolerance: 0.0891459
# MAPE: 0.0620955
# RMSE: 4.68434
#
# Iter: 7
# Tolerance: 0.0598619
# MAPE: 0.0621202
# RMSE: 4.32664
#
# Iter: 8
# Tolerance: 0.0406658
# MAPE: 0.0797526
# RMSE: 5.25488
#
# Iter: 9
# Tolerance: 0.034345
# MAPE: 0.0791059
# RMSE: 5.19637
#
# Iter: 10
# Tolerance: 0.0349264
# MAPE: 0.0653536
# RMSE: 4.36703
#
# Iter: 11
# Tolerance: 0.0356323
# MAPE: 0.0473857
# RMSE: 3.30191
#
# Iter: 12
# Tolerance: 0.0343215
# MAPE: 0.0322715
# RMSE: 2.44754
#
# Iter: 13
# Tolerance: 0.0321294
# MAPE: 0.0241542
# RMSE: 2.00267
#
# Iter: 14
# Tolerance: 0.0303282
# MAPE: 0.0214112
# RMSE: 1.83168
#
# Iter: 15
# Tolerance: 0.0289342
# MAPE: 0.0208294
# RMSE: 1.7797
#
# Iter: 16
# Tolerance: 0.0279787
# MAPE: 0.0201668
# RMSE: 1.73811
#
# Iter: 17
# Tolerance: 0.0267485
# MAPE: 0.0197632
# RMSE: 1.71853
#
# Iter: 18
# Tolerance: 0.0258189
# MAPE: 0.0192706
# RMSE: 1.69532
#
# Iter: 19
# Tolerance: 0.0244512
# MAPE: 0.0190984
# RMSE: 1.68854
#
# Iter: 20
# Tolerance: 0.0235406
# MAPE: 0.0188605
# RMSE: 1.67697
#
# Iter: 21
# Tolerance: 0.0222108
# MAPE: 0.0188017
# RMSE: 1.67501
#
# Iter: 22
# Tolerance: 0.0213294
# MAPE: 0.0186694
# RMSE: 1.66908
#
# Iter: 23
# Tolerance: 0.0202106
# MAPE: 0.0186187
# RMSE: 1.66759
#
# Iter: 24
# Tolerance: 0.0193518
# MAPE: 0.0185175
# RMSE: 1.66334
#
# Iter: 25
# Tolerance: 0.0184136
# MAPE: 0.0184796
# RMSE: 1.66252
#
# Iter: 26
# Tolerance: 0.0175522
# MAPE: 0.0184077
# RMSE: 1.65967
#
# Iter: 27
# Tolerance: 0.0166694
# MAPE: 0.0183674
# RMSE: 1.65832
#
# Iter: 28
# Tolerance: 0.0157847
# MAPE: 0.0183151
# RMSE: 1.65621
#
# Iter: 29
# Tolerance: 0.0148842
# MAPE: 0.0182778
# RMSE: 1.65475
#
# Iter: 30
# Tolerance: 0.0139773
# MAPE: 0.0182373
# RMSE: 1.65304
#
# Iter: 31
# Tolerance: 0.0130943
# MAPE: 0.018202
# RMSE: 1.65155
#
# Iter: 32
# Tolerance: 0.0122569
# MAPE: 0.0181726
# RMSE: 1.65038
#
# Iter: 33
# Tolerance: 0.0114664
# MAPE: 0.018145
# RMSE: 1.64931
#
# Iter: 34
# Tolerance: 0.0107199
# MAPE: 0.0181254
# RMSE: 1.64867
#
# Iter: 35
# Tolerance: 0.0100204
# MAPE: 0.0181057
# RMSE: 1.64805
#
# Iter: 36
# Tolerance: 0.00935851
# MAPE: 0.0180929
# RMSE: 1.64779
#
# Iter: 37
# Tolerance: 0.00874033
# MAPE: 0.0180796
# RMSE: 1.64752
#
# Iter: 38
# Tolerance: 0.00815561
# MAPE: 0.0180714
# RMSE: 1.64752
#
# Iter: 39
# Tolerance: 0.00761001
# MAPE: 0.0180629
# RMSE: 1.6475
#
# Iter: 40
# Tolerance: 0.00709514
# MAPE: 0.0180577
# RMSE: 1.64765
#
# Iter: 41
# Tolerance: 0.0066146
# MAPE: 0.0180526
# RMSE: 1.6478
#
# Iter: 42
# Tolerance: 0.0061625
# MAPE: 0.0180494
# RMSE: 1.64805
#
# Iter: 43
# Tolerance: 0.00574036
# MAPE: 0.0180466
# RMSE: 1.6483
#
# Iter: 44
# Tolerance: 0.00534427
# MAPE: 0.018045
# RMSE: 1.6486
#
# Iter: 45
# Tolerance: 0.00497425
# MAPE: 0.0180436
# RMSE: 1.64891
#
# Iter: 46
# Tolerance: 0.00462774
# MAPE: 0.0180431
# RMSE: 1.64925
#
# Iter: 47
# Tolerance: 0.004304
# MAPE: 0.0180428
# RMSE: 1.64959
#
# Iter: 48
# Tolerance: 0.00400131
# MAPE: 0.018043
# RMSE: 1.64994
#
# Iter: 49
# Tolerance: 0.00371875
# MAPE: 0.0180434
# RMSE: 1.65029
#
# Iter: 50
# Tolerance: 0.00345498
# MAPE: 0.0180441
# RMSE: 1.65065
#
# Iter: 51
# Tolerance: 0.00320911
# MAPE: 0.0180449
# RMSE: 1.651
#
# Iter: 52
# Tolerance: 0.0029799
# MAPE: 0.018046
# RMSE: 1.65135
#
# Iter: 53
# Tolerance: 0.00276649
# MAPE: 0.0180471
# RMSE: 1.65169
#
# Iter: 54
# Tolerance: 0.00256772
# MAPE: 0.0180484
# RMSE: 1.65204
#
# Iter: 55
# Tolerance: 0.00238275
# MAPE: 0.0180496
# RMSE: 1.65236
#
# Iter: 56
# Tolerance: 0.00221052
# MAPE: 0.0180511
# RMSE: 1.6527
#
# Iter: 57
# Tolerance: 0.00205025
# MAPE: 0.0180524
# RMSE: 1.65301
#
# Iter: 58
# Tolerance: 0.00190102
# MAPE: 0.018054
# RMSE: 1.65333
#
# Iter: 59
# Tolerance: 0.00176219
# MAPE: 0.0180553
# RMSE: 1.65362
#
# Iter: 60
# Tolerance: 0.001633
# MAPE: 0.0180568
# RMSE: 1.65392
#
# Iter: 61
# Tolerance: 0.00151294
# MAPE: 0.0180582
# RMSE: 1.65419
#
# Iter: 62
# Tolerance: 0.00140133
# MAPE: 0.0180597
# RMSE: 1.65447
#
# Iter: 63
# Tolerance: 0.00129773
# MAPE: 0.018061
# RMSE: 1.65473
#
# Iter: 64
# Tolerance: 0.00120149
# MAPE: 0.0180625
# RMSE: 1.65499
#
# Iter: 65
# Tolerance: 0.0011122
# MAPE: 0.0180637
# RMSE: 1.65523
#
# Iter: 66
# Tolerance: 0.00102927
# MAPE: 0.0180651
# RMSE: 1.65547
#
# Iter: 67
# Tolerance: 0.000952349
# MAPE: 0.0180663
# RMSE: 1.65569
#
# Total iteration: 67
# Tolerance: 0.000952349
# Imputation MAPE: 0.0180663
# Imputation RMSE: 1.65569
#
# Running time: 877.37 minutes

# %%
import time
import numpy as np
import pandas as pd
np.random.seed(1000)

data = pd.read_csv('../datasets/California-data-set/pems-8w.csv', header = None)
dense_tensor = mat2ten(data.values, np.array([data.values.shape[0], 288, 8 * 7]), 0)
random_tensor = np.random.rand(data.values.shape[0], 288, 8 * 7)

missing_rate = 0.7

### Random missing (RM) scenario:
sparse_tensor = np.multiply(dense_tensor, np.round(random_tensor + 0.5 - missing_rate))
del data, random_tensor

start = time.time()
alpha = np.ones(3) / 3
rho = 1e-4
theta = 0.05
epsilon = 1e-3
maxiter = 100
tensor_hat = LRTC(dense_tensor, sparse_tensor, alpha, rho, theta, epsilon, maxiter)
end = time.time()
print('Running time: %.2f minutes' % ((end - start)/60.0))
# Out:
# Iter: 1
# Tolerance: 0.243622
# MAPE: 0.916532
# RMSE: 58.7165
#
# Iter: 2
# Tolerance: 0.24178
# MAPE: 0.832558
# RMSE: 53.6622
#
# Iter: 3
# Tolerance: 0.154562
# MAPE: 0.753982
# RMSE: 49.0774
#
# Iter: 4
# Tolerance: 0.141411
# MAPE: 0.680861
# RMSE: 44.815
#
# Iter: 5
# Tolerance: 0.128172
# MAPE: 0.614093
# RMSE: 40.9515
#
# Iter: 6
# Tolerance: 0.117644
# MAPE: 0.552855
# RMSE: 37.3174
#
# Iter: 7
# Tolerance: 0.107875
# MAPE: 0.497379
# RMSE: 33.9646
#
# Iter: 8
# Tolerance: 0.100869
# MAPE: 0.446579
# RMSE: 30.7926
#
# Iter: 9
# Tolerance: 0.0933413
# MAPE: 0.400409
# RMSE: 27.8518
#
# Iter: 10
# Tolerance: 0.0874642
# MAPE: 0.357856
# RMSE: 25.0786
#
# Iter: 11
# Tolerance: 0.0810908
# MAPE: 0.318921
# RMSE: 22.5035
#
# Iter: 12
# Tolerance: 0.0760835
# MAPE: 0.282835
# RMSE: 20.0809
#
# Iter: 13
# Tolerance: 0.0708531
# MAPE: 0.249724
# RMSE: 17.8325
#
# Iter: 14
# Tolerance: 0.0667261
# MAPE: 0.218991
# RMSE: 15.7221
#
# Iter: 15
# Tolerance: 0.0623536
# MAPE: 0.190825
# RMSE: 13.7691
#
# Iter: 16
# Tolerance: 0.058876
# MAPE: 0.164751
# RMSE: 11.9452
#
# Iter: 17
# Tolerance: 0.0551433
# MAPE: 0.140958
# RMSE: 10.2688
#
# Iter: 18
# Tolerance: 0.0521095
# MAPE: 0.119072
# RMSE: 8.71828
#
# Iter: 19
# Tolerance: 0.048683
# MAPE: 0.0993375
# RMSE: 7.319
#
# Iter: 20
# Tolerance: 0.045624
# MAPE: 0.0815605
# RMSE: 6.06289
#
# Iter: 21
# Tolerance: 0.042118
# MAPE: 0.0660447
# RMSE: 4.98013
#
# Iter: 22
# Tolerance: 0.038385
# MAPE: 0.0530344
# RMSE: 4.09351
#
# Iter: 23
# Tolerance: 0.0339992
# MAPE: 0.0432008
# RMSE: 3.44202
#
# Iter: 24
# Tolerance: 0.0292273
# MAPE: 0.0371666
# RMSE: 3.03396
#
# Iter: 25
# Tolerance: 0.0245973
# MAPE: 0.0346762
# RMSE: 2.82481
#
# Iter: 26
# Tolerance: 0.0206109
# MAPE: 0.0340772
# RMSE: 2.73246
#
# Iter: 27
# Tolerance: 0.0175948
# MAPE: 0.0338576
# RMSE: 2.68397
#
# Iter: 28
# Tolerance: 0.0154697
# MAPE: 0.0333389
# RMSE: 2.63842
#
# Iter: 29
# Tolerance: 0.0140237
# MAPE: 0.0324083
# RMSE: 2.58366
#
# Iter: 30
# Tolerance: 0.0129808
# MAPE: 0.0311888
# RMSE: 2.52206
#
# Iter: 31
# Tolerance: 0.0121071
# MAPE: 0.0298943
# RMSE: 2.46181
#
# Iter: 32
# Tolerance: 0.0112759
# MAPE: 0.0287038
# RMSE: 2.40938
#
# Iter: 33
# Tolerance: 0.0104294
# MAPE: 0.0277457
# RMSE: 2.36847
#
# Iter: 34
# Tolerance: 0.00959582
# MAPE: 0.0270617
# RMSE: 2.33895
#
# Iter: 35
# Tolerance: 0.00878361
# MAPE: 0.0266299
# RMSE: 2.31904
#
# Iter: 36
# Tolerance: 0.00803543
# MAPE: 0.0263798
# RMSE: 2.30604
#
# Iter: 37
# Tolerance: 0.00734691
# MAPE: 0.026235
# RMSE: 2.29764
#
# Iter: 38
# Tolerance: 0.00673373
# MAPE: 0.0261371
# RMSE: 2.29212
#
# Iter: 39
# Tolerance: 0.00617732
# MAPE: 0.0260542
# RMSE: 2.28836
#
# Iter: 40
# Tolerance: 0.00567786
# MAPE: 0.0259759
# RMSE: 2.28581
#
# Iter: 41
# Tolerance: 0.00521781
# MAPE: 0.0259008
# RMSE: 2.28408
#
# Iter: 42
# Tolerance: 0.00479583
# MAPE: 0.0258345
# RMSE: 2.28307
#
# Iter: 43
# Tolerance: 0.00440211
# MAPE: 0.0257796
# RMSE: 2.28258
#
# Iter: 44
# Tolerance: 0.00403719
# MAPE: 0.0257397
# RMSE: 2.28256
#
# Iter: 45
# Tolerance: 0.00369724
# MAPE: 0.0257131
# RMSE: 2.28284
#
# Iter: 46
# Tolerance: 0.00338259
# MAPE: 0.0256984
# RMSE: 2.28337
#
# Iter: 47
# Tolerance: 0.00309188
# MAPE: 0.0256911
# RMSE: 2.28403
#
# Iter: 48
# Tolerance: 0.00282404
# MAPE: 0.0256891
# RMSE: 2.28479
#
# Iter: 49
# Tolerance: 0.00257837
# MAPE: 0.0256891
# RMSE: 2.28558
#
# Iter: 50
# Tolerance: 0.00235275
# MAPE: 0.0256905
# RMSE: 2.2864
#
# Iter: 51
# Tolerance: 0.00214664
# MAPE: 0.0256922
# RMSE: 2.2872
#
# Iter: 52
# Tolerance: 0.00195717
# MAPE: 0.0256945
# RMSE: 2.28799
#
# Iter: 53
# Tolerance: 0.001784
# MAPE: 0.0256971
# RMSE: 2.28876
#
# Iter: 54
# Tolerance: 0.00162404
# MAPE: 0.0257003
# RMSE: 2.2895
#
# Iter: 55
# Tolerance: 0.00147786
# MAPE: 0.025704
# RMSE: 2.29022
#
# Iter: 56
# Tolerance: 0.00134258
# MAPE: 0.0257082
# RMSE: 2.29091
#
# Iter: 57
# Tolerance: 0.00121944
# MAPE: 0.0257128
# RMSE: 2.29158
#
# Iter: 58
# Tolerance: 0.00110568
# MAPE: 0.0257174
# RMSE: 2.29221
#
# Iter: 59
# Tolerance: 0.00100262
# MAPE: 0.0257221
# RMSE: 2.29281
#
# Iter: 60
# Tolerance: 0.000907938
# MAPE: 0.0257267
# RMSE: 2.29338
#
# Total iteration: 60
# Tolerance: 0.000907938
# Imputation MAPE: 0.0257267
# Imputation RMSE: 2.29338
#
# Running time: 807.00 minutes

# %% [markdown]
# We generate **non-random missing (NM)** values on PeMS data set. Then, we conduct the imputation experiment.

# %%
import time
import numpy as np
import pandas as pd
np.random.seed(1000)

data = pd.read_csv('../datasets/California-data-set/pems-8w.csv', header = None)
dense_tensor = mat2ten(data.values, np.array([data.values.shape[0], 288, 8 * 7]), 0)
random_matrix = np.random.rand(data.values.shape[0], 8 * 7)

missing_rate = 0.3

### Non-random missing (NM) scenario:
binary_tensor = np.zeros(dense_tensor.shape)
for i1 in range(dense_tensor.shape[0]):
    for i2 in range(dense_tensor.shape[2]):
        binary_tensor[i1, :, i2] = np.round(random_matrix[i1, i2] + 0.5 - missing_rate)
sparse_tensor = np.multiply(dense_tensor, binary_tensor)
del data, random_matrix, binary_tensor

start = time.time()
alpha = np.ones(3) / 3
rho = 1e-5
theta = 0.05
epsilon = 1e-3
maxiter = 100
tensor_hat = LRTC(dense_tensor, sparse_tensor, alpha, rho, theta, epsilon, maxiter)
end = time.time()
print('Running time: %.2f minutes' % ((end - start)/60.0))
# Out:
# Iter: 1
# Tolerance: 0.12317
# MAPE: 0.867673
# RMSE: 55.3517
#
# Iter: 2
# Tolerance: 0.115052
# MAPE: 0.744081
# RMSE: 47.3842
#
# Iter: 3
# Tolerance: 0.101592
# MAPE: 0.626195
# RMSE: 39.7447
#
# Iter: 4
# Tolerance: 0.148729
# MAPE: 0.441145
# RMSE: 28.6189
#
# Iter: 5
# Tolerance: 0.143841
# MAPE: 0.316507
# RMSE: 20.6786
#
# Iter: 6
# Tolerance: 0.129217
# MAPE: 0.196263
# RMSE: 13.5911
#
# Iter: 7
# Tolerance: 0.106335
# MAPE: 0.0960332
# RMSE: 7.94286
#
# Iter: 8
# Tolerance: 0.0901724
# MAPE: 0.0755248
# RMSE: 6.05062
#
# Iter: 9
# Tolerance: 0.0826911
# MAPE: 0.0846522
# RMSE: 5.95276
#
# Iter: 10
# Tolerance: 0.0822369
# MAPE: 0.0757313
# RMSE: 5.48285
#
# Iter: 11
# Tolerance: 0.0836934
# MAPE: 0.063912
# RMSE: 4.9838
#
# Iter: 12
# Tolerance: 0.0858154
# MAPE: 0.0589949
# RMSE: 4.78313
#
# Iter: 13
# Tolerance: 0.0869298
# MAPE: 0.0590947
# RMSE: 4.78225
#
# Iter: 14
# Tolerance: 0.0882782
# MAPE: 0.0593871
# RMSE: 4.80297
#
# Iter: 15
# Tolerance: 0.0873945
# MAPE: 0.0594621
# RMSE: 4.82892
#
# Iter: 16
# Tolerance: 0.0876289
# MAPE: 0.0589578
# RMSE: 4.831
#
# Iter: 17
# Tolerance: 0.0878311
# MAPE: 0.0578941
# RMSE: 4.76193
#
# Iter: 18
# Tolerance: 0.0868255
# MAPE: 0.0580224
# RMSE: 4.78937
#
# Iter: 19
# Tolerance: 0.0873106
# MAPE: 0.0579442
# RMSE: 4.78176
#
# Iter: 20
# Tolerance: 0.0867324
# MAPE: 0.0578031
# RMSE: 4.76722
#
# Iter: 21
# Tolerance: 0.0849089
# MAPE: 0.0575796
# RMSE: 4.74351
#
# Iter: 22
# Tolerance: 0.0837086
# MAPE: 0.0570082
# RMSE: 4.69549
#
# Iter: 23
# Tolerance: 0.0828055
# MAPE: 0.0570762
# RMSE: 4.69287
#
# Iter: 24
# Tolerance: 0.0833522
# MAPE: 0.0567892
# RMSE: 4.66292
#
# Iter: 25
# Tolerance: 0.0821642
# MAPE: 0.0562945
# RMSE: 4.62004
#
# Iter: 26
# Tolerance: 0.0798175
# MAPE: 0.0558209
# RMSE: 4.58153
#
# Iter: 27
# Tolerance: 0.0786742
# MAPE: 0.0555034
# RMSE: 4.5547
#
# Iter: 28
# Tolerance: 0.0781503
# MAPE: 0.0552314
# RMSE: 4.53174
#
# Iter: 29
# Tolerance: 0.0770525
# MAPE: 0.0547595
# RMSE: 4.49293
#
# Iter: 30
# Tolerance: 0.0756228
# MAPE: 0.0542958
# RMSE: 4.45716
#
# Iter: 31
# Tolerance: 0.0742185
# MAPE: 0.0537737
# RMSE: 4.41433
#
# Iter: 32
# Tolerance: 0.0724008
# MAPE: 0.0533479
# RMSE: 4.3826
#
# Iter: 33
# Tolerance: 0.0713568
# MAPE: 0.0530027
# RMSE: 4.3544
#
# Iter: 34
# Tolerance: 0.0702601
# MAPE: 0.0525975
# RMSE: 4.32427
#
# Iter: 35
# Tolerance: 0.0689528
# MAPE: 0.0521383
# RMSE: 4.2874
#
# Iter: 36
# Tolerance: 0.067406
# MAPE: 0.0516666
# RMSE: 4.25305
#
# Iter: 37
# Tolerance: 0.0660627
# MAPE: 0.0513223
# RMSE: 4.22672
#
# Iter: 38
# Tolerance: 0.0649382
# MAPE: 0.0509352
# RMSE: 4.19791
#
# Iter: 39
# Tolerance: 0.0637711
# MAPE: 0.0505782
# RMSE: 4.17122
#
# Iter: 40
# Tolerance: 0.0624379
# MAPE: 0.0502327
# RMSE: 4.14398
#
# Iter: 41
# Tolerance: 0.061123
# MAPE: 0.0498763
# RMSE: 4.11927
#
# Iter: 42
# Tolerance: 0.0600069
# MAPE: 0.0495944
# RMSE: 4.09769
#
# Iter: 43
# Tolerance: 0.0587344
# MAPE: 0.0492184
# RMSE: 4.07148
#
# Iter: 44
# Tolerance: 0.0574631
# MAPE: 0.0489208
# RMSE: 4.05007
#
# Iter: 45
# Tolerance: 0.0562241
# MAPE: 0.0485696
# RMSE: 4.02556
#
# Iter: 46
# Tolerance: 0.0549681
# MAPE: 0.0482784
# RMSE: 4.00524
#
# Iter: 47
# Tolerance: 0.0533335
# MAPE: 0.0478952
# RMSE: 3.98121
#
# Iter: 48
# Tolerance: 0.0512338
# MAPE: 0.0474363
# RMSE: 3.95341
#
# Iter: 49
# Tolerance: 0.0493394
# MAPE: 0.0469989
# RMSE: 3.92746
#
# Iter: 50
# Tolerance: 0.0476949
# MAPE: 0.0465794
# RMSE: 3.90358
#
# Iter: 51
# Tolerance: 0.0461794
# MAPE: 0.0461855
# RMSE: 3.87994
#
# Iter: 52
# Tolerance: 0.0446444
# MAPE: 0.0458128
# RMSE: 3.85737
#
# Iter: 53
# Tolerance: 0.0431002
# MAPE: 0.0454514
# RMSE: 3.83506
#
# Iter: 54
# Tolerance: 0.0415352
# MAPE: 0.0450974
# RMSE: 3.81377
#
# Iter: 55
# Tolerance: 0.0399904
# MAPE: 0.0447771
# RMSE: 3.79443
#
# Iter: 56
# Tolerance: 0.0385083
# MAPE: 0.0444481
# RMSE: 3.77475
#
# Iter: 57
# Tolerance: 0.0370603
# MAPE: 0.0441331
# RMSE: 3.75592
#
# Iter: 58
# Tolerance: 0.0356895
# MAPE: 0.043827
# RMSE: 3.73772
#
# Iter: 59
# Tolerance: 0.034365
# MAPE: 0.0435426
# RMSE: 3.72126
#
# Iter: 60
# Tolerance: 0.0331185
# MAPE: 0.0432707
# RMSE: 3.70563
#
# Iter: 61
# Tolerance: 0.0319129
# MAPE: 0.0430299
# RMSE: 3.69225
#
# Iter: 62
# Tolerance: 0.0307757
# MAPE: 0.0428084
# RMSE: 3.67963
#
# Iter: 63
# Tolerance: 0.0296834
# MAPE: 0.0426167
# RMSE: 3.66913
#
# Iter: 64
# Tolerance: 0.0286461
# MAPE: 0.0424478
# RMSE: 3.66002
#
# Iter: 65
# Tolerance: 0.0276445
# MAPE: 0.0423065
# RMSE: 3.65241
#
# Iter: 66
# Tolerance: 0.0266598
# MAPE: 0.0421825
# RMSE: 3.64569
#
# Iter: 67
# Tolerance: 0.0256789
# MAPE: 0.0420829
# RMSE: 3.64047
#
# Iter: 68
# Tolerance: 0.0246879
# MAPE: 0.0419928
# RMSE: 3.63573
#
# Iter: 69
# Tolerance: 0.0237007
# MAPE: 0.0419188
# RMSE: 3.63181
#
# Iter: 70
# Tolerance: 0.0226958
# MAPE: 0.0418575
# RMSE: 3.62852
#
# Iter: 71
# Tolerance: 0.021706
# MAPE: 0.0418117
# RMSE: 3.626
#
# Iter: 72
# Tolerance: 0.0207204
# MAPE: 0.0417792
# RMSE: 3.62438
#
# Iter: 73
# Tolerance: 0.0197632
# MAPE: 0.0417574
# RMSE: 3.62309
#
# Iter: 74
# Tolerance: 0.0188288
# MAPE: 0.04175
# RMSE: 3.62281
#
# Iter: 75
# Tolerance: 0.0179075
# MAPE: 0.0417539
# RMSE: 3.623
#
# Iter: 76
# Tolerance: 0.016983
# MAPE: 0.0417683
# RMSE: 3.62403
#
# Iter: 77
# Tolerance: 0.0160438
# MAPE: 0.0417894
# RMSE: 3.62528
#
# Iter: 78
# Tolerance: 0.0150887
# MAPE: 0.0418176
# RMSE: 3.62718
#
# Iter: 79
# Tolerance: 0.0141296
# MAPE: 0.0418474
# RMSE: 3.629
#
# Iter: 80
# Tolerance: 0.013196
# MAPE: 0.0418818
# RMSE: 3.63134
#
# Iter: 81
# Tolerance: 0.0123051
# MAPE: 0.041916
# RMSE: 3.63353
#
# Iter: 82
# Tolerance: 0.0114614
# MAPE: 0.0419545
# RMSE: 3.63619
#
# Iter: 83
# Tolerance: 0.0106664
# MAPE: 0.0419922
# RMSE: 3.63871
#
# Iter: 84
# Tolerance: 0.00991796
# MAPE: 0.0420332
# RMSE: 3.6416
#
# Iter: 85
# Tolerance: 0.0092156
# MAPE: 0.0420734
# RMSE: 3.64438
#
# Iter: 86
# Tolerance: 0.00855677
# MAPE: 0.042116
# RMSE: 3.64743
#
# Iter: 87
# Tolerance: 0.0079401
# MAPE: 0.0421573
# RMSE: 3.65039
#
# Iter: 88
# Tolerance: 0.00736306
# MAPE: 0.0422002
# RMSE: 3.65351
#
# Iter: 89
# Tolerance: 0.00682408
# MAPE: 0.0422418
# RMSE: 3.65656
#
# Iter: 90
# Tolerance: 0.00632088
# MAPE: 0.0422841
# RMSE: 3.65971
#
# Iter: 91
# Tolerance: 0.00585186
# MAPE: 0.0423251
# RMSE: 3.66277
#
# Iter: 92
# Tolerance: 0.00541475
# MAPE: 0.0423661
# RMSE: 3.66587
#
# Iter: 93
# Tolerance: 0.00500791
# MAPE: 0.0424058
# RMSE: 3.6689
#
# Iter: 94
# Tolerance: 0.00462914
# MAPE: 0.0424452
# RMSE: 3.67192
#
# Iter: 95
# Tolerance: 0.00427698
# MAPE: 0.0424832
# RMSE: 3.67487
#
# Iter: 96
# Tolerance: 0.00394957
# MAPE: 0.0425205
# RMSE: 3.67777
#
# Iter: 97
# Tolerance: 0.00364563
# MAPE: 0.0425565
# RMSE: 3.68062
#
# Iter: 98
# Tolerance: 0.00336362
# MAPE: 0.0425915
# RMSE: 3.68338
#
# Iter: 99
# Tolerance: 0.00310221
# MAPE: 0.0426254
# RMSE: 3.68609
#
# Iter: 100
# Tolerance: 0.00286009
# MAPE: 0.042658
# RMSE: 3.68869
#
# Total iteration: 100
# Tolerance: 0.00286009
# Imputation MAPE: 0.042658
# Imputation RMSE: 3.68869
#
# Running time: 1302.68 minutes

# %%
import time
import numpy as np
import pandas as pd
np.random.seed(1000)

data = pd.read_csv('../datasets/California-data-set/pems-8w.csv', header = None)
dense_tensor = mat2ten(data.values, np.array([data.values.shape[0], 288, 8 * 7]), 0)
random_matrix = np.random.rand(data.values.shape[0], 8 * 7)

missing_rate = 0.7

### Non-random missing (NM) scenario:
binary_tensor = np.zeros(dense_tensor.shape)
for i1 in range(dense_tensor.shape[0]):
    for i2 in range(dense_tensor.shape[2]):
        binary_tensor[i1, :, i2] = np.round(random_matrix[i1, i2] + 0.5 - missing_rate)
sparse_tensor = np.multiply(dense_tensor, binary_tensor)
del data, random_matrix, binary_tensor

start = time.time()
alpha = np.ones(3) / 3
rho = 1e-6
theta = 0.05
epsilon = 1e-3
maxiter = 100
tensor_hat = LRTC(dense_tensor, sparse_tensor, alpha, rho, theta, epsilon, maxiter)
end = time.time()
print('Running time: %.2f minutes' % ((end - start)/60.0))
# Out:
# Iter: 1
# Tolerance: 0.671375
# MAPE: 1.0
# RMSE: 63.8232
#
# Iter: 2
# Tolerance: 0.723968
# MAPE: 0.611444
# RMSE: 39.9236
#
# Iter: 3
# Tolerance: 0.645231
# MAPE: 0.246217
# RMSE: 16.9267
#
# Iter: 4
# Tolerance: 0.562335
# MAPE: 0.219779
# RMSE: 14.2832
#
# Iter: 5
# Tolerance: 0.380154
# MAPE: 0.422896
# RMSE: 25.4146
#
# Iter: 6
# Tolerance: 0.199423
# MAPE: 0.526677
# RMSE: 30.9369
#
# Iter: 7
# Tolerance: 0.132041
# MAPE: 0.512379
# RMSE: 30.1968
#
# Iter: 8
# Tolerance: 0.192578
# MAPE: 0.414108
# RMSE: 25.2171
#
# Iter: 9
# Tolerance: 0.290839
# MAPE: 0.281561
# RMSE: 18.5201
#
# Iter: 10
# Tolerance: 0.28553
# MAPE: 0.193033
# RMSE: 13.2302
#
# Iter: 11
# Tolerance: 0.246134
# MAPE: 0.171317
# RMSE: 11.2589
#
# Iter: 12
# Tolerance: 0.245045
# MAPE: 0.174887
# RMSE: 11.5234
#
# Iter: 13
# Tolerance: 0.13918
# MAPE: 0.193542
# RMSE: 12.3715
#
# Iter: 14
# Tolerance: 0.124861
# MAPE: 0.186032
# RMSE: 12.2063
#
# Iter: 15
# Tolerance: 0.160521
# MAPE: 0.166248
# RMSE: 11.3429
#
# Iter: 16
# Tolerance: 0.191212
# MAPE: 0.141983
# RMSE: 10.1123
#
# Iter: 17
# Tolerance: 0.167704
# MAPE: 0.122834
# RMSE: 8.95309
#
# Iter: 18
# Tolerance: 0.123062
# MAPE: 0.118985
# RMSE: 8.61237
#
# Iter: 19
# Tolerance: 0.150309
# MAPE: 0.107357
# RMSE: 7.72068
#
# Iter: 20
# Tolerance: 0.166095
# MAPE: 0.103012
# RMSE: 7.13977
#
# Iter: 21
# Tolerance: 0.14523
# MAPE: 0.105887
# RMSE: 7.2772
#
# Iter: 22
# Tolerance: 0.140472
# MAPE: 0.112612
# RMSE: 7.629
#
# Iter: 23
# Tolerance: 0.162767
# MAPE: 0.107194
# RMSE: 7.52208
#
# Iter: 24
# Tolerance: 0.205746
# MAPE: 0.0861079
# RMSE: 6.3206
#
# Iter: 25
# Tolerance: 0.157515
# MAPE: 0.0841842
# RMSE: 6.2763
#
# Iter: 26
# Tolerance: 0.152284
# MAPE: 0.081963
# RMSE: 6.26653
#
# Iter: 27
# Tolerance: 0.160094
# MAPE: 0.0831442
# RMSE: 6.42608
#
# Iter: 28
# Tolerance: 0.135511
# MAPE: 0.0836186
# RMSE: 6.45469
#
# Iter: 29
# Tolerance: 0.149368
# MAPE: 0.0840057
# RMSE: 6.51245
#
# Iter: 30
# Tolerance: 0.202028
# MAPE: 0.0793928
# RMSE: 6.28138
#
# Iter: 31
# Tolerance: 0.174567
# MAPE: 0.0761536
# RMSE: 6.07152
#
# Iter: 32
# Tolerance: 0.15264
# MAPE: 0.0742562
# RMSE: 5.97273
#
# Iter: 33
# Tolerance: 0.153122
# MAPE: 0.0714673
# RMSE: 5.73455
#
# Iter: 34
# Tolerance: 0.145831
# MAPE: 0.0771765
# RMSE: 6.11239
#
# Iter: 35
# Tolerance: 0.135584
# MAPE: 0.0758119
# RMSE: 5.85681
#
# Iter: 36
# Tolerance: 0.14812
# MAPE: 0.078039
# RMSE: 6.07871
#
# Iter: 37
# Tolerance: 0.154107
# MAPE: 0.0723065
# RMSE: 5.75269
#
# Iter: 38
# Tolerance: 0.144011
# MAPE: 0.0685725
# RMSE: 5.54903
#
# Iter: 39
# Tolerance: 0.117698
# MAPE: 0.067708
# RMSE: 5.55029
#
# Iter: 40
# Tolerance: 0.121046
# MAPE: 0.0676895
# RMSE: 5.55395
#
# Iter: 41
# Tolerance: 0.133632
# MAPE: 0.06736
# RMSE: 5.57016
#
# Iter: 42
# Tolerance: 0.121189
# MAPE: 0.0665353
# RMSE: 5.53139
#
# Iter: 43
# Tolerance: 0.115786
# MAPE: 0.0657686
# RMSE: 5.45712
#
# Iter: 44
# Tolerance: 0.12352
# MAPE: 0.0664364
# RMSE: 5.53465
#
# Iter: 45
# Tolerance: 0.123324
# MAPE: 0.0657808
# RMSE: 5.51076
#
# Iter: 46
# Tolerance: 0.120729
# MAPE: 0.0638778
# RMSE: 5.35661
#
# Iter: 47
# Tolerance: 0.114122
# MAPE: 0.0640696
# RMSE: 5.36202
#
# Iter: 48
# Tolerance: 0.109572
# MAPE: 0.0641467
# RMSE: 5.33563
#
# Iter: 49
# Tolerance: 0.11393
# MAPE: 0.0647635
# RMSE: 5.38621
#
# Iter: 50
# Tolerance: 0.118434
# MAPE: 0.0644984
# RMSE: 5.36384
#
# Iter: 51
# Tolerance: 0.115491
# MAPE: 0.064114
# RMSE: 5.33404
#
# Iter: 52
# Tolerance: 0.117276
# MAPE: 0.0640513
# RMSE: 5.3357
#
# Iter: 53
# Tolerance: 0.11394
# MAPE: 0.0634237
# RMSE: 5.30248
#
# Iter: 54
# Tolerance: 0.115855
# MAPE: 0.0631348
# RMSE: 5.29558
#
# Iter: 55
# Tolerance: 0.114983
# MAPE: 0.0626377
# RMSE: 5.25519
#
# Iter: 56
# Tolerance: 0.111831
# MAPE: 0.0616395
# RMSE: 5.18637
#
# Iter: 57
# Tolerance: 0.112265
# MAPE: 0.0619125
# RMSE: 5.20328
#
# Iter: 58
# Tolerance: 0.113101
# MAPE: 0.0620325
# RMSE: 5.2139
#
# Iter: 59
# Tolerance: 0.108008
# MAPE: 0.0615085
# RMSE: 5.16336
#
# Iter: 60
# Tolerance: 0.107361
# MAPE: 0.0612293
# RMSE: 5.13877
#
# Iter: 61
# Tolerance: 0.106871
# MAPE: 0.0618407
# RMSE: 5.17415
#
# Iter: 62
# Tolerance: 0.102999
# MAPE: 0.0606787
# RMSE: 5.08491
#
# Iter: 63
# Tolerance: 0.104345
# MAPE: 0.0612867
# RMSE: 5.11933
#
# Iter: 64
# Tolerance: 0.10038
# MAPE: 0.0607284
# RMSE: 5.07702
#
# Iter: 65
# Tolerance: 0.0971464
# MAPE: 0.0601679
# RMSE: 5.03417
#
# Iter: 66
# Tolerance: 0.0970442
# MAPE: 0.0599223
# RMSE: 5.01334
#
# Iter: 67
# Tolerance: 0.0965874
# MAPE: 0.0600529
# RMSE: 5.01499
#
# Iter: 68
# Tolerance: 0.0932022
# MAPE: 0.0591034
# RMSE: 4.95084
#
# Iter: 69
# Tolerance: 0.0922702
# MAPE: 0.0590961
# RMSE: 4.94415
#
# Iter: 70
# Tolerance: 0.0905733
# MAPE: 0.0586168
# RMSE: 4.91364
#
# Iter: 71
# Tolerance: 0.0893639
# MAPE: 0.0585375
# RMSE: 4.90049
#
# Iter: 72
# Tolerance: 0.086253
# MAPE: 0.0579202
# RMSE: 4.85863
#
# Iter: 73
# Tolerance: 0.0851463
# MAPE: 0.0578443
# RMSE: 4.84881
#
# Iter: 74
# Tolerance: 0.0835598
# MAPE: 0.0574429
# RMSE: 4.82256
#
# Iter: 75
# Tolerance: 0.0822713
# MAPE: 0.0572449
# RMSE: 4.80469
#
# Iter: 76
# Tolerance: 0.0798223
# MAPE: 0.0567976
# RMSE: 4.77242
#
# Iter: 77
# Tolerance: 0.0789715
# MAPE: 0.056625
# RMSE: 4.75777
#
# Iter: 78
# Tolerance: 0.0769104
# MAPE: 0.0562241
# RMSE: 4.732
#
# Iter: 79
# Tolerance: 0.0754545
# MAPE: 0.0559763
# RMSE: 4.7115
#
# Iter: 80
# Tolerance: 0.0738197
# MAPE: 0.0556781
# RMSE: 4.69126
#
# Iter: 81
# Tolerance: 0.0725836
# MAPE: 0.0554738
# RMSE: 4.67505
#
# Iter: 82
# Tolerance: 0.0712752
# MAPE: 0.0552482
# RMSE: 4.65946
#
# Iter: 83
# Tolerance: 0.0693852
# MAPE: 0.0550057
# RMSE: 4.64198
#
# Iter: 84
# Tolerance: 0.0682686
# MAPE: 0.0548348
# RMSE: 4.63072
#
# Iter: 85
# Tolerance: 0.0663328
# MAPE: 0.0546038
# RMSE: 4.61518
#
# Iter: 86
# Tolerance: 0.0652594
# MAPE: 0.0544645
# RMSE: 4.60526
#
# Iter: 87
# Tolerance: 0.0638425
# MAPE: 0.0543209
# RMSE: 4.59436
#
# Iter: 88
# Tolerance: 0.0624965
# MAPE: 0.0541598
# RMSE: 4.58382
#
# Iter: 89
# Tolerance: 0.0610121
# MAPE: 0.0540295
# RMSE: 4.57535
#
# Iter: 90
# Tolerance: 0.0600056
# MAPE: 0.0539194
# RMSE: 4.56805
#
# Iter: 91
# Tolerance: 0.0582413
# MAPE: 0.0537776
# RMSE: 4.55911
#
# Iter: 92
# Tolerance: 0.0571598
# MAPE: 0.0537001
# RMSE: 4.55425
#
# Iter: 93
# Tolerance: 0.055768
# MAPE: 0.0535812
# RMSE: 4.54696
#
# Iter: 94
# Tolerance: 0.0545033
# MAPE: 0.0534999
# RMSE: 4.54217
#
# Iter: 95
# Tolerance: 0.053108
# MAPE: 0.0533942
# RMSE: 4.53642
#
# Iter: 96
# Tolerance: 0.0519161
# MAPE: 0.0533421
# RMSE: 4.53318
#
# Iter: 97
# Tolerance: 0.0507617
# MAPE: 0.0532854
# RMSE: 4.52975
#
# Iter: 98
# Tolerance: 0.0493674
# MAPE: 0.0532071
# RMSE: 4.52541
#
# Iter: 99
# Tolerance: 0.048274
# MAPE: 0.0531718
# RMSE: 4.52408
#
# Iter: 100
# Tolerance: 0.0469458
# MAPE: 0.0531097
# RMSE: 4.52065
#
# Total iteration: 100
# Tolerance: 0.0469458
# Imputation MAPE: 0.0531097
# Imputation RMSE: 4.52065
#
# Running time: 1307.53 minutes

# %% [markdown]
# ### License
#
# <div class="alert alert-block alert-danger">
# <b>This work is released under the MIT license.</b>
# </div>
