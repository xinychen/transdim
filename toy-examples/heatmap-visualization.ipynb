# %%
import numpy as np

State = True
if State == True:
    rmse_mat_als = np.array([[4.83, 5.18, 5.51, 5.80, 6.04],
                             [4.38, 4.41, 4.49, 4.57, 4.66], 
                             [4.29, 4.28, 4.31, 4.37, 4.45], 
                             [4.26, 4.24, 4.27, 4.33, 4.41], 
                             [4.25, 4.23, 4.28, 4.34, 4.41], 
                             [4.26, 4.25, 4.30, 4.36, 4.44]])
    rmse_mat_svd = np.array([[4.04, 3.85, 3.72, 3.64, 3.61],
                             [4.07, 3.90, 3.80, 3.76, 3.76],
                             [4.09, 3.95, 3.89, 3.87, 3.87],
                             [4.12, 4.00, 3.96, 3.95, 3.97],
                             [4.15, 4.05, 4.02, 4.02, 4.04], 
                             [4.17, 4.09, 4.07, 4.07, 4.09]])
    
    import matplotlib.pyplot as plt
    import matplotlib.patches as patches

    plt.style.use('classic')
    plt.rcParams['font.family'] = 'Arial'
    fig = plt.figure(figsize=(4.5, 4))
    ax = fig.add_subplot(1, 1, 1)
    mark = ['o', '^', 'v', '*', 'd']
    for i in range(5):
        plt.plot(rmse_mat_als[:, i], 'red', marker = mark[i], alpha = 0.7, linewidth = 1)
    for i in range(5):
        plt.plot(rmse_mat_svd[:, i], 'orange', marker = mark[i], alpha = 0.95, linewidth = 1)
    ax.set_xlim([-0.2, 5.2])
    ax.set_ylim([3.5, 6.1])

    plt.xticks(np.arange(0, 6, 1))
    ax.set_xticklabels(np.arange(1, 7, 1))
    ax.set_xlabel("Order")
    ax.set_ylabel("RMSE")
    ax.grid(color = 'gray', linestyle = '-', linewidth = 0.2, alpha = 0.5)
    plt.legend(['ALS: R = 200', 'ALS: R = 400', 'ALS: R = 600', 'ALS: R = 800', 'ALS: R = 1000',
                'SVD: R = 200', 'SVD: R = 400', 'SVD: R = 600', 'SVD: R = 800', 'SVD: R = 1000'], 
               bbox_to_anchor = (1.05, 1), loc = 'upper left', fontsize='small')
    plt.show()
    fig.savefig("../large-predictor/rmse_delta1.pdf", bbox_inches = 'tight')

# %%
import numpy as np

State = True
if State == True:
    rmse_mat_als = np.array([[4.89, 5.14, 5.33, 5.45, 5.56],
                             [4.63, 4.74, 4.85, 4.94, 5.02], 
                             [4.58, 4.69, 4.79, 4.87, 4.95], 
                             [4.56, 4.68, 4.77, 4.86, 4.94], 
                             [4.57, 4.68, 4.78, 4.87, 4.95], 
                             [4.57, 4.68, 4.79, 4.87, 4.95]])
    rmse_mat_svd = np.array([[4.42, 4.44, 4.48, 4.52, 4.56],
                             [4.43, 4.48, 4.55, 4.61, 4.66],
                             [4.45, 4.51, 4.59, 4.66, 4.72],
                             [4.46, 4.53, 4.63, 4.70, 4.76],
                             [4.47, 4.56, 4.65, 4.72, 4.78], 
                             [4.48, 4.57, 4.66, 4.73, 4.79]])
    
    import matplotlib.pyplot as plt
    import matplotlib.patches as patches

    plt.style.use('classic')
    plt.rcParams['font.family'] = 'Arial'
    fig = plt.figure(figsize=(4.5, 4))
    ax = fig.add_subplot(1, 1, 1)
    mark = ['o', '^', 'v', '*', 'd']
    for i in range(5):
        plt.plot(rmse_mat_als[:, i], 'red', marker = mark[i], alpha = 0.7, linewidth = 1)
    for i in range(5):
        plt.plot(rmse_mat_svd[:, i], 'orange', marker = mark[i], alpha = 0.95, linewidth = 1)
    ax.set_xlim([-0.2, 5.2])
    ax.set_ylim([4.2, 5.6])

    plt.xticks(np.arange(0, 6, 1))
    ax.set_xticklabels(np.arange(1, 7, 1))
    ax.set_xlabel("Order")
    ax.set_ylabel("RMSE")
    ax.grid(color = 'gray', linestyle = '-', linewidth = 0.2, alpha = 0.5)
    plt.legend(['ALS: R = 200', 'ALS: R = 400', 'ALS: R = 600', 'ALS: R = 800', 'ALS: R = 1000',
                'SVD: R = 200', 'SVD: R = 400', 'SVD: R = 600', 'SVD: R = 800', 'SVD: R = 1000'], 
               bbox_to_anchor = (1.05, 1), loc = 'upper left', fontsize='small')
    plt.show()
    fig.savefig("../large-predictor/rmse_delta12.pdf", bbox_inches = 'tight')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

rmse_mat_als = np.array([[4.83, 5.18, 5.51, 5.80, 6.04],
                         [4.38, 4.41, 4.49, 4.57, 4.66], 
                         [4.29, 4.28, 4.31, 4.37, 4.45], 
                         [4.26, 4.24, 4.27, 4.33, 4.41], 
                         [4.25, 4.23, 4.28, 4.34, 4.41], 
                         [4.26, 4.25, 4.30, 4.36, 4.44]])
rmse_mat_svd = np.array([[4.04, 3.85, 3.72, 3.64, 3.61],
                         [4.07, 3.90, 3.80, 3.76, 3.76],
                         [4.09, 3.95, 3.89, 3.87, 3.87],
                         [4.12, 4.00, 3.96, 3.95, 3.97],
                         [4.15, 4.05, 4.02, 4.02, 4.04]])

df = pd.DataFrame(rmse_mat_als, index = [1, 2, 3, 4, 5, 6], columns = [200, 400, 600, 800, 1000])

fig, ax = plt.subplots(figsize = (4, 3.5))
plt.style.use('classic')
plt.style.use('ggplot')
plt.style.use('bmh')
plt.rcParams['font.family'] = 'Arial'
ax = sns.heatmap(df, annot = True, fmt = '.4g', linewidths = .1, vmin = 3.3, vmax = 4.5)
plt.yticks(rotation = 0)
plt.xlabel(r'Low rank $R$')
plt.ylabel(r'Order $d$')
plt.show()
# fig.savefig("4w_rmse_als_delta1.pdf", bbox_inches = 'tight')

df = pd.DataFrame(rmse_mat_svd, index = [1, 2, 3, 4, 5], columns = [200, 400, 600, 800, 1000])

fig, ax = plt.subplots(figsize = (4, 3.5))
plt.style.use('classic')
plt.style.use('ggplot')
plt.style.use('bmh')
plt.rcParams['font.family'] = 'Arial'
ax = sns.heatmap(df, annot = True, fmt = '.4g', linewidths = .1, vmin = 3.3, vmax = 4.5)
plt.yticks(rotation = 0)
plt.xlabel(r'Low rank $R$')
plt.ylabel(r'Order $d$')
plt.show()
# fig.savefig("4w_rmse_svd_delta1.pdf", bbox_inches = 'tight')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# On Guangzhou data set
G_30rm_rmse = np.array([[3.28, 3.18, 3.10, 3.04, 3.01, 2.99],   # c = 1/10
                        [3.26, 3.16, 3.08, 3.02, 2.99, 2.97],   # c = 1/5
                        [3.13, 3.03, 2.96, 2.91, 2.87, 2.85],   # c = 1
                        [2.76, 2.71, 2.67, 2.64, 2.62, 2.61],   # c = 5
                        [2.62, 2.59, 2.57, 2.56, 2.55, 2.54]])  # c = 10
df = pd.DataFrame(G_30rm_rmse, index = [r'$\frac{1}{10}$', r'$\frac{1}{5}$', 1, 5, 10], 
                  columns = [5, 10, 15, 20, 25, 30])

fig, ax = plt.subplots(figsize = (4.5, 3))
# plt.style.use('classic')
# plt.style.use('ggplot')
plt.style.use('bmh')
plt.rcParams['font.family'] = 'Arial'
ax = sns.heatmap(df, annot = True, fmt = '.4g', linewidths = .1, vmin = 2.0, vmax = 3.5)
plt.yticks(rotation = 0)
plt.xlabel(r'Truncation parameter $r$')
plt.ylabel(r'Coefficient $c=\lambda/\rho$')
plt.show()
fig.savefig("G_30rm_rmse.pdf", bbox_inches = 'tight')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# On Guangzhou data set
G_70rm_rmse = np.array([[3.85, 3.70, 3.62, 3.59, 3.61, 3.67],   # c = 1/10
                        [3.84, 3.69, 3.61, 3.58, 3.60, 3.64],   # c = 1/5
                        [3.76, 3.61, 3.53, 3.49, 3.49, 3.51],   # c = 1
                        [3.47, 3.37, 3.30, 3.27, 3.26, 3.27],   # c = 5
                        [3.30, 3.23, 3.19, 3.18, 3.18, 3.19]])  # c = 10
df = pd.DataFrame(G_70rm_rmse, index = [r'$\frac{1}{10}$', r'$\frac{1}{5}$', 1, 5, 10], 
                  columns = [5, 10, 15, 20, 25, 30])

fig, ax = plt.subplots(figsize = (4.5, 3))
# plt.style.use('classic')
# plt.style.use('ggplot')
plt.style.use('bmh')
plt.rcParams['font.family'] = 'Arial'
ax = sns.heatmap(df, annot = True, fmt = '.4g', linewidths = .1, vmin = 2.5, vmax = 4.0)
plt.yticks(rotation = 0)
plt.xlabel(r'Truncation parameter $r$')
plt.ylabel(r'Coefficient $c=\lambda/\rho$')
plt.show()
fig.savefig("G_70rm_rmse.pdf", bbox_inches = 'tight')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# On Guangzhou data set
G_90rm_rmse = np.array([[4.29, 4.09, 4.10, 4.18, 4.30, 4.45],   # c = 1/10
                        [4.28, 4.09, 4.07, 4.15, 4.26, 4.39],   # c = 1/5
                        [4.24, 4.05, 4.00, 4.05, 4.10, 4.19],   # c = 1
                        [4.14, 3.97, 3.91, 3.92, 3.95, 4.01],   # c = 5
                        [4.06, 3.91, 3.86, 3.88, 3.92, 3.98]])  # c = 10
df = pd.DataFrame(G_90rm_rmse, index = [r'$\frac{1}{10}$', r'$\frac{1}{5}$', 1, 5, 10], 
                  columns = [5, 10, 15, 20, 25, 30])

fig, ax = plt.subplots(figsize = (4.5, 3))
# plt.style.use('classic')
# plt.style.use('ggplot')
plt.style.use('bmh')
plt.rcParams['font.family'] = 'Arial'
ax = sns.heatmap(df, annot = True, fmt = '.4g', linewidths = .1, vmin = 3.5, vmax = 4.5)
plt.yticks(rotation = 0)
plt.xlabel(r'Truncation parameter $r$')
plt.ylabel(r'Coefficient $c=\lambda/\rho$')
plt.show()
fig.savefig("G_90rm_rmse.pdf", bbox_inches = 'tight')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# On Guangzhou data set
G_30nm_rmse = np.array([[4.13, 4.09, 4.11, 4.19, 4.28, 4.41],   # c = 1/10
                        [4.13, 4.09, 4.11, 4.18, 4.28, 4.41],   # c = 1/5
                        [4.13, 4.09, 4.11, 4.18, 4.28, 4.40],   # c = 1
                        [4.13, 4.09, 4.10, 4.17, 4.26, 4.38],   # c = 5
                        [4.13, 4.09, 4.10, 4.17, 4.25, 4.35]])  # c = 10
df = pd.DataFrame(G_30nm_rmse, index = [r'$\frac{1}{10}$', r'$\frac{1}{5}$', 1, 5, 10], 
                  columns = [5, 10, 15, 20, 25, 30])

fig, ax = plt.subplots(figsize = (4.5, 3))
# plt.style.use('classic')
# plt.style.use('ggplot')
plt.style.use('bmh')
plt.rcParams['font.family'] = 'Arial'
ax = sns.heatmap(df, annot = True, fmt = '.4g', linewidths = .1, vmin = 4, vmax = 4.5)
plt.yticks(rotation = 0)
plt.xlabel(r'Truncation parameter $r$')
plt.ylabel(r'Coefficient $c=\lambda/\rho$')
plt.show()
fig.savefig("G_30nm_rmse.pdf", bbox_inches = 'tight')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# On Guangzhou data set
G_70nm_rmse = np.array([[4.35, 4.38, 4.57, 4.69, 4.89, 5.06],   # c = 1/10
                        [4.35, 4.37, 4.55, 4.71, 4.91, 5.06],   # c = 1/5
                        [4.35, 4.37, 4.52, 4.70, 4.87, 5.05],   # c = 1
                        [4.35, 4.37, 4.51, 4.70, 4.83, 5.02],   # c = 5
                        [4.35, 4.37, 4.53, 4.65, 4.83, 4.95]])  # c = 10
df = pd.DataFrame(G_70nm_rmse, index = [r'$\frac{1}{10}$', r'$\frac{1}{5}$', 1, 5, 10], 
                  columns = [5, 10, 15, 20, 25, 30])

fig, ax = plt.subplots(figsize = (4.5, 3))
# plt.style.use('classic')
# plt.style.use('ggplot')
plt.style.use('bmh')
plt.rcParams['font.family'] = 'Arial'
ax = sns.heatmap(df, annot = True, fmt = '.4g', linewidths = .1, vmin = 4, vmax = 5.5)
plt.yticks(rotation = 0)
plt.xlabel(r'Truncation parameter $r$')
plt.ylabel(r'Coefficient $c=\lambda/\rho$')
plt.show()
fig.savefig("G_70nm_rmse.pdf", bbox_inches = 'tight')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# On Guangzhou data set
G_30bm_rmse = np.array([[4.08, 3.98, 3.99, 4.03, 4.10, 4.19],   # c = 1/10
                        [4.08, 3.98, 3.99, 4.03, 4.09, 4.19],   # c = 1/5
                        [4.07, 3.97, 3.98, 4.01, 4.07, 4.16],   # c = 1
                        [4.05, 3.94, 3.95, 3.97, 4.01, 4.08],   # c = 5
                        [4.02, 3.92, 3.91, 3.93, 3.96, 4.02]])  # c = 10
df = pd.DataFrame(G_30bm_rmse, index = [r'$\frac{1}{10}$', r'$\frac{1}{5}$', 1, 5, 10], 
                  columns = [5, 10, 15, 20, 25, 30])

fig, ax = plt.subplots(figsize = (4.5, 3))
# plt.style.use('classic')
# plt.style.use('ggplot')
plt.style.use('bmh')
plt.rcParams['font.family'] = 'Arial'
ax = sns.heatmap(df, annot = True, fmt = '.4g', linewidths = .1, vmin = 3.7, vmax = 4.5)
plt.yticks(rotation = 0)
plt.xlabel(r'Truncation parameter $r$')
plt.ylabel(r'Coefficient $c=\lambda/\rho$')
plt.show()
fig.savefig("G_30bm_rmse.pdf", bbox_inches = 'tight')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# On Hangzhou data set
H_30rm_rmse = np.array([[25.52, 25.54, 26.30, 28.14],   # c = 1/10
                        [25.47, 25.41, 25.92, 27.65],   # c = 1/5
                        [25.33, 25.08, 24.97, 26.36],   # c = 1
                        [26.06, 25.99, 26.40, 27.52],   # c = 5
                        [27.22, 27.36, 27.94, 28.95]])  # c = 10
df = pd.DataFrame(H_30rm_rmse, index = [r'$\frac{1}{10}$', r'$\frac{1}{5}$', 1, 5, 10], 
                  columns = [5, 10, 15, 20])

fig, ax = plt.subplots(figsize = (4, 2.8))
# plt.style.use('classic')
# plt.style.use('ggplot')
plt.style.use('bmh')
plt.rcParams['font.family'] = 'Arial'
ax = sns.heatmap(df, annot = True, fmt = '.4g', linewidths = .1, vmin = 20, vmax = 35)
plt.yticks(rotation = 0)
plt.xlabel(r'Truncation parameter $r$')
plt.ylabel(r'Coefficient $c=\lambda/\rho$')
plt.show()
fig.savefig("H_30rm_rmse.pdf", bbox_inches = 'tight')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# On Hangzhou data set
H_70rm_rmse = np.array([[28.57, 28.83, 29.65, 31.19],   # c = 1/10
                        [28.53, 28.44, 29.56, 31.09],   # c = 1/5
                        [28.45, 28.25, 29.43, 31.37],   # c = 1
                        [29.30, 29.86, 31.38, 33.48],   # c = 5
                        [30.29, 31.06, 32.78, 34.82]])  # c = 10
df = pd.DataFrame(H_70rm_rmse, index = [r'$\frac{1}{10}$', r'$\frac{1}{5}$', 1, 5, 10], 
                  columns = [5, 10, 15, 20])

fig, ax = plt.subplots(figsize = (4, 2.8))
# plt.style.use('classic')
# plt.style.use('ggplot')
plt.style.use('bmh')
plt.rcParams['font.family'] = 'Arial'
ax = sns.heatmap(df, annot = True, fmt = '.4g', linewidths = .1, vmin = 20, vmax = 35)
plt.yticks(rotation = 0)
plt.xlabel(r'Truncation parameter $r$')
plt.ylabel(r'Coefficient $c=\lambda/\rho$')
plt.show()
fig.savefig("H_70rm_rmse.pdf", bbox_inches = 'tight')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# On Hangzhou data set
H_90rm_rmse = np.array([[36.19, 34.81, 36.55, 37.83],   # c = 1/10
                        [36.23, 34.68, 36.74, 37.86],   # c = 1/5
                        [35.21, 34.44, 35.90, 37.30],   # c = 1
                        [36.26, 36.22, 37.83, 39.56],   # c = 5
                        [36.91, 38.55, 43.34, 47.39]])  # c = 10
df = pd.DataFrame(H_90rm_rmse, index = [r'$\frac{1}{10}$', r'$\frac{1}{5}$', 1, 5, 10], 
                  columns = [5, 10, 15, 20])

fig, ax = plt.subplots(figsize = (4, 2.8))
# plt.style.use('classic')
# plt.style.use('ggplot')
plt.style.use('bmh')
plt.rcParams['font.family'] = 'Arial'
ax = sns.heatmap(df, annot = True, fmt = '.4g', linewidths = .1, vmin = 25, vmax = 50)
plt.yticks(rotation = 0)
plt.xlabel(r'Truncation parameter $r$')
plt.ylabel(r'Coefficient $c=\lambda/\rho$')
plt.show()
fig.savefig("H_90rm_rmse.pdf", bbox_inches = 'tight')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# On Hangzhou data set
H_30nm_rmse = np.array([[47.38, 50.15, 50.33, 52.28],   # c = 1/10
                        [47.44, 50.42, 49.57, 52.34],   # c = 1/5
                        [48.53, 53.50, 54.54, 56.78],   # c = 1
                        [57.04, 61.80, 64.46, 65.67],   # c = 5
                        [64.00, 68.28, 72.01, 73.43]])  # c = 10
df = pd.DataFrame(H_30nm_rmse, index = [r'$\frac{1}{10}$', r'$\frac{1}{5}$', 1, 5, 10], 
                  columns = [5, 10, 15, 20])

fig, ax = plt.subplots(figsize = (4, 2.8))
# plt.style.use('classic')
# plt.style.use('ggplot')
plt.style.use('bmh')
plt.rcParams['font.family'] = 'Arial'
ax = sns.heatmap(df, annot = True, fmt = '.4g', linewidths = .1, vmin = 40, vmax = 60)
plt.yticks(rotation = 0)
plt.xlabel(r'Truncation parameter $r$')
plt.ylabel(r'Coefficient $c=\lambda/\rho$')
plt.show()
fig.savefig("H_30nm_rmse.pdf", bbox_inches = 'tight')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# On Hangzhou data set
H_70nm_rmse = np.array([[47.53, 50.98, 52.75, 54.28],   # c = 1/10
                        [47.30, 50.89, 52.46, 53.69],   # c = 1/5
                        [51.16, 55.55, 56.07, 56.91],   # c = 1
                        [67.11, 70.73, 71.38, 72.32],   # c = 5
                        [110.73, 111.84, 112.77, 113.57]])  # c = 10
df = pd.DataFrame(H_70nm_rmse, index = [r'$\frac{1}{10}$', r'$\frac{1}{5}$', 1, 5, 10], 
                  columns = [5, 10, 15, 20])

fig, ax = plt.subplots(figsize = (4, 2.8))
# plt.style.use('classic')
# plt.style.use('ggplot')
plt.style.use('bmh')
plt.rcParams['font.family'] = 'Arial'
ax = sns.heatmap(df, annot = True, fmt = '.4g', linewidths = .1, vmin = 40, vmax = 60)
plt.yticks(rotation = 0)
plt.xlabel(r'Truncation parameter $r$')
plt.ylabel(r'Coefficient $c=\lambda/\rho$')
plt.show()
fig.savefig("H_70nm_rmse.pdf", bbox_inches = 'tight')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# On Hangzhou data set
H_30bm_rmse = np.array([[28.83, 28.73, 29.82, 32.06],   # c = 1/10
                        [28.81, 28.70, 29.62, 31.65],   # c = 1/5
                        [28.84, 28.64, 30.16, 32.43],   # c = 1
                        [30.47, 33.38, 37.04, 40.10],   # c = 5
                        [33.42, 38.30, 42.50, 45.18]])  # c = 10
df = pd.DataFrame(H_30bm_rmse, index = [r'$\frac{1}{10}$', r'$\frac{1}{5}$', 1, 5, 10], 
                  columns = [5, 10, 15, 20])

fig, ax = plt.subplots(figsize = (4, 2.8))
# plt.style.use('classic')
# plt.style.use('ggplot')
plt.style.use('bmh')
plt.rcParams['font.family'] = 'Arial'
ax = sns.heatmap(df, annot = True, fmt = '.4g', linewidths = .1, vmin = 20, vmax = 50)
plt.yticks(rotation = 0)
plt.xlabel(r'Truncation parameter $r$')
plt.ylabel(r'Coefficient $c=\lambda/\rho$')
plt.show()
fig.savefig("H_30bm_rmse.pdf", bbox_inches = 'tight')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# On Seattle data set
S_30bm_rmse = np.array([[5.58, 5.47, 5.58, 5.69, 5.62],   # c = 1/10
                        [5.58, 5.46, 5.59, 5.68, 5.62],   # c = 1/5
                        [5.57, 5.45, 5.55, 5.65, 5.59],   # c = 1
                        [5.53, 5.40, 5.48, 5.55, 5.51],   # c = 5
                        [5.49, 5.36, 5.42, 5.49, 5.47]])  # c = 10
df = pd.DataFrame(S_30bm_rmse, index = [r'$\frac{1}{10}$', r'$\frac{1}{5}$', 1, 5, 10], 
                  columns = [5, 10, 15, 20, 25])

fig, ax = plt.subplots(figsize = (4.5, 3))
plt.style.use('bmh')
plt.rcParams['font.family'] = 'Arial'
ax = sns.heatmap(df, annot = True, fmt = '.4g', linewidths = .1, vmin = 5.2, vmax = 5.8)
plt.yticks(rotation = 0)
plt.xlabel(r'Truncation parameter $r$')
plt.ylabel(r'Coefficient $c=\lambda/\rho$')
plt.show()
fig.savefig("S_30bm_rmse.pdf", bbox_inches = 'tight')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# On Seattle data set
S_30rm_rmse = np.array([[3.48, 3.38, 3.30, 3.24, 3.19],   # c = 1/10
                        [3.48, 3.38, 3.30, 3.24, 3.19],   # c = 1/5
                        [3.47, 3.37, 3.29, 3.23, 3.19],   # c = 1
                        [3.43, 3.34, 3.27, 3.21, 3.17],   # c = 5
                        [3.40, 3.32, 3.25, 3.19, 3.16]])  # c = 10
df = pd.DataFrame(S_30rm_rmse, index = [r'$\frac{1}{10}$', r'$\frac{1}{5}$', 1, 5, 10], 
                  columns = [5, 10, 15, 20, 25])

fig, ax = plt.subplots(figsize = (4.5, 3))
plt.style.use('bmh')
plt.rcParams['font.family'] = 'Arial'
ax = sns.heatmap(df, annot = True, fmt = '.4g', linewidths = .1, vmin = 3, vmax = 3.5)
plt.yticks(rotation = 0)
plt.xlabel(r'Truncation parameter $r$')
plt.ylabel(r'Coefficient $c=\lambda/\rho$')
plt.show()
fig.savefig("S_30rm_rmse.pdf", bbox_inches = 'tight')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# On Seattle data set
S_70rm_rmse = np.array([[4.36, 4.12, 3.96, 3.85, 3.79],   # c = 1/10
                        [4.35, 4.12, 3.96, 3.85, 3.79],   # c = 1/5
                        [4.34, 4.11, 3.95, 3.84, 3.78],   # c = 1
                        [4.29, 4.06, 3.91, 3.81, 3.74],   # c = 5
                        [4.23, 4.02, 3.87, 3.78, 3.71]])  # c = 10
df = pd.DataFrame(S_70rm_rmse, index = [r'$\frac{1}{10}$', r'$\frac{1}{5}$', 1, 5, 10], 
                  columns = [5, 10, 15, 20, 25])

fig, ax = plt.subplots(figsize = (4.5, 3))
plt.style.use('bmh')
plt.rcParams['font.family'] = 'Arial'
ax = sns.heatmap(df, annot = True, fmt = '.4g', linewidths = .1, vmin = 3.5, vmax = 4.5)
plt.yticks(rotation = 0)
plt.xlabel(r'Truncation parameter $r$')
plt.ylabel(r'Coefficient $c=\lambda/\rho$')
plt.show()
fig.savefig("S_70rm_rmse.pdf", bbox_inches = 'tight')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# On Seattle data set
S_90rm_rmse = np.array([[5.29, 4.91, 4.75, 4.71, 4.71],   # c = 1/10
                        [5.28, 4.91, 4.74, 4.70, 4.70],   # c = 1/5
                        [5.28, 4.89, 4.73, 4.68, 4.67],   # c = 1
                        [5.24, 4.85, 4.68, 4.60, 4.56],   # c = 5
                        [5.20, 4.82, 4.64, 4.55, 4.51]])  # c = 10
df = pd.DataFrame(S_90rm_rmse, index = [r'$\frac{1}{10}$', r'$\frac{1}{5}$', 1, 5, 10], 
                  columns = [5, 10, 15, 20, 25])

fig, ax = plt.subplots(figsize = (4.5, 3))
plt.style.use('bmh')
plt.rcParams['font.family'] = 'Arial'
ax = sns.heatmap(df, annot = True, fmt = '.4g', linewidths = .1, vmin = 4.0, vmax = 5.5)
plt.yticks(rotation = 0)
plt.xlabel(r'Truncation parameter $r$')
plt.ylabel(r'Coefficient $c=\lambda/\rho$')
plt.show()
fig.savefig("S_90rm_rmse.pdf", bbox_inches = 'tight')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# On Seattle data set
S_30nm_rmse = np.array([[4.65, 4.48, 4.40, 4.36, 4.35],   # c = 1/10
                        [4.65, 4.48, 4.40, 4.36, 4.36],   # c = 1/5
                        [4.66, 4.49, 4.40, 4.36, 4.35],   # c = 1
                        [4.67, 4.50, 4.41, 4.36, 4.33],   # c = 5
                        [4.68, 4.51, 4.42, 4.37, 4.33]])  # c = 10
df = pd.DataFrame(S_30nm_rmse, index = [r'$\frac{1}{10}$', r'$\frac{1}{5}$', 1, 5, 10], 
                  columns = [5, 10, 15, 20, 25])

fig, ax = plt.subplots(figsize = (4.5, 3))
plt.style.use('bmh')
plt.rcParams['font.family'] = 'Arial'
ax = sns.heatmap(df, annot = True, fmt = '.4g', linewidths = .1, vmin = 4.0, vmax = 5.5)
plt.yticks(rotation = 0)
plt.xlabel(r'Truncation parameter $r$')
plt.ylabel(r'Coefficient $c=\lambda/\rho$')
plt.show()
fig.savefig("S_30nm_rmse.pdf", bbox_inches = 'tight')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# On Seattle data set
S_70nm_rmse = np.array([[5.58, 5.43, 5.53, 5.56, 5.62],   # c = 1/10
                        [5.58, 5.43, 5.52, 5.57, 5.60],   # c = 1/5
                        [5.59, 5.42, 5.49, 5.58, 5.60],   # c = 1
                        [5.59, 5.41, 5.50, 5.53, 5.55],   # c = 5
                        [5.59, 5.40, 5.48, 5.50, 5.51]])  # c = 10
df = pd.DataFrame(S_70nm_rmse, index = [r'$\frac{1}{10}$', r'$\frac{1}{5}$', 1, 5, 10], 
                  columns = [5, 10, 15, 20, 25])

fig, ax = plt.subplots(figsize = (4.5, 3))
plt.style.use('bmh')
plt.rcParams['font.family'] = 'Arial'
ax = sns.heatmap(df, annot = True, fmt = '.4g', linewidths = .1, vmin = 5.0, vmax = 6.0)
plt.yticks(rotation = 0)
plt.xlabel(r'Truncation parameter $r$')
plt.ylabel(r'Coefficient $c=\lambda/\rho$')
plt.show()
fig.savefig("S_70nm_rmse.pdf", bbox_inches = 'tight')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# On Portland data set
P_30bm_rmse = np.array([[23.73, 34.98, 37.13, 38.88, 40.76, 41.62],   # c = 1/10
                        [23.67, 29.90, 36.60, 39.91, 41.81, 42.82],   # c = 1/5
                        [23.52, 32.87, 37.78, 23.63, 42.39, 43.69],   # c = 1
                        [23.63, 23.72, 24.28, 25.38, 26.10, 26.91],   # c = 5
                        [23.83, 24.03, 24.55, 25.22, 25.88, 26.50]])  # c = 10
df = pd.DataFrame(P_30bm_rmse, index = [r'$\frac{1}{10}$', r'$\frac{1}{5}$', 1, 5, 10], 
                  columns = [5, 10, 15, 20, 25, 30])

fig, ax = plt.subplots(figsize = (4.5, 3))
plt.style.use('bmh')
plt.rcParams['font.family'] = 'Arial'
ax = sns.heatmap(df, annot = True, fmt = '.4g', linewidths = .1,
                 vmin = 0, vmax = 50)#, cbar = False) # cbar_kws={"orientation": "horizontal"}
plt.yticks(rotation = 0)
plt.xlabel(r'Truncation parameter $r$')
plt.ylabel(r'Coefficient $c=\lambda/\rho$')
plt.show()
fig.savefig("P_30bm_rmse.pdf", bbox_inches = 'tight')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# On Portland data set
P_30rm_rmse = np.array([[16.49, 15.90, 15.99, 16.31, 16.51, 16.60],   # c = 1/10
                        [16.46, 15.88, 15.94, 16.22, 16.36, 16.40],   # c = 1/5
                        [16.36, 15.89, 15.90, 15.98, 15.99, 15.93],   # c = 1
                        [16.85, 16.67, 16.65, 16.67, 16.64, 16.60],   # c = 5
                        [17.70, 17.63, 17.64, 17.66, 17.65, 17.66]])  # c = 10
df = pd.DataFrame(P_30rm_rmse, index = [r'$\frac{1}{10}$', r'$\frac{1}{5}$', 1, 5, 10], 
                  columns = [5, 10, 15, 20, 25, 30])

fig, ax = plt.subplots(figsize = (4.5, 3))
ax = sns.heatmap(df, annot = True, fmt = '.4g', linewidths = .1, vmin = 15.5, vmax = 18)
plt.yticks(rotation = 0)
plt.xlabel(r'Truncation parameter $r$')
plt.ylabel(r'Coefficient $c=\lambda/\rho$')
plt.show()
fig.savefig("P_30rm_rmse.pdf", bbox_inches = 'tight')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# On Portland data set
P_70rm_rmse = np.array([[19.85, 19.21, 19.22, 19.20, 19.08, 18.93],   # c = 1/10
                        [19.83, 19.14, 19.09, 18.98, 18.94, 18.83],   # c = 1/5
                        [19.69, 19.06, 18.82, 18.70, 18.70, 18.70],   # c = 1
                        [20.00, 19.63, 19.59, 19.53, 19.60, 19.68],   # c = 5
                        [20.50, 20.32, 20.37, 20.36, 20.45, 20.60]])  # c = 10
df = pd.DataFrame(P_70rm_rmse, index = [r'$\frac{1}{10}$', r'$\frac{1}{5}$', 1, 5, 10], 
                  columns = [5, 10, 15, 20, 25, 30])

fig, ax = plt.subplots(figsize = (4.5, 3))
ax = sns.heatmap(df, annot = True, fmt = '.4g', linewidths = .1, vmin = 18, vmax = 21)
plt.yticks(rotation = 0)
plt.xlabel(r'Truncation parameter $r$')
plt.ylabel(r'Coefficient $c=\lambda/\rho$')
plt.show()
fig.savefig("P_70rm_rmse.pdf", bbox_inches = 'tight')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# On Portland data set
P_90rm_rmse = np.array([[24.28, 23.32, 23.14, 23.04, 23.09, 23.30],   # c = 1/10
                        [24.21, 23.37, 23.03, 22.74, 22.93, 23.17],   # c = 1/5
                        [24.27, 23.22, 22.83, 22.83, 22.92, 23.17],   # c = 1
                        [24.75, 24.63, 24.70, 25.08, 25.35, 25.77],   # c = 5
                        [25.23, 25.66, 26.05, 26.57, 27.12, 27.64]])  # c = 10
df = pd.DataFrame(P_90rm_rmse, index = [r'$\frac{1}{10}$', r'$\frac{1}{5}$', 1, 5, 10], 
                  columns = [5, 10, 15, 20, 25, 30])

fig, ax = plt.subplots(figsize = (4.5, 3))
ax = sns.heatmap(df, annot = True, fmt = '.4g', linewidths = .1, vmin = 20, vmax = 28)
plt.yticks(rotation = 0)
plt.xlabel(r'Truncation parameter $r$')
plt.ylabel(r'Coefficient $c=\lambda/\rho$')
plt.show()
fig.savefig("P_90rm_rmse.pdf", bbox_inches = 'tight')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# On Portland data set
P_30nm_rmse = np.array([[19.61, 18.98, 19.05, 18.97, 18.91, 19.17],   # c = 1/10
                        [19.61, 19.03, 19.05, 18.92, 18.84, 19.09],   # c = 1/5
                        [19.76, 19.37, 25.84, 28.38, 29.65, 29.85],   # c = 1
                        [20.65, 20.87, 29.56, 65.12, 99.85, 108.38],  # c = 5
                        [21.51, 22.49, 45.23, 77.78, 110.99, 115.57]])# c = 10
df = pd.DataFrame(P_30nm_rmse, index = [r'$\frac{1}{10}$', r'$\frac{1}{5}$', 1, 5, 10], 
                  columns = [5, 10, 15, 20, 25, 30])

fig, ax = plt.subplots(figsize = (4.5, 3))
ax = sns.heatmap(df, annot = True, fmt = '.4g', linewidths = .1, vmin = 0, vmax = 50)
plt.yticks(rotation = 0)
plt.xlabel(r'Truncation parameter $r$')
plt.ylabel(r'Coefficient $c=\lambda/\rho$')
plt.show()
fig.savefig("P_30nm_rmse.pdf", bbox_inches = 'tight')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# On Portland data set
P_30nm_rmse = np.array([[32.51, 31.74, 32.47, 32.94, 33.30, 33.34],      # c = 1/10
                        [35.12, 35.97, 36.54, 36.93, 37.02, 37.13],      # c = 1/5
                        [39.94, 82.53, 115.3, 127.9, 130.06, 134.44],    # c = 1
                        [51.48, 102.4, 134.18, 155.39, 161.17, 161.57],  # c = 5
                        [52.06, 105.01, 138.22, 157.72, 166.81, 162.92]])# c = 10
df = pd.DataFrame(P_30nm_rmse, index = [r'$\frac{1}{10}$', r'$\frac{1}{5}$', 1, 5, 10], 
                  columns = [5, 10, 15, 20, 25, 30])

fig, ax = plt.subplots(figsize = (4.5, 3))
ax = sns.heatmap(df, annot = True, fmt = '.4g', linewidths = .1, vmin = 0, vmax = 50)
plt.yticks(rotation = 0)
plt.xlabel(r'Truncation parameter $r$')
plt.ylabel(r'Coefficient $c=\lambda/\rho$')
plt.show()
fig.savefig("P_70nm_rmse.pdf", bbox_inches = 'tight')
