% %%
clc;
clear;
% Exemplified by a read-world (7,4,3) volume tensor
% where we have 7 detectors, 4 days and 3 time windows.
tensor(:,:,1) = [155,74,493,426;108,44,350,359;...
    175,78,567,581;181,111,517,552;...
    137,53,489,485;90,44,306,290;...
    139,55,398,390];
tensor(:,:,2) = [172,69,590,386;104,39,310,304;...
    158,74,505,546;176,90,525,552;...
    150,64,438,459;73,32,281,299;...
    127,51,358,382];
tensor(:,:,3) = [225,92,443,436;94,44,355,356;...
    139,77,575,604;175,98,574,553;...
    126,67,593,484;58,49,348,301;...
    144,71,444,396];
[n1,n2,n3] = size(tensor);

% %%
% Create missing values for this (7,4,3) tensor randomly.
S = round(rand(n1,n2,n3)+0.3);
sparse_tensor = S.*tensor;
pos_obs = find(sparse_tensor~=0); % index set of observed entries
pos_unobs = find(sparse_tensor==0); % index set of missing entries

% %%
%%file cp_combination.m
function tensor = cp_combination(factor_mat,dim)
% This is a function for the CP combination over factor matrices.

d = length(dim);
factor_mat = flipud(factor_mat);
if d == 2
    tensor = factor_mat{2}*factor_mat{1}';
elseif d == 3
    mat = kr(factor_mat{1},factor_mat{2});
    tensor = mat2ten(factor_mat{d}*mat',dim,1);
else
    mat = kr(factor_mat{1},factor_mat{2});
    for k = 3:d-1
        mat = kr(mat,factor_mat{k});
    end
    tensor = mat2ten(factor_mat{d}*mat',dim,1);
end
end
% Out:
% Created file 'C:\Program Files\MATLAB\R2016b\extern\engines\python\cp_combination.m'.

% %%
%%file khatrirao_fast.m
function P = khatrirao_fast(varargin)
%KHATRIRAO Khatri-Rao product of matrices.
%
%   KHATRIRAO(A,B) computes the Khatri-Rao product of matrices A and
%   B that have the same number of columns.  The result is the
%   column-wise Kronecker product
%   [KRON(A(:,1),B(:,1)) ... KRON(A(:,n),B(:,n))]
%
%   KHATRIRAO(A1,A2,...) computes the Khatri-Rao product of
%   multiple matrices that have the same number of columns.
%
%   KHATRIRAO(C) computes the Khatri-Rao product of
%   the matrices in cell array C.
%
%   KHATRIRAO(...,'r') computes the Khatri-Rao product in reverse
%   order.
%
%   Examples
%   A = rand(5,2); B = rand(3,2); C = rand(2,2);
%   khatrirao(A,B) %<-- Khatri-Rao of A and B
%   khatrirao(B,A,'r') %<-- same thing as above
%   khatrirao({C,B,A}) %<-- passing a cell array
%   khatrirao({A,B,C},'r') %<-- same as above
%
%   See also TENSOR, KTENSOR.
%
%MATLAB Tensor Toolbox.
%Copyright 2012, Sandia Corporation.

% This is the MATLAB Tensor Toolbox by T. Kolda, B. Bader, and others.
% http://www.sandia.gov/~tgkolda/TensorToolbox.
% Copyright (2012) Sandia Corporation. Under the terms of Contract
% DE-AC04-94AL85000, there is a non-exclusive license for use of this
% work by or on behalf of the U.S. Government. Export of this data may
% require a license from the United States Government.
% The full license terms can be found in the file LICENSE.txt


%% Error checking on input and set matrix order
% Note that this next if/else check forces A to be a cell array.
if ischar(varargin{end}) && varargin{end} == 'r'
    if nargin == 2 && iscell(varargin{1})
        % Input is a single cell array
        A = varargin{1};
    else
        % Input is a sequence of matrices
        A = {varargin{1:end-1}};
    end
    matorder = length(A):-1:1;
else
    if nargin == 1 && iscell(varargin{1})
        % Input is a single cell array
        A = varargin{1};
    else
        % Input is a sequence of matrices
        A = varargin;
    end
    matorder = 1:length(A);
end

%% Error check on matrices and compute number of rows in result 

% N = number of columns (must be the same for every input)
N = size(A{1},2); 

% After loop, M = number of rows in the result
M = 1; 

for i = matorder
    if ndims(A) ~= 2
        error('Each argument must be a matrix');
    end
    if (N ~= size(A{i},2))
        error('All matrices must have the same number of columns.')
    end
    M = M * size(A{i},1);
end

%% Computation
P = kr(A([matorder]));
% Out:
% Created file 'C:\Program Files\MATLAB\R2016b\extern\engines\python\khatrirao_fast.m'.

% %%
%%file kr.m
function X = kr(U,varargin)
%KR Khatri-Rao product.
%   kr(A,B) returns the Khatri-Rao product of two matrices A and B, of 
%   dimensions I-by-K and J-by-K respectively. The result is an I*J-by-K
%   matrix formed by the matching columnwise Kronecker products, i.e.
%   the k-th column of the Khatri-Rao product is defined as
%   kron(A(:,k),B(:,k)).
%
%   kr(A,B,C,...) and kr({A B C ...}) compute a string of Khatri-Rao 
%   products A o B o C o ..., where o denotes the Khatri-Rao product.
%
%   See also kron.

%   Version: 21/10/10
%   Authors: Laurent Sorber (Laurent.Sorber@cs.kuleuven.be)

if ~iscell(U), U = [U varargin]; end
K = size(U{1},2);
% if any(cellfun('size',U,2)-K)
%     error('kr:ColumnMismatch', ...
%           'Input matrices must have the same number of columns.');
% end
J = size(U{end},1);
X = reshape(U{end},[J 1 K]);
for n = length(U)-1:-1:1
    I = size(U{n},1);
    A = reshape(U{n},[1 I K]);
    X = reshape(bsxfun(@times,A,X),[I*J 1 K]);
    J = I*J;
end
X = reshape(X,[size(X,1) K]);
% Out:
% Created file 'C:\Program Files\MATLAB\R2016b\extern\engines\python\kr.m'.

% %%
%%file mat2ten.m
function tensor = mat2ten(mat,dim,k)
% Folding a matrix into a tensor.
% 	dim = (n1,n2,...,nd)
% 	k=1,2,...,d

dim0 = [([dim(1:k-1),dim(k+1:length(dim))]),dim(k)];
tensor = permute(reshape(mat',dim0),[1:k-1,length(dim),k:length(dim)-1]);
end
% Out:
% Created file 'C:\Program Files\MATLAB\R2016b\extern\engines\python\mat2ten.m'.

% %%
%%file ten2mat.m
function mat = ten2mat(tensor,dim,k)
% This is a function for tensor unfolding.
% 	dim = (n1,n2,...,nd)
% 	k=1,2,...,d

mat = reshape(permute(tensor,[k,1:k-1,k+1:length(dim)]),dim(k),[]);
end
% Out:
% Created file 'C:\Program Files\MATLAB\R2016b\extern\engines\python\ten2mat.m'.

% %%
%%file BGCP_Gibbs.m
function [tensor_hat,factor_mat,final_result] = BGCP_Gibbs(dense_tensor,sparse_tensor,varargin)
% Bayesian Gaussian CP decomposition (BGCP) using Gibbs sampling.

dim = size(sparse_tensor);
d = length(dim);
position = find(sparse_tensor~=0);
pos = find(dense_tensor>0 & sparse_tensor==0);
binary_tensor = zeros(dim);
binary_tensor(position) = 1;

ip = inputParser;
ip.addParamValue('CP_rank',30,@isscalar);
ip.addParamValue('maxiter',1000,@isscalar);
ip.parse(varargin{:});

r = ip.Results.CP_rank;
maxiter = ip.Results.maxiter;

U = cell(d,1);
for k = 1:d
    U{k} = 0.1*randn(dim(k),r);
end

beta0 = 1;
nu0 = r;
mu0 = zeros(r,1);
tau_epsilon = 1;
a0 = 1;
b0 = 1;
W0 = eye(r);

%% Test Gibbs samplers for BGCP model.
rmse = zeros(maxiter,1);
fprintf('\n------Bayesian Gaussian CP decomposition using Gibbs sampling------\n');
for iter = 1:maxiter
    for k = 1:d
        % Sample hyper-parameters \Lambda^{(k)} and \mu^{(k)}.
        U_bar = mean(U{k},1)';
        var_mu0 = (dim(k)*U_bar+beta0*mu0)./(dim(k)+beta0);
        var_nu = dim(k)+nu0;
        var_W = inv(inv(W0)+dim(k)*cov(U{k})+dim(k)*beta0/(dim(k)+beta0)*(U_bar-mu0)*(U_bar-mu0)');
        var_W = (var_W+var_W')./2;
        var_Lambda0 = wishrnd(var_W,var_nu);
        var_mu0 = mvnrnd(var_mu0,inv((dim(k)+beta0)*var_Lambda0))';
        
        % Sample factor matrice U^{(k)}.
        var1 = khatrirao_fast(U{[1:k-1,k+1:d]},'r')';
        var2 = kr(var1,var1);
        var3 = reshape(var2*(ten2mat(binary_tensor,dim,k)'),[r,r,dim(k)]);
        var4 = tau_epsilon*var1*ten2mat(sparse_tensor,dim,k)'+ones(r,dim(k)).*(var_Lambda0*var_mu0);
        for i = 1:dim(k)
            var_Lambda1 = tau_epsilon*var3(:,:,i)+var_Lambda0;
            inv_var_Lambda1 = inv((var_Lambda1+var_Lambda1')./2);
            var_mu = inv_var_Lambda1*var4(:,i);
            U{k}(i,:) = mvnrnd(var_mu,inv_var_Lambda1);
        end
    end
    
    % Compute the estimated tensor.
    tensor_hat = cp_combination(U,dim);
    rmse(iter,1) = sqrt(sum((dense_tensor(pos)-tensor_hat(pos)).^2)./length(pos));
    
    % Sample precision \tau_{\epsilon}.
    var_a = a0+0.5*length(position);
    error = sparse_tensor-tensor_hat;
    var_b = b0+0.5*sum(error(position).^2);
    tau_epsilon = gamrnd(var_a,1./var_b);
    
    % Print the results.
    fprintf('iteration = %g, RMSE = %g.\n',iter,rmse(iter));
end

%% Average factor matrices over additional iterations.
fprintf('\n------Final Result of Bayesian Gaussian CP decomposition------\n');
factor_mat = cell(d,1);
for k = 1:d
    factor_mat{k} = zeros(dim(k),r);
end
tensor_hat0 = zeros(dim);
iters = 500;
for iter = 1:iters
    for k = 1:d
        % Sample hyper-parameters \Lambda^{(k)} and \mu^{(k)}.
        U_bar = mean(U{k},1)';
        var_mu0 = (dim(k)*U_bar+beta0*mu0)./(dim(k)+beta0);
        var_nu = dim(k)+nu0;
        var_W = inv(inv(W0)+dim(k)*cov(U{k})+dim(k)*beta0/(dim(k)+beta0)*(U_bar-mu0)*(U_bar-mu0)');
        var_W = (var_W+var_W')./2;
        var_Lambda0 = wishrnd(var_W,var_nu);
        var_mu0 = mvnrnd(var_mu0,inv((dim(k)+beta0)*var_Lambda0))';
        
        % Sample factor matrice U^{(k)}.
        var1 = khatrirao_fast(U{[1:k-1,k+1:d]},'r')';
        var2 = kr(var1,var1);
        var3 = reshape(var2*(ten2mat(binary_tensor,dim,k)'),[r,r,dim(k)]);
        var4 = tau_epsilon*var1*ten2mat(sparse_tensor,dim,k)'+ones(r,dim(k)).*(var_Lambda0*var_mu0);
        for i = 1:dim(k)
            var_Lambda1 = tau_epsilon*var3(:,:,i)+var_Lambda0;
            inv_var_Lambda1 = inv((var_Lambda1+var_Lambda1')./2);
            var_mu = inv_var_Lambda1*var4(:,i);
            U{k}(i,:) = mvnrnd(var_mu,inv_var_Lambda1);
        end
        factor_mat{k} = factor_mat{k}+U{k};
    end
    
    % Compute an estimated tensor.
    tensor_hat = cp_combination(U,dim);
    tensor_hat0 = tensor_hat0+tensor_hat;
    
    % Sample precision \tau_{\epsilon}.
    var_a = a0+0.5*length(position);
    error = sparse_tensor-tensor_hat;
    var_b = b0+0.5*sum(error(position).^2);
    tau_epsilon = gamrnd(var_a,1./var_b);
end
for k = 1:d
    factor_mat{k} = factor_mat{k}./iters;
end

tensor_hat = tensor_hat0/iters;
final_result = cell(2,1);
FinalMAPE = sum(abs(dense_tensor(pos)-tensor_hat(pos))./dense_tensor(pos))./length(pos);
final_result{1} = FinalMAPE;
FinalRMSE = sqrt(sum((dense_tensor(pos)-tensor_hat(pos)).^2)./length(pos));
final_result{2} = FinalRMSE;

% Print the results.
fprintf('Final RMSE = %g, MAPE = %g\n',FinalRMSE,FinalMAPE);
end
% Out:
% Created file 'C:\Program Files\MATLAB\R2016b\extern\engines\python\BGCP_Gibbs.m'.

% %%
[tensor_hat,model,result] = BGCP_Gibbs(tensor,sparse_tensor,'CP_rank',3,'maxiter',2000);
% Out:
% ------Bayesian Gaussian CP decomposition using Gibbs sampling------
% iteration = 1, RMSE = 151.01.
% iteration = 2, RMSE = 48.4965.
% iteration = 3, RMSE = 27.7547.
% iteration = 4, RMSE = 24.2612.
% iteration = 5, RMSE = 31.6578.
% iteration = 6, RMSE = 26.5075.
% iteration = 7, RMSE = 20.7942.
% iteration = 8, RMSE = 21.618.
% iteration = 9, RMSE = 27.0666.
% iteration = 10, RMSE = 34.3827.
% iteration = 11, RMSE = 32.053.
% iteration = 12, RMSE = 29.0464.
% iteration = 13, RMSE = 23.9818.
% iteration = 14, RMSE = 37.9526.
% iteration = 15, RMSE = 28.4163.
% iteration = 16, RMSE = 28.4664.
% iteration = 17, RMSE = 23.9012.
% iteration = 18, RMSE = 31.8868.
% iteration = 19, RMSE = 24.8787.
% iteration = 20, RMSE = 24.6603.
% iteration = 21, RMSE = 23.5096.
% iteration = 22, RMSE = 26.6971.
% iteration = 23, RMSE = 26.1986.
% iteration = 24, RMSE = 20.4857.
% iteration = 25, RMSE = 20.2202.
% iteration = 26, RMSE = 15.4819.
% iteration = 27, RMSE = 31.0592.
% iteration = 28, RMSE = 31.0276.
% iteration = 29, RMSE = 29.0842.
% iteration = 30, RMSE = 38.2292.
% iteration = 31, RMSE = 23.583.
% iteration = 32, RMSE = 23.6548.
% iteration = 33, RMSE = 28.0147.
% iteration = 34, RMSE = 26.0654.
% iteration = 35, RMSE = 21.1968.
% iteration = 36, RMSE = 24.2017.
% iteration = 37, RMSE = 31.1152.
% iteration = 38, RMSE = 30.3165.
% iteration = 39, RMSE = 16.4413.
% iteration = 40, RMSE = 21.1727.
% iteration = 41, RMSE = 30.8547.
% iteration = 42, RMSE = 31.317.
% iteration = 43, RMSE = 33.9755.
% iteration = 44, RMSE = 41.0783.
% iteration = 45, RMSE = 28.6235.
% iteration = 46, RMSE = 22.593.
% iteration = 47, RMSE = 18.0031.
% iteration = 48, RMSE = 23.153.
% iteration = 49, RMSE = 28.1318.
% iteration = 50, RMSE = 17.4221.
% iteration = 51, RMSE = 18.9637.
% iteration = 52, RMSE = 19.6982.
% iteration = 53, RMSE = 19.6204.
% iteration = 54, RMSE = 20.1212.
% iteration = 55, RMSE = 27.7472.
% iteration = 56, RMSE = 27.1385.
% iteration = 57, RMSE = 24.5825.
% iteration = 58, RMSE = 26.9378.
% iteration = 59, RMSE = 30.6411.
% iteration = 60, RMSE = 33.3496.
% iteration = 61, RMSE = 26.2434.
% iteration = 62, RMSE = 18.1567.
% iteration = 63, RMSE = 24.246.
% iteration = 64, RMSE = 28.1144.
% iteration = 65, RMSE = 26.2907.
% iteration = 66, RMSE = 30.5068.
% iteration = 67, RMSE = 20.295.
% iteration = 68, RMSE = 25.4372.
% iteration = 69, RMSE = 23.7757.
% iteration = 70, RMSE = 22.0611.
% iteration = 71, RMSE = 18.405.
% iteration = 72, RMSE = 22.0586.
% iteration = 73, RMSE = 31.7435.
% iteration = 74, RMSE = 25.4779.
% iteration = 75, RMSE = 43.3225.
% iteration = 76, RMSE = 38.3714.
% iteration = 77, RMSE = 43.9625.
% iteration = 78, RMSE = 24.2676.
% iteration = 79, RMSE = 22.0349.
% iteration = 80, RMSE = 21.6734.
% iteration = 81, RMSE = 25.6287.
% iteration = 82, RMSE = 20.815.
% iteration = 83, RMSE = 42.0658.
% iteration = 84, RMSE = 34.749.
% iteration = 85, RMSE = 28.5475.
% iteration = 86, RMSE = 29.3006.
% iteration = 87, RMSE = 31.6093.
% iteration = 88, RMSE = 46.6633.
% iteration = 89, RMSE = 28.0367.
% iteration = 90, RMSE = 29.049.
% iteration = 91, RMSE = 24.4856.
% iteration = 92, RMSE = 23.5778.
% iteration = 93, RMSE = 28.7149.
% iteration = 94, RMSE = 18.8058.
% iteration = 95, RMSE = 23.05.
% iteration = 96, RMSE = 13.4842.
% iteration = 97, RMSE = 25.0817.
% iteration = 98, RMSE = 29.6637.
% iteration = 99, RMSE = 25.1788.
% iteration = 100, RMSE = 25.276.
% iteration = 101, RMSE = 21.0945.
% iteration = 102, RMSE = 21.102.
% iteration = 103, RMSE = 33.0602.
% iteration = 104, RMSE = 29.1986.
% iteration = 105, RMSE = 26.9908.
% iteration = 106, RMSE = 25.5743.
% iteration = 107, RMSE = 19.2845.
% iteration = 108, RMSE = 31.0987.
% iteration = 109, RMSE = 26.5865.
% iteration = 110, RMSE = 21.4648.
% iteration = 111, RMSE = 28.0995.
% iteration = 112, RMSE = 24.2155.
% iteration = 113, RMSE = 27.6716.
% iteration = 114, RMSE = 19.3559.
% iteration = 115, RMSE = 26.8476.
% iteration = 116, RMSE = 31.8721.
% iteration = 117, RMSE = 17.9384.
% iteration = 118, RMSE = 36.9498.
% iteration = 119, RMSE = 20.9846.
% iteration = 120, RMSE = 31.349.
% iteration = 121, RMSE = 29.3119.
% iteration = 122, RMSE = 28.1459.
% iteration = 123, RMSE = 21.3511.
% iteration = 124, RMSE = 24.795.
% iteration = 125, RMSE = 29.9265.
% iteration = 126, RMSE = 26.6048.
% iteration = 127, RMSE = 27.0949.
% iteration = 128, RMSE = 26.1182.
% iteration = 129, RMSE = 19.541.
% iteration = 130, RMSE = 36.945.
% iteration = 131, RMSE = 25.768.
% iteration = 132, RMSE = 30.385.
% iteration = 133, RMSE = 22.1067.
% iteration = 134, RMSE = 28.3478.
% iteration = 135, RMSE = 28.4669.
% iteration = 136, RMSE = 21.4506.
% iteration = 137, RMSE = 25.1757.
% iteration = 138, RMSE = 36.2075.
% iteration = 139, RMSE = 19.0648.
% iteration = 140, RMSE = 16.1768.
% iteration = 141, RMSE = 27.2274.
% iteration = 142, RMSE = 19.8001.
% iteration = 143, RMSE = 21.4695.
% iteration = 144, RMSE = 25.8375.
% iteration = 145, RMSE = 21.5496.
% iteration = 146, RMSE = 34.4327.
% iteration = 147, RMSE = 27.2676.
% iteration = 148, RMSE = 25.354.
% iteration = 149, RMSE = 32.9669.
% iteration = 150, RMSE = 31.5617.
% iteration = 151, RMSE = 26.9362.
% iteration = 152, RMSE = 24.489.
% iteration = 153, RMSE = 23.2023.
% iteration = 154, RMSE = 16.5661.
% iteration = 155, RMSE = 27.2831.
% iteration = 156, RMSE = 26.8677.
% iteration = 157, RMSE = 26.0341.
% iteration = 158, RMSE = 32.2751.
% iteration = 159, RMSE = 25.9511.
% iteration = 160, RMSE = 27.3566.
% iteration = 161, RMSE = 28.283.
% iteration = 162, RMSE = 33.3072.
% iteration = 163, RMSE = 25.2699.
% iteration = 164, RMSE = 25.8113.
% iteration = 165, RMSE = 26.7158.
% iteration = 166, RMSE = 30.0655.
% iteration = 167, RMSE = 34.2647.
% iteration = 168, RMSE = 23.1195.
% iteration = 169, RMSE = 17.1464.
% iteration = 170, RMSE = 26.7085.
% iteration = 171, RMSE = 32.1879.
% iteration = 172, RMSE = 23.4143.
% iteration = 173, RMSE = 34.7853.
% iteration = 174, RMSE = 34.0542.
% iteration = 175, RMSE = 31.0939.
% iteration = 176, RMSE = 15.3568.
% iteration = 177, RMSE = 23.1312.
% iteration = 178, RMSE = 26.8273.
% iteration = 179, RMSE = 31.9452.
% iteration = 180, RMSE = 26.0691.
% iteration = 181, RMSE = 27.4605.
% iteration = 182, RMSE = 21.2707.
% iteration = 183, RMSE = 23.3022.
% iteration = 184, RMSE = 23.9811.
% iteration = 185, RMSE = 29.0696.
% iteration = 186, RMSE = 25.5627.
% iteration = 187, RMSE = 24.7051.
% iteration = 188, RMSE = 33.9122.
% iteration = 189, RMSE = 21.8917.
% iteration = 190, RMSE = 15.5162.
% iteration = 191, RMSE = 23.5193.
% iteration = 192, RMSE = 32.3412.
% iteration = 193, RMSE = 32.8885.
% iteration = 194, RMSE = 20.2372.
% iteration = 195, RMSE = 31.7929.
% iteration = 196, RMSE = 25.9828.
% iteration = 197, RMSE = 32.683.
% iteration = 198, RMSE = 16.3259.
% iteration = 199, RMSE = 24.2883.
% iteration = 200, RMSE = 19.1057.
% iteration = 201, RMSE = 18.5352.
% iteration = 202, RMSE = 29.4432.
% iteration = 203, RMSE = 25.226.
% iteration = 204, RMSE = 25.8961.
% iteration = 205, RMSE = 24.1985.
% iteration = 206, RMSE = 25.1055.
% iteration = 207, RMSE = 25.5432.
% iteration = 208, RMSE = 20.1939.
% iteration = 209, RMSE = 22.8863.
% iteration = 210, RMSE = 21.9079.
% iteration = 211, RMSE = 17.7757.
% iteration = 212, RMSE = 16.3321.
% iteration = 213, RMSE = 20.2629.
% iteration = 214, RMSE = 22.3016.
% iteration = 215, RMSE = 19.2237.
% iteration = 216, RMSE = 21.3349.
% iteration = 217, RMSE = 26.1878.
% iteration = 218, RMSE = 21.2189.
% iteration = 219, RMSE = 21.178.
% iteration = 220, RMSE = 23.9787.
% iteration = 221, RMSE = 30.5805.
% iteration = 222, RMSE = 31.6942.
% iteration = 223, RMSE = 21.857.
% iteration = 224, RMSE = 20.2888.
% iteration = 225, RMSE = 29.6032.
% iteration = 226, RMSE = 25.4479.
% iteration = 227, RMSE = 32.3343.
% iteration = 228, RMSE = 32.0557.
% iteration = 229, RMSE = 26.2099.
% iteration = 230, RMSE = 28.4411.
% iteration = 231, RMSE = 27.0941.
% iteration = 232, RMSE = 27.0798.
% iteration = 233, RMSE = 33.369.
% iteration = 234, RMSE = 17.1425.
% iteration = 235, RMSE = 29.4054.
% iteration = 236, RMSE = 33.0538.
% iteration = 237, RMSE = 28.2651.
% iteration = 238, RMSE = 27.4696.
% iteration = 239, RMSE = 22.2809.
% iteration = 240, RMSE = 29.332.
% iteration = 241, RMSE = 25.0914.
% iteration = 242, RMSE = 24.8599.
% iteration = 243, RMSE = 23.0765.
% iteration = 244, RMSE = 29.0056.
% iteration = 245, RMSE = 27.5777.
% iteration = 246, RMSE = 25.8152.
% iteration = 247, RMSE = 20.1043.
% iteration = 248, RMSE = 21.6339.
% iteration = 249, RMSE = 19.8418.
% iteration = 250, RMSE = 29.7061.
% iteration = 251, RMSE = 26.9979.
% iteration = 252, RMSE = 25.9675.
% iteration = 253, RMSE = 26.7459.
% iteration = 254, RMSE = 27.5416.
% iteration = 255, RMSE = 25.0358.
% iteration = 256, RMSE = 23.8747.
% iteration = 257, RMSE = 21.7439.
% iteration = 258, RMSE = 33.2908.
% iteration = 259, RMSE = 23.5531.
% iteration = 260, RMSE = 30.8366.
% iteration = 261, RMSE = 30.462.
% iteration = 262, RMSE = 26.3665.
% iteration = 263, RMSE = 26.7209.
% iteration = 264, RMSE = 19.6012.
% iteration = 265, RMSE = 24.2986.
% iteration = 266, RMSE = 26.0602.
% iteration = 267, RMSE = 22.4453.
% iteration = 268, RMSE = 21.8995.
% iteration = 269, RMSE = 24.6732.
% iteration = 270, RMSE = 24.3215.
% iteration = 271, RMSE = 28.576.
% iteration = 272, RMSE = 28.7936.
% iteration = 273, RMSE = 27.6407.
% iteration = 274, RMSE = 23.154.
% iteration = 275, RMSE = 33.4532.
% iteration = 276, RMSE = 24.3845.
% iteration = 277, RMSE = 20.4518.
% iteration = 278, RMSE = 21.1279.
% iteration = 279, RMSE = 33.8815.
% iteration = 280, RMSE = 33.8041.
% iteration = 281, RMSE = 33.5038.
% iteration = 282, RMSE = 23.3009.
% iteration = 283, RMSE = 29.3861.
% iteration = 284, RMSE = 33.9947.
% iteration = 285, RMSE = 25.6519.
% iteration = 286, RMSE = 30.7404.
% iteration = 287, RMSE = 22.1467.
% iteration = 288, RMSE = 23.8153.
% iteration = 289, RMSE = 24.0296.
% iteration = 290, RMSE = 22.2358.
% iteration = 291, RMSE = 24.6472.
% iteration = 292, RMSE = 24.696.
% iteration = 293, RMSE = 23.0308.
% iteration = 294, RMSE = 23.7559.
% iteration = 295, RMSE = 30.2331.
% iteration = 296, RMSE = 29.0816.
% iteration = 297, RMSE = 32.0689.
% iteration = 298, RMSE = 25.9287.
% iteration = 299, RMSE = 25.6256.
% iteration = 300, RMSE = 36.3549.
% iteration = 301, RMSE = 27.2796.
% iteration = 302, RMSE = 29.3911.
% iteration = 303, RMSE = 25.6493.
% iteration = 304, RMSE = 34.7469.
% iteration = 305, RMSE = 27.2983.
% iteration = 306, RMSE = 19.6764.
% iteration = 307, RMSE = 32.7931.
% iteration = 308, RMSE = 31.3241.
% iteration = 309, RMSE = 25.3974.
% iteration = 310, RMSE = 31.0428.
% iteration = 311, RMSE = 25.5917.
% iteration = 312, RMSE = 30.7622.
% iteration = 313, RMSE = 20.1229.
% iteration = 314, RMSE = 32.2034.
% iteration = 315, RMSE = 19.6111.
% iteration = 316, RMSE = 25.227.
% iteration = 317, RMSE = 30.3584.
% iteration = 318, RMSE = 23.2946.
% iteration = 319, RMSE = 27.2902.
% iteration = 320, RMSE = 30.2306.
% iteration = 321, RMSE = 22.9694.
% iteration = 322, RMSE = 23.343.
% iteration = 323, RMSE = 25.0443.
% iteration = 324, RMSE = 26.8078.
% iteration = 325, RMSE = 24.6086.
% iteration = 326, RMSE = 31.5464.
% iteration = 327, RMSE = 23.0981.
% iteration = 328, RMSE = 24.0973.
% iteration = 329, RMSE = 25.698.
% iteration = 330, RMSE = 24.2687.
% iteration = 331, RMSE = 26.8687.
% iteration = 332, RMSE = 29.164.
% iteration = 333, RMSE = 26.3295.
% iteration = 334, RMSE = 24.8228.
% iteration = 335, RMSE = 30.8354.
% iteration = 336, RMSE = 24.3512.
% iteration = 337, RMSE = 23.1517.
% iteration = 338, RMSE = 27.0479.
% iteration = 339, RMSE = 25.718.
% iteration = 340, RMSE = 21.1044.
% iteration = 341, RMSE = 18.8725.
% iteration = 342, RMSE = 29.2591.
% iteration = 343, RMSE = 25.3578.
% iteration = 344, RMSE = 25.1674.
% iteration = 345, RMSE = 30.3557.
% iteration = 346, RMSE = 24.3433.
% iteration = 347, RMSE = 27.4849.
% iteration = 348, RMSE = 22.5199.
% iteration = 349, RMSE = 37.1415.
% iteration = 350, RMSE = 23.0292.
% iteration = 351, RMSE = 29.7075.
% iteration = 352, RMSE = 23.6776.
% iteration = 353, RMSE = 30.557.
% iteration = 354, RMSE = 35.3826.
% iteration = 355, RMSE = 25.1828.
% iteration = 356, RMSE = 28.198.
% iteration = 357, RMSE = 25.4965.
% iteration = 358, RMSE = 26.2324.
% iteration = 359, RMSE = 23.8903.
% iteration = 360, RMSE = 29.5397.
% iteration = 361, RMSE = 27.0551.
% iteration = 362, RMSE = 30.7731.
% iteration = 363, RMSE = 17.2024.
% iteration = 364, RMSE = 21.286.
% iteration = 365, RMSE = 26.9374.
% iteration = 366, RMSE = 30.9261.
% iteration = 367, RMSE = 36.406.
% iteration = 368, RMSE = 31.9129.
% iteration = 369, RMSE = 29.0078.
% iteration = 370, RMSE = 22.7291.
% iteration = 371, RMSE = 22.8885.
% iteration = 372, RMSE = 20.3517.
% iteration = 373, RMSE = 23.6987.
% iteration = 374, RMSE = 22.9477.
% iteration = 375, RMSE = 25.3379.
% iteration = 376, RMSE = 28.9743.
% iteration = 377, RMSE = 26.2745.
% iteration = 378, RMSE = 25.5425.
% iteration = 379, RMSE = 31.7992.
% iteration = 380, RMSE = 30.0719.
% iteration = 381, RMSE = 24.6084.
% iteration = 382, RMSE = 27.3541.
% iteration = 383, RMSE = 31.5239.
% iteration = 384, RMSE = 24.5029.
% iteration = 385, RMSE = 19.5187.
% iteration = 386, RMSE = 22.0875.
% iteration = 387, RMSE = 19.095.
% iteration = 388, RMSE = 26.2192.
% iteration = 389, RMSE = 23.8166.
% iteration = 390, RMSE = 23.6991.
% iteration = 391, RMSE = 22.9849.
% iteration = 392, RMSE = 21.0751.
% iteration = 393, RMSE = 22.3976.
% iteration = 394, RMSE = 29.7658.
% iteration = 395, RMSE = 28.0235.
% iteration = 396, RMSE = 19.5774.
% iteration = 397, RMSE = 23.0677.
% iteration = 398, RMSE = 23.034.
% iteration = 399, RMSE = 25.0289.
% iteration = 400, RMSE = 30.5588.
% iteration = 401, RMSE = 28.4576.
% iteration = 402, RMSE = 20.1706.
% iteration = 403, RMSE = 26.5289.
% iteration = 404, RMSE = 22.2586.
% iteration = 405, RMSE = 27.6799.
% iteration = 406, RMSE = 31.0258.
% iteration = 407, RMSE = 30.1272.
% iteration = 408, RMSE = 23.6268.
% iteration = 409, RMSE = 22.3551.
% iteration = 410, RMSE = 29.5791.
% iteration = 411, RMSE = 17.8966.
% iteration = 412, RMSE = 24.7131.
% iteration = 413, RMSE = 31.2773.
% iteration = 414, RMSE = 29.7801.
% iteration = 415, RMSE = 20.7306.
% iteration = 416, RMSE = 27.3776.
% iteration = 417, RMSE = 19.1539.
% iteration = 418, RMSE = 28.471.
% iteration = 419, RMSE = 27.9105.
% iteration = 420, RMSE = 26.1393.
% iteration = 421, RMSE = 26.4584.
% iteration = 422, RMSE = 25.4512.
% iteration = 423, RMSE = 21.6056.
% iteration = 424, RMSE = 19.9271.
% iteration = 425, RMSE = 29.2771.
% iteration = 426, RMSE = 24.3754.
% iteration = 427, RMSE = 22.9172.
% iteration = 428, RMSE = 24.5123.
% iteration = 429, RMSE = 23.3097.
% iteration = 430, RMSE = 21.0271.
% iteration = 431, RMSE = 25.8741.
% iteration = 432, RMSE = 25.2271.
% iteration = 433, RMSE = 24.6326.
% iteration = 434, RMSE = 27.0855.
% iteration = 435, RMSE = 23.6947.
% iteration = 436, RMSE = 22.0908.
% iteration = 437, RMSE = 16.2536.
% iteration = 438, RMSE = 26.1426.
% iteration = 439, RMSE = 16.7628.
% iteration = 440, RMSE = 19.8321.
% iteration = 441, RMSE = 29.2642.
% iteration = 442, RMSE = 28.5143.
% iteration = 443, RMSE = 25.5061.
% iteration = 444, RMSE = 31.7085.
% iteration = 445, RMSE = 30.7375.
% iteration = 446, RMSE = 20.1773.
% iteration = 447, RMSE = 30.2297.
% iteration = 448, RMSE = 19.6527.
% iteration = 449, RMSE = 23.8162.
% iteration = 450, RMSE = 22.0686.
% iteration = 451, RMSE = 31.1884.
% iteration = 452, RMSE = 27.3717.
% iteration = 453, RMSE = 27.4941.
% iteration = 454, RMSE = 25.6194.
% iteration = 455, RMSE = 26.2866.
% iteration = 456, RMSE = 31.582.
% iteration = 457, RMSE = 18.9805.
% iteration = 458, RMSE = 18.6063.
% iteration = 459, RMSE = 26.921.
% iteration = 460, RMSE = 23.5065.
% iteration = 461, RMSE = 26.6281.
% iteration = 462, RMSE = 28.662.
% iteration = 463, RMSE = 22.5533.
% iteration = 464, RMSE = 22.1515.
% iteration = 465, RMSE = 36.7244.
% iteration = 466, RMSE = 29.6306.
% iteration = 467, RMSE = 30.51.
% iteration = 468, RMSE = 24.9302.
% iteration = 469, RMSE = 31.9679.
% iteration = 470, RMSE = 29.2373.
% iteration = 471, RMSE = 23.8164.
% iteration = 472, RMSE = 19.6894.
% iteration = 473, RMSE = 25.6554.
% iteration = 474, RMSE = 28.0726.
% iteration = 475, RMSE = 22.3847.
% iteration = 476, RMSE = 26.3033.
% iteration = 477, RMSE = 30.8902.
% iteration = 478, RMSE = 25.626.
% iteration = 479, RMSE = 27.7156.
% iteration = 480, RMSE = 21.0197.
% iteration = 481, RMSE = 26.6067.
% iteration = 482, RMSE = 31.6421.
% iteration = 483, RMSE = 23.6382.
% iteration = 484, RMSE = 25.1242.
% iteration = 485, RMSE = 26.3325.
% iteration = 486, RMSE = 20.7816.
% iteration = 487, RMSE = 27.6456.
% iteration = 488, RMSE = 31.4367.
% iteration = 489, RMSE = 24.9624.
% iteration = 490, RMSE = 27.1423.
% iteration = 491, RMSE = 31.0267.
% iteration = 492, RMSE = 26.1001.
% iteration = 493, RMSE = 23.3111.
% iteration = 494, RMSE = 31.4964.
% iteration = 495, RMSE = 22.4215.
% iteration = 496, RMSE = 20.0215.
% iteration = 497, RMSE = 29.6462.
% iteration = 498, RMSE = 28.8352.
% iteration = 499, RMSE = 16.3889.
% iteration = 500, RMSE = 24.6497.
% iteration = 501, RMSE = 24.8601.
% iteration = 502, RMSE = 20.5364.
% iteration = 503, RMSE = 23.6835.
% iteration = 504, RMSE = 30.992.
% iteration = 505, RMSE = 19.8831.
% iteration = 506, RMSE = 23.4378.
% iteration = 507, RMSE = 25.4102.
% iteration = 508, RMSE = 22.0906.
% iteration = 509, RMSE = 23.4189.
% iteration = 510, RMSE = 32.5149.
% iteration = 511, RMSE = 28.8337.
% iteration = 512, RMSE = 31.8763.
% iteration = 513, RMSE = 28.009.
% iteration = 514, RMSE = 25.9088.
% iteration = 515, RMSE = 24.9106.
% iteration = 516, RMSE = 25.4857.
% iteration = 517, RMSE = 27.509.
% iteration = 518, RMSE = 28.876.
% iteration = 519, RMSE = 29.9569.
% iteration = 520, RMSE = 23.6596.
% iteration = 521, RMSE = 27.4083.
% iteration = 522, RMSE = 26.8378.
% iteration = 523, RMSE = 28.8275.
% iteration = 524, RMSE = 23.1829.
% iteration = 525, RMSE = 21.0837.
% iteration = 526, RMSE = 32.5391.
% iteration = 527, RMSE = 26.3739.
% iteration = 528, RMSE = 29.7439.
% iteration = 529, RMSE = 19.8996.
% iteration = 530, RMSE = 28.3799.
% iteration = 531, RMSE = 31.0404.
% iteration = 532, RMSE = 23.5682.
% iteration = 533, RMSE = 20.7204.
% iteration = 534, RMSE = 18.3157.
% iteration = 535, RMSE = 30.3928.
% iteration = 536, RMSE = 22.7543.
% iteration = 537, RMSE = 24.168.
% iteration = 538, RMSE = 24.0528.
% iteration = 539, RMSE = 30.4459.
% iteration = 540, RMSE = 25.9987.
% iteration = 541, RMSE = 23.7757.
% iteration = 542, RMSE = 24.2608.
% iteration = 543, RMSE = 22.0716.
% iteration = 544, RMSE = 23.686.
% iteration = 545, RMSE = 24.3091.
% iteration = 546, RMSE = 21.9352.
% iteration = 547, RMSE = 23.1831.
% iteration = 548, RMSE = 21.4755.
% iteration = 549, RMSE = 22.2788.
% iteration = 550, RMSE = 27.6411.
% iteration = 551, RMSE = 18.8725.
% iteration = 552, RMSE = 25.554.
% iteration = 553, RMSE = 21.299.
% iteration = 554, RMSE = 28.3126.
% iteration = 555, RMSE = 28.1523.
% iteration = 556, RMSE = 23.9725.
% iteration = 557, RMSE = 38.629.
% iteration = 558, RMSE = 30.4715.
% iteration = 559, RMSE = 29.7588.
% iteration = 560, RMSE = 28.1852.
% iteration = 561, RMSE = 22.9647.
% iteration = 562, RMSE = 25.9689.
% iteration = 563, RMSE = 24.1306.
% iteration = 564, RMSE = 22.2998.
% iteration = 565, RMSE = 25.015.
% iteration = 566, RMSE = 25.1858.
% iteration = 567, RMSE = 18.1593.
% iteration = 568, RMSE = 18.6112.
% iteration = 569, RMSE = 21.492.
% iteration = 570, RMSE = 24.3374.
% iteration = 571, RMSE = 31.9074.
% iteration = 572, RMSE = 21.2971.
% iteration = 573, RMSE = 35.9191.
% iteration = 574, RMSE = 24.8574.
% iteration = 575, RMSE = 21.2931.
% iteration = 576, RMSE = 32.6464.
% iteration = 577, RMSE = 28.3937.
% iteration = 578, RMSE = 30.2077.
% iteration = 579, RMSE = 30.3709.
% iteration = 580, RMSE = 28.9225.
% iteration = 581, RMSE = 26.3341.
% iteration = 582, RMSE = 23.1729.
% iteration = 583, RMSE = 23.3172.
% iteration = 584, RMSE = 28.6229.
% iteration = 585, RMSE = 24.8241.
% iteration = 586, RMSE = 33.6105.
% iteration = 587, RMSE = 25.8352.
% iteration = 588, RMSE = 28.1146.
% iteration = 589, RMSE = 27.2301.
% iteration = 590, RMSE = 23.0213.
% iteration = 591, RMSE = 28.656.
% iteration = 592, RMSE = 21.6524.
% iteration = 593, RMSE = 25.6447.
% iteration = 594, RMSE = 21.702.
% iteration = 595, RMSE = 25.4988.
% iteration = 596, RMSE = 23.5357.
% iteration = 597, RMSE = 22.814.
% iteration = 598, RMSE = 21.6204.
% iteration = 599, RMSE = 23.2819.
% iteration = 600, RMSE = 26.35.
% iteration = 601, RMSE = 24.2582.
% iteration = 602, RMSE = 22.0129.
% iteration = 603, RMSE = 23.3624.
% iteration = 604, RMSE = 25.017.
% iteration = 605, RMSE = 24.0423.
% iteration = 606, RMSE = 25.567.
% iteration = 607, RMSE = 26.1659.
% iteration = 608, RMSE = 35.7658.
% iteration = 609, RMSE = 30.8193.
% iteration = 610, RMSE = 32.6702.
% iteration = 611, RMSE = 29.379.
% iteration = 612, RMSE = 27.7056.
% iteration = 613, RMSE = 30.5569.
% iteration = 614, RMSE = 25.6439.
% iteration = 615, RMSE = 20.8483.
% iteration = 616, RMSE = 20.0976.
% iteration = 617, RMSE = 22.8877.
% iteration = 618, RMSE = 25.9297.
% iteration = 619, RMSE = 25.9175.
% iteration = 620, RMSE = 22.0894.
% iteration = 621, RMSE = 36.8548.
% iteration = 622, RMSE = 21.5287.
% iteration = 623, RMSE = 29.3774.
% iteration = 624, RMSE = 22.1965.
% iteration = 625, RMSE = 27.1148.
% iteration = 626, RMSE = 29.016.
% iteration = 627, RMSE = 27.7246.
% iteration = 628, RMSE = 32.5193.
% iteration = 629, RMSE = 31.8503.
% iteration = 630, RMSE = 21.7852.
% iteration = 631, RMSE = 27.2441.
% iteration = 632, RMSE = 26.0905.
% iteration = 633, RMSE = 20.2124.
% iteration = 634, RMSE = 23.5803.
% iteration = 635, RMSE = 27.7308.
% iteration = 636, RMSE = 26.4368.
% iteration = 637, RMSE = 20.6345.
% iteration = 638, RMSE = 23.6061.
% iteration = 639, RMSE = 21.4016.
% iteration = 640, RMSE = 26.1257.
% iteration = 641, RMSE = 25.1491.
% iteration = 642, RMSE = 26.1871.
% iteration = 643, RMSE = 30.9767.
% iteration = 644, RMSE = 23.6649.
% iteration = 645, RMSE = 25.0222.
% iteration = 646, RMSE = 22.5637.
% iteration = 647, RMSE = 30.2112.
% iteration = 648, RMSE = 24.9889.
% iteration = 649, RMSE = 25.5353.
% iteration = 650, RMSE = 29.7103.
% iteration = 651, RMSE = 16.9035.
% iteration = 652, RMSE = 19.0859.
% iteration = 653, RMSE = 22.2331.
% iteration = 654, RMSE = 19.331.
% iteration = 655, RMSE = 21.0141.
% iteration = 656, RMSE = 35.3381.
% iteration = 657, RMSE = 22.6894.
% iteration = 658, RMSE = 15.8966.
% iteration = 659, RMSE = 19.1666.
% iteration = 660, RMSE = 24.8054.
% iteration = 661, RMSE = 20.3655.
% iteration = 662, RMSE = 20.5861.
% iteration = 663, RMSE = 21.7078.
% iteration = 664, RMSE = 20.7995.
% iteration = 665, RMSE = 17.8706.
% iteration = 666, RMSE = 18.9524.
% iteration = 667, RMSE = 22.0744.
% iteration = 668, RMSE = 17.5755.
% iteration = 669, RMSE = 25.2634.
% iteration = 670, RMSE = 24.5187.
% iteration = 671, RMSE = 23.1394.
% iteration = 672, RMSE = 28.2166.
% iteration = 673, RMSE = 22.9063.
% iteration = 674, RMSE = 24.8821.
% iteration = 675, RMSE = 22.1919.
% iteration = 676, RMSE = 20.0329.
% iteration = 677, RMSE = 25.1474.
% iteration = 678, RMSE = 21.1361.
% iteration = 679, RMSE = 29.6451.
% iteration = 680, RMSE = 19.7778.
% iteration = 681, RMSE = 25.3717.
% iteration = 682, RMSE = 28.3038.
% iteration = 683, RMSE = 34.983.
% iteration = 684, RMSE = 20.1208.
% iteration = 685, RMSE = 26.1688.
% iteration = 686, RMSE = 23.0544.
% iteration = 687, RMSE = 20.4231.
% iteration = 688, RMSE = 18.954.
% iteration = 689, RMSE = 23.2534.
% iteration = 690, RMSE = 22.3545.
% iteration = 691, RMSE = 23.3654.
% iteration = 692, RMSE = 33.0785.
% iteration = 693, RMSE = 21.9316.
% iteration = 694, RMSE = 20.4215.
% iteration = 695, RMSE = 22.2278.
% iteration = 696, RMSE = 24.0082.
% iteration = 697, RMSE = 20.9078.
% iteration = 698, RMSE = 33.5709.
% iteration = 699, RMSE = 25.002.
% iteration = 700, RMSE = 29.1371.
% iteration = 701, RMSE = 28.1995.
% iteration = 702, RMSE = 20.5515.
% iteration = 703, RMSE = 23.0182.
% iteration = 704, RMSE = 29.1768.
% iteration = 705, RMSE = 29.1152.
% iteration = 706, RMSE = 29.285.
% iteration = 707, RMSE = 28.2834.
% iteration = 708, RMSE = 30.3135.
% iteration = 709, RMSE = 22.2423.
% iteration = 710, RMSE = 25.2855.
% iteration = 711, RMSE = 23.7925.
% iteration = 712, RMSE = 30.6732.
% iteration = 713, RMSE = 23.3746.
% iteration = 714, RMSE = 21.7513.
% iteration = 715, RMSE = 24.5711.
% iteration = 716, RMSE = 23.8322.
% iteration = 717, RMSE = 31.3959.
% iteration = 718, RMSE = 20.256.
% iteration = 719, RMSE = 26.6835.
% iteration = 720, RMSE = 27.6423.
% iteration = 721, RMSE = 23.8489.
% iteration = 722, RMSE = 27.2504.
% iteration = 723, RMSE = 28.1045.
% iteration = 724, RMSE = 25.74.
% iteration = 725, RMSE = 24.7026.
% iteration = 726, RMSE = 33.9804.
% iteration = 727, RMSE = 22.4197.
% iteration = 728, RMSE = 24.5532.
% iteration = 729, RMSE = 23.4475.
% iteration = 730, RMSE = 26.2317.
% iteration = 731, RMSE = 26.1599.
% iteration = 732, RMSE = 25.0639.
% iteration = 733, RMSE = 30.6803.
% iteration = 734, RMSE = 22.4084.
% iteration = 735, RMSE = 25.5424.
% iteration = 736, RMSE = 25.2772.
% iteration = 737, RMSE = 20.1403.
% iteration = 738, RMSE = 26.7905.
% iteration = 739, RMSE = 24.2829.
% iteration = 740, RMSE = 30.431.
% iteration = 741, RMSE = 31.9553.
% iteration = 742, RMSE = 20.2049.
% iteration = 743, RMSE = 22.1983.
% iteration = 744, RMSE = 27.1236.
% iteration = 745, RMSE = 22.9897.
% iteration = 746, RMSE = 23.4926.
% iteration = 747, RMSE = 24.2391.
% iteration = 748, RMSE = 21.892.
% iteration = 749, RMSE = 30.0187.
% iteration = 750, RMSE = 26.7833.
% iteration = 751, RMSE = 28.3276.
% iteration = 752, RMSE = 21.8208.
% iteration = 753, RMSE = 26.5847.
% iteration = 754, RMSE = 24.5954.
% iteration = 755, RMSE = 27.5294.
% iteration = 756, RMSE = 21.7482.
% iteration = 757, RMSE = 26.7064.
% iteration = 758, RMSE = 34.4336.
% iteration = 759, RMSE = 28.7534.
% iteration = 760, RMSE = 27.1746.
% iteration = 761, RMSE = 28.9093.
% iteration = 762, RMSE = 25.8351.
% iteration = 763, RMSE = 26.9239.
% iteration = 764, RMSE = 26.4293.
% iteration = 765, RMSE = 29.3474.
% iteration = 766, RMSE = 38.6723.
% iteration = 767, RMSE = 26.8501.
% iteration = 768, RMSE = 26.0751.
% iteration = 769, RMSE = 23.5583.
% iteration = 770, RMSE = 21.9487.
% iteration = 771, RMSE = 23.0072.
% iteration = 772, RMSE = 20.638.
% iteration = 773, RMSE = 28.085.
% iteration = 774, RMSE = 31.8457.
% iteration = 775, RMSE = 18.488.
% iteration = 776, RMSE = 24.4695.
% iteration = 777, RMSE = 21.9811.
% iteration = 778, RMSE = 31.0937.
% iteration = 779, RMSE = 25.9861.
% iteration = 780, RMSE = 20.4409.
% iteration = 781, RMSE = 23.5212.
% iteration = 782, RMSE = 27.6617.
% iteration = 783, RMSE = 25.1437.
% iteration = 784, RMSE = 23.7806.
% iteration = 785, RMSE = 27.583.
% iteration = 786, RMSE = 24.3182.
% iteration = 787, RMSE = 17.5777.
% iteration = 788, RMSE = 17.3024.
% iteration = 789, RMSE = 21.3097.
% iteration = 790, RMSE = 19.6912.
% iteration = 791, RMSE = 24.6842.
% iteration = 792, RMSE = 25.9786.
% iteration = 793, RMSE = 31.6784.
% iteration = 794, RMSE = 30.3227.
% iteration = 795, RMSE = 23.2068.
% iteration = 796, RMSE = 18.5178.
% iteration = 797, RMSE = 26.0022.
% iteration = 798, RMSE = 20.5803.
% iteration = 799, RMSE = 29.1651.
% iteration = 800, RMSE = 17.7198.
% iteration = 801, RMSE = 28.4919.
% iteration = 802, RMSE = 28.9472.
% iteration = 803, RMSE = 26.1771.
% iteration = 804, RMSE = 26.8653.
% iteration = 805, RMSE = 20.9639.
% iteration = 806, RMSE = 25.9874.
% iteration = 807, RMSE = 25.4753.
% iteration = 808, RMSE = 26.074.
% iteration = 809, RMSE = 33.9803.
% iteration = 810, RMSE = 18.2203.
% iteration = 811, RMSE = 27.2066.
% iteration = 812, RMSE = 22.4828.
% iteration = 813, RMSE = 25.5063.
% iteration = 814, RMSE = 28.7291.
% iteration = 815, RMSE = 21.6855.
% iteration = 816, RMSE = 31.3353.
% iteration = 817, RMSE = 23.1274.
% iteration = 818, RMSE = 26.1485.
% iteration = 819, RMSE = 23.4215.
% iteration = 820, RMSE = 30.6449.
% iteration = 821, RMSE = 23.3651.
% iteration = 822, RMSE = 25.7051.
% iteration = 823, RMSE = 27.0664.
% iteration = 824, RMSE = 26.3804.
% iteration = 825, RMSE = 29.9675.
% iteration = 826, RMSE = 21.0065.
% iteration = 827, RMSE = 28.7814.
% iteration = 828, RMSE = 25.6194.
% iteration = 829, RMSE = 28.3106.
% iteration = 830, RMSE = 23.4634.
% iteration = 831, RMSE = 20.939.
% iteration = 832, RMSE = 29.2341.
% iteration = 833, RMSE = 26.6797.
% iteration = 834, RMSE = 29.9007.
% iteration = 835, RMSE = 27.6025.
% iteration = 836, RMSE = 29.7885.
% iteration = 837, RMSE = 28.5587.
% iteration = 838, RMSE = 19.6056.
% iteration = 839, RMSE = 24.3529.
% iteration = 840, RMSE = 25.9309.
% iteration = 841, RMSE = 18.743.
% iteration = 842, RMSE = 29.7021.
% iteration = 843, RMSE = 27.2916.
% iteration = 844, RMSE = 23.0981.
% iteration = 845, RMSE = 26.6502.
% iteration = 846, RMSE = 22.9539.
% iteration = 847, RMSE = 28.4993.
% iteration = 848, RMSE = 23.7615.
% iteration = 849, RMSE = 26.2248.
% iteration = 850, RMSE = 24.7855.
% iteration = 851, RMSE = 16.6116.
% iteration = 852, RMSE = 23.6356.
% iteration = 853, RMSE = 34.3051.
% iteration = 854, RMSE = 31.8908.
% iteration = 855, RMSE = 23.3267.
% iteration = 856, RMSE = 26.4696.
% iteration = 857, RMSE = 29.9642.
% iteration = 858, RMSE = 22.1813.
% iteration = 859, RMSE = 26.8302.
% iteration = 860, RMSE = 27.4691.
% iteration = 861, RMSE = 24.8564.
% iteration = 862, RMSE = 27.1879.
% iteration = 863, RMSE = 20.8936.
% iteration = 864, RMSE = 24.9377.
% iteration = 865, RMSE = 22.3319.
% iteration = 866, RMSE = 18.8478.
% iteration = 867, RMSE = 23.6091.
% iteration = 868, RMSE = 23.6592.
% iteration = 869, RMSE = 23.3597.
% iteration = 870, RMSE = 20.0206.
% iteration = 871, RMSE = 16.0242.
% iteration = 872, RMSE = 23.3467.
% iteration = 873, RMSE = 17.6077.
% iteration = 874, RMSE = 25.3233.
% iteration = 875, RMSE = 26.4203.
% iteration = 876, RMSE = 25.1642.
% iteration = 877, RMSE = 28.6199.
% iteration = 878, RMSE = 34.2804.
% iteration = 879, RMSE = 22.4701.
% iteration = 880, RMSE = 30.0427.
% iteration = 881, RMSE = 26.357.
% iteration = 882, RMSE = 14.8603.
% iteration = 883, RMSE = 26.4185.
% iteration = 884, RMSE = 25.5642.
% iteration = 885, RMSE = 23.0305.
% iteration = 886, RMSE = 25.3217.
% iteration = 887, RMSE = 28.79.
% iteration = 888, RMSE = 33.3466.
% iteration = 889, RMSE = 22.3328.
% iteration = 890, RMSE = 28.0222.
% iteration = 891, RMSE = 23.5319.
% iteration = 892, RMSE = 27.6245.
% iteration = 893, RMSE = 26.6376.
% iteration = 894, RMSE = 21.6068.
% iteration = 895, RMSE = 21.251.
% iteration = 896, RMSE = 26.2762.
% iteration = 897, RMSE = 31.4621.
% iteration = 898, RMSE = 26.8009.
% iteration = 899, RMSE = 28.3426.
% iteration = 900, RMSE = 28.4055.
% iteration = 901, RMSE = 28.7368.
% iteration = 902, RMSE = 25.9265.
% iteration = 903, RMSE = 30.6451.
% iteration = 904, RMSE = 32.8243.
% iteration = 905, RMSE = 20.2871.
% iteration = 906, RMSE = 28.0152.
% iteration = 907, RMSE = 31.2762.
% iteration = 908, RMSE = 20.4426.
% iteration = 909, RMSE = 37.264.
% iteration = 910, RMSE = 23.7468.
% iteration = 911, RMSE = 26.5814.
% iteration = 912, RMSE = 26.1188.
% iteration = 913, RMSE = 23.7221.
% iteration = 914, RMSE = 33.1233.
% iteration = 915, RMSE = 22.1944.
% iteration = 916, RMSE = 30.5784.
% iteration = 917, RMSE = 26.8518.
% iteration = 918, RMSE = 21.7545.
% iteration = 919, RMSE = 20.7431.
% iteration = 920, RMSE = 29.0988.
% iteration = 921, RMSE = 31.5597.
% iteration = 922, RMSE = 25.3568.
% iteration = 923, RMSE = 24.5318.
% iteration = 924, RMSE = 20.8352.
% iteration = 925, RMSE = 28.739.
% iteration = 926, RMSE = 19.8476.
% iteration = 927, RMSE = 25.0566.
% iteration = 928, RMSE = 22.6362.
% iteration = 929, RMSE = 24.5851.
% iteration = 930, RMSE = 29.4011.
% iteration = 931, RMSE = 21.8374.
% iteration = 932, RMSE = 33.4381.
% iteration = 933, RMSE = 22.0365.
% iteration = 934, RMSE = 28.2804.
% iteration = 935, RMSE = 22.783.
% iteration = 936, RMSE = 19.798.
% iteration = 937, RMSE = 22.2067.
% iteration = 938, RMSE = 25.046.
% iteration = 939, RMSE = 32.7694.
% iteration = 940, RMSE = 22.4412.
% iteration = 941, RMSE = 20.4556.
% iteration = 942, RMSE = 19.8823.
% iteration = 943, RMSE = 20.7541.
% iteration = 944, RMSE = 27.4968.
% iteration = 945, RMSE = 20.3067.
% iteration = 946, RMSE = 24.866.
% iteration = 947, RMSE = 28.4035.
% iteration = 948, RMSE = 32.4175.
% iteration = 949, RMSE = 23.3555.
% iteration = 950, RMSE = 19.0743.
% iteration = 951, RMSE = 24.9895.
% iteration = 952, RMSE = 21.9559.
% iteration = 953, RMSE = 23.9551.
% iteration = 954, RMSE = 26.225.
% iteration = 955, RMSE = 19.747.
% iteration = 956, RMSE = 18.6469.
% iteration = 957, RMSE = 21.9394.
% iteration = 958, RMSE = 19.63.
% iteration = 959, RMSE = 17.2006.
% iteration = 960, RMSE = 18.3182.
% iteration = 961, RMSE = 27.8741.
% iteration = 962, RMSE = 22.9214.
% iteration = 963, RMSE = 26.8447.
% iteration = 964, RMSE = 33.838.
% iteration = 965, RMSE = 31.3237.
% iteration = 966, RMSE = 23.7073.
% iteration = 967, RMSE = 20.6634.
% iteration = 968, RMSE = 28.2131.
% iteration = 969, RMSE = 22.2822.
% iteration = 970, RMSE = 30.051.
% iteration = 971, RMSE = 34.403.
% iteration = 972, RMSE = 30.457.
% iteration = 973, RMSE = 25.2967.
% iteration = 974, RMSE = 23.5804.
% iteration = 975, RMSE = 21.2006.
% iteration = 976, RMSE = 23.386.
% iteration = 977, RMSE = 24.4656.
% iteration = 978, RMSE = 21.7322.
% iteration = 979, RMSE = 28.912.
% iteration = 980, RMSE = 29.5563.
% iteration = 981, RMSE = 29.6958.
% iteration = 982, RMSE = 20.9498.
% iteration = 983, RMSE = 22.8735.
% iteration = 984, RMSE = 29.3836.
% iteration = 985, RMSE = 31.7651.
% iteration = 986, RMSE = 25.3167.
% iteration = 987, RMSE = 23.9064.
% iteration = 988, RMSE = 24.1437.
% iteration = 989, RMSE = 23.5709.
% iteration = 990, RMSE = 23.6979.
% iteration = 991, RMSE = 21.1391.
% iteration = 992, RMSE = 24.4655.
% iteration = 993, RMSE = 26.9105.
% iteration = 994, RMSE = 25.8445.
% iteration = 995, RMSE = 29.8534.
% iteration = 996, RMSE = 26.3448.
% iteration = 997, RMSE = 22.9351.
% iteration = 998, RMSE = 23.074.
% iteration = 999, RMSE = 27.8754.
% iteration = 1000, RMSE = 39.7365.
% iteration = 1001, RMSE = 35.0828.
% iteration = 1002, RMSE = 19.9168.
% iteration = 1003, RMSE = 22.7668.
% iteration = 1004, RMSE = 24.7262.
% iteration = 1005, RMSE = 24.0446.
% iteration = 1006, RMSE = 35.5044.
% iteration = 1007, RMSE = 32.7629.
% iteration = 1008, RMSE = 28.2103.
% iteration = 1009, RMSE = 35.9136.
% iteration = 1010, RMSE = 27.6644.
% iteration = 1011, RMSE = 28.9496.
% iteration = 1012, RMSE = 23.5619.
% iteration = 1013, RMSE = 28.3551.
% iteration = 1014, RMSE = 31.746.
% iteration = 1015, RMSE = 18.8604.
% iteration = 1016, RMSE = 22.1377.
% iteration = 1017, RMSE = 19.1633.
% iteration = 1018, RMSE = 25.8644.
% iteration = 1019, RMSE = 27.5559.
% iteration = 1020, RMSE = 19.371.
% iteration = 1021, RMSE = 25.8358.
% iteration = 1022, RMSE = 28.109.
% iteration = 1023, RMSE = 30.569.
% iteration = 1024, RMSE = 22.8376.
% iteration = 1025, RMSE = 28.113.
% iteration = 1026, RMSE = 27.8196.
% iteration = 1027, RMSE = 24.4294.
% iteration = 1028, RMSE = 20.2577.
% iteration = 1029, RMSE = 27.6914.
% iteration = 1030, RMSE = 19.5811.
% iteration = 1031, RMSE = 29.2653.
% iteration = 1032, RMSE = 21.1929.
% iteration = 1033, RMSE = 21.2934.
% iteration = 1034, RMSE = 31.5364.
% iteration = 1035, RMSE = 26.7517.
% iteration = 1036, RMSE = 30.025.
% iteration = 1037, RMSE = 24.1863.
% iteration = 1038, RMSE = 29.7475.
% iteration = 1039, RMSE = 33.23.
% iteration = 1040, RMSE = 26.0664.
% iteration = 1041, RMSE = 30.619.
% iteration = 1042, RMSE = 24.2159.
% iteration = 1043, RMSE = 23.8269.
% iteration = 1044, RMSE = 30.8456.
% iteration = 1045, RMSE = 24.2867.
% iteration = 1046, RMSE = 24.0402.
% iteration = 1047, RMSE = 23.561.
% iteration = 1048, RMSE = 25.9352.
% iteration = 1049, RMSE = 20.1206.
% iteration = 1050, RMSE = 20.7486.
% iteration = 1051, RMSE = 18.3897.
% iteration = 1052, RMSE = 22.6256.
% iteration = 1053, RMSE = 20.0962.
% iteration = 1054, RMSE = 20.1246.
% iteration = 1055, RMSE = 21.9233.
% iteration = 1056, RMSE = 28.344.
% iteration = 1057, RMSE = 23.4976.
% iteration = 1058, RMSE = 21.5231.
% iteration = 1059, RMSE = 26.43.
% iteration = 1060, RMSE = 22.9825.
% iteration = 1061, RMSE = 28.172.
% iteration = 1062, RMSE = 23.3843.
% iteration = 1063, RMSE = 22.9709.
% iteration = 1064, RMSE = 18.5555.
% iteration = 1065, RMSE = 25.702.
% iteration = 1066, RMSE = 16.0822.
% iteration = 1067, RMSE = 13.9614.
% iteration = 1068, RMSE = 20.1693.
% iteration = 1069, RMSE = 20.6931.
% iteration = 1070, RMSE = 24.506.
% iteration = 1071, RMSE = 26.2677.
% iteration = 1072, RMSE = 21.0972.
% iteration = 1073, RMSE = 26.9625.
% iteration = 1074, RMSE = 28.6445.
% iteration = 1075, RMSE = 22.7249.
% iteration = 1076, RMSE = 23.3875.
% iteration = 1077, RMSE = 18.9576.
% iteration = 1078, RMSE = 16.8713.
% iteration = 1079, RMSE = 19.0814.
% iteration = 1080, RMSE = 23.9563.
% iteration = 1081, RMSE = 24.2692.
% iteration = 1082, RMSE = 29.6874.
% iteration = 1083, RMSE = 28.4489.
% iteration = 1084, RMSE = 29.392.
% iteration = 1085, RMSE = 26.0258.
% iteration = 1086, RMSE = 22.6592.
% iteration = 1087, RMSE = 26.6713.
% iteration = 1088, RMSE = 24.4266.
% iteration = 1089, RMSE = 26.3425.
% iteration = 1090, RMSE = 23.1491.
% iteration = 1091, RMSE = 32.8503.
% iteration = 1092, RMSE = 23.8564.
% iteration = 1093, RMSE = 24.8951.
% iteration = 1094, RMSE = 23.1469.
% iteration = 1095, RMSE = 19.2892.
% iteration = 1096, RMSE = 26.7319.
% iteration = 1097, RMSE = 28.4616.
% iteration = 1098, RMSE = 23.955.
% iteration = 1099, RMSE = 19.7252.
% iteration = 1100, RMSE = 25.3053.
% iteration = 1101, RMSE = 50.052.
% iteration = 1102, RMSE = 35.9852.
% iteration = 1103, RMSE = 39.6318.
% iteration = 1104, RMSE = 29.4352.
% iteration = 1105, RMSE = 22.2959.
% iteration = 1106, RMSE = 20.3848.
% iteration = 1107, RMSE = 23.0548.
% iteration = 1108, RMSE = 26.0567.
% iteration = 1109, RMSE = 18.6922.
% iteration = 1110, RMSE = 22.0838.
% iteration = 1111, RMSE = 23.057.
% iteration = 1112, RMSE = 19.0792.
% iteration = 1113, RMSE = 35.9256.
% iteration = 1114, RMSE = 16.8854.
% iteration = 1115, RMSE = 25.6536.
% iteration = 1116, RMSE = 27.23.
% iteration = 1117, RMSE = 29.9372.
% iteration = 1118, RMSE = 29.226.
% iteration = 1119, RMSE = 36.5801.
% iteration = 1120, RMSE = 32.0854.
% iteration = 1121, RMSE = 21.278.
% iteration = 1122, RMSE = 24.8463.
% iteration = 1123, RMSE = 20.9868.
% iteration = 1124, RMSE = 26.621.
% iteration = 1125, RMSE = 26.3993.
% iteration = 1126, RMSE = 22.2495.
% iteration = 1127, RMSE = 26.2084.
% iteration = 1128, RMSE = 22.3321.
% iteration = 1129, RMSE = 26.4948.
% iteration = 1130, RMSE = 26.8677.
% iteration = 1131, RMSE = 28.4143.
% iteration = 1132, RMSE = 28.1249.
% iteration = 1133, RMSE = 28.0597.
% iteration = 1134, RMSE = 30.5642.
% iteration = 1135, RMSE = 30.1108.
% iteration = 1136, RMSE = 28.8945.
% iteration = 1137, RMSE = 22.1248.
% iteration = 1138, RMSE = 28.1181.
% iteration = 1139, RMSE = 35.057.
% iteration = 1140, RMSE = 26.2207.
% iteration = 1141, RMSE = 19.2716.
% iteration = 1142, RMSE = 23.871.
% iteration = 1143, RMSE = 28.4487.
% iteration = 1144, RMSE = 32.2931.
% iteration = 1145, RMSE = 21.1393.
% iteration = 1146, RMSE = 21.9567.
% iteration = 1147, RMSE = 19.1017.
% iteration = 1148, RMSE = 26.0342.
% iteration = 1149, RMSE = 28.4841.
% iteration = 1150, RMSE = 36.4589.
% iteration = 1151, RMSE = 29.0778.
% iteration = 1152, RMSE = 17.3402.
% iteration = 1153, RMSE = 24.8112.
% iteration = 1154, RMSE = 17.9926.
% iteration = 1155, RMSE = 22.7978.
% iteration = 1156, RMSE = 18.2438.
% iteration = 1157, RMSE = 17.3909.
% iteration = 1158, RMSE = 25.3718.
% iteration = 1159, RMSE = 21.094.
% iteration = 1160, RMSE = 25.7246.
% iteration = 1161, RMSE = 20.0544.
% iteration = 1162, RMSE = 20.8982.
% iteration = 1163, RMSE = 31.1403.
% iteration = 1164, RMSE = 15.0219.
% iteration = 1165, RMSE = 26.8198.
% iteration = 1166, RMSE = 25.8911.
% iteration = 1167, RMSE = 23.0444.
% iteration = 1168, RMSE = 16.6048.
% iteration = 1169, RMSE = 22.3117.
% iteration = 1170, RMSE = 23.2261.
% iteration = 1171, RMSE = 20.63.
% iteration = 1172, RMSE = 23.9982.
% iteration = 1173, RMSE = 20.6854.
% iteration = 1174, RMSE = 18.4953.
% iteration = 1175, RMSE = 20.4132.
% iteration = 1176, RMSE = 26.4432.
% iteration = 1177, RMSE = 24.0773.
% iteration = 1178, RMSE = 24.1462.
% iteration = 1179, RMSE = 18.7969.
% iteration = 1180, RMSE = 19.9646.
% iteration = 1181, RMSE = 16.9399.
% iteration = 1182, RMSE = 24.544.
% iteration = 1183, RMSE = 17.2059.
% iteration = 1184, RMSE = 31.5953.
% iteration = 1185, RMSE = 23.587.
% iteration = 1186, RMSE = 22.1086.
% iteration = 1187, RMSE = 20.7888.
% iteration = 1188, RMSE = 27.5538.
% iteration = 1189, RMSE = 23.9068.
% iteration = 1190, RMSE = 35.3276.
% iteration = 1191, RMSE = 29.4816.
% iteration = 1192, RMSE = 20.6828.
% iteration = 1193, RMSE = 19.593.
% iteration = 1194, RMSE = 28.7386.
% iteration = 1195, RMSE = 31.7044.
% iteration = 1196, RMSE = 26.2464.
% iteration = 1197, RMSE = 29.2599.
% iteration = 1198, RMSE = 28.3008.
% iteration = 1199, RMSE = 28.8593.
% iteration = 1200, RMSE = 22.1869.
% iteration = 1201, RMSE = 22.9509.
% iteration = 1202, RMSE = 37.3829.
% iteration = 1203, RMSE = 22.7665.
% iteration = 1204, RMSE = 20.7982.
% iteration = 1205, RMSE = 26.4783.
% iteration = 1206, RMSE = 26.2188.
% iteration = 1207, RMSE = 27.3953.
% iteration = 1208, RMSE = 36.0518.
% iteration = 1209, RMSE = 20.6557.
% iteration = 1210, RMSE = 24.1805.
% iteration = 1211, RMSE = 30.5177.
% iteration = 1212, RMSE = 32.7256.
% iteration = 1213, RMSE = 19.5446.
% iteration = 1214, RMSE = 25.1156.
% iteration = 1215, RMSE = 19.7068.
% iteration = 1216, RMSE = 16.3043.
% iteration = 1217, RMSE = 24.1589.
% iteration = 1218, RMSE = 22.4885.
% iteration = 1219, RMSE = 18.0779.
% iteration = 1220, RMSE = 22.2142.
% iteration = 1221, RMSE = 18.1465.
% iteration = 1222, RMSE = 20.6729.
% iteration = 1223, RMSE = 22.5051.
% iteration = 1224, RMSE = 22.935.
% iteration = 1225, RMSE = 22.4041.
% iteration = 1226, RMSE = 21.5971.
% iteration = 1227, RMSE = 21.8954.
% iteration = 1228, RMSE = 18.6235.
% iteration = 1229, RMSE = 17.4163.
% iteration = 1230, RMSE = 22.0918.
% iteration = 1231, RMSE = 35.889.
% iteration = 1232, RMSE = 26.0617.
% iteration = 1233, RMSE = 16.6779.
% iteration = 1234, RMSE = 16.8229.
% iteration = 1235, RMSE = 21.062.
% iteration = 1236, RMSE = 18.8543.
% iteration = 1237, RMSE = 25.6278.
% iteration = 1238, RMSE = 31.0909.
% iteration = 1239, RMSE = 20.5793.
% iteration = 1240, RMSE = 25.6555.
% iteration = 1241, RMSE = 24.4914.
% iteration = 1242, RMSE = 24.7609.
% iteration = 1243, RMSE = 24.5814.
% iteration = 1244, RMSE = 22.5257.
% iteration = 1245, RMSE = 19.6281.
% iteration = 1246, RMSE = 22.2726.
% iteration = 1247, RMSE = 33.5696.
% iteration = 1248, RMSE = 25.4377.
% iteration = 1249, RMSE = 24.003.
% iteration = 1250, RMSE = 24.9894.
% iteration = 1251, RMSE = 26.2936.
% iteration = 1252, RMSE = 27.9966.
% iteration = 1253, RMSE = 21.0361.
% iteration = 1254, RMSE = 19.0239.
% iteration = 1255, RMSE = 26.0094.
% iteration = 1256, RMSE = 25.7179.
% iteration = 1257, RMSE = 19.3636.
% iteration = 1258, RMSE = 34.5778.
% iteration = 1259, RMSE = 19.3809.
% iteration = 1260, RMSE = 22.6345.
% iteration = 1261, RMSE = 27.3639.
% iteration = 1262, RMSE = 27.7889.
% iteration = 1263, RMSE = 17.8627.
% iteration = 1264, RMSE = 25.4239.
% iteration = 1265, RMSE = 24.1153.
% iteration = 1266, RMSE = 24.1798.
% iteration = 1267, RMSE = 21.2717.
% iteration = 1268, RMSE = 21.7444.
% iteration = 1269, RMSE = 20.9759.
% iteration = 1270, RMSE = 15.8999.
% iteration = 1271, RMSE = 19.5151.
% iteration = 1272, RMSE = 28.0298.
% iteration = 1273, RMSE = 22.5359.
% iteration = 1274, RMSE = 24.621.
% iteration = 1275, RMSE = 30.8395.
% iteration = 1276, RMSE = 24.9233.
% iteration = 1277, RMSE = 20.8988.
% iteration = 1278, RMSE = 25.0073.
% iteration = 1279, RMSE = 23.9835.
% iteration = 1280, RMSE = 27.5462.
% iteration = 1281, RMSE = 31.0489.
% iteration = 1282, RMSE = 27.4103.
% iteration = 1283, RMSE = 24.9071.
% iteration = 1284, RMSE = 25.7634.
% iteration = 1285, RMSE = 24.9584.
% iteration = 1286, RMSE = 24.5792.
% iteration = 1287, RMSE = 29.1256.
% iteration = 1288, RMSE = 18.7436.
% iteration = 1289, RMSE = 16.8048.
% iteration = 1290, RMSE = 18.1867.
% iteration = 1291, RMSE = 23.4887.
% iteration = 1292, RMSE = 24.4663.
% iteration = 1293, RMSE = 22.2663.
% iteration = 1294, RMSE = 24.5225.
% iteration = 1295, RMSE = 25.3352.
% iteration = 1296, RMSE = 24.0375.
% iteration = 1297, RMSE = 21.9921.
% iteration = 1298, RMSE = 24.3058.
% iteration = 1299, RMSE = 23.5083.
% iteration = 1300, RMSE = 27.1499.
% iteration = 1301, RMSE = 23.0584.
% iteration = 1302, RMSE = 25.5106.
% iteration = 1303, RMSE = 23.6825.
% iteration = 1304, RMSE = 27.3774.
% iteration = 1305, RMSE = 17.3335.
% iteration = 1306, RMSE = 17.138.
% iteration = 1307, RMSE = 16.6512.
% iteration = 1308, RMSE = 14.6844.
% iteration = 1309, RMSE = 22.9664.
% iteration = 1310, RMSE = 18.5083.
% iteration = 1311, RMSE = 20.7191.
% iteration = 1312, RMSE = 21.3018.
% iteration = 1313, RMSE = 19.1697.
% iteration = 1314, RMSE = 20.3934.
% iteration = 1315, RMSE = 23.2381.
% iteration = 1316, RMSE = 22.4872.
% iteration = 1317, RMSE = 15.5898.
% iteration = 1318, RMSE = 13.6117.
% iteration = 1319, RMSE = 20.8135.
% iteration = 1320, RMSE = 23.8864.
% iteration = 1321, RMSE = 16.0878.
% iteration = 1322, RMSE = 20.6616.
% iteration = 1323, RMSE = 28.2521.
% iteration = 1324, RMSE = 17.6311.
% iteration = 1325, RMSE = 24.5307.
% iteration = 1326, RMSE = 17.9406.
% iteration = 1327, RMSE = 19.5153.
% iteration = 1328, RMSE = 17.4644.
% iteration = 1329, RMSE = 19.8518.
% iteration = 1330, RMSE = 19.1641.
% iteration = 1331, RMSE = 15.189.
% iteration = 1332, RMSE = 20.4774.
% iteration = 1333, RMSE = 21.8009.
% iteration = 1334, RMSE = 17.6779.
% iteration = 1335, RMSE = 26.9495.
% iteration = 1336, RMSE = 19.0333.
% iteration = 1337, RMSE = 19.1547.
% iteration = 1338, RMSE = 19.3102.
% iteration = 1339, RMSE = 25.4502.
% iteration = 1340, RMSE = 14.502.
% iteration = 1341, RMSE = 28.2288.
% iteration = 1342, RMSE = 33.3849.
% iteration = 1343, RMSE = 24.5747.
% iteration = 1344, RMSE = 24.2851.
% iteration = 1345, RMSE = 24.2501.
% iteration = 1346, RMSE = 19.8757.
% iteration = 1347, RMSE = 21.7259.
% iteration = 1348, RMSE = 23.5423.
% iteration = 1349, RMSE = 30.2639.
% iteration = 1350, RMSE = 29.8328.
% iteration = 1351, RMSE = 29.7419.
% iteration = 1352, RMSE = 20.6986.
% iteration = 1353, RMSE = 18.5779.
% iteration = 1354, RMSE = 19.999.
% iteration = 1355, RMSE = 25.6568.
% iteration = 1356, RMSE = 21.2201.
% iteration = 1357, RMSE = 24.0666.
% iteration = 1358, RMSE = 20.8697.
% iteration = 1359, RMSE = 22.5341.
% iteration = 1360, RMSE = 25.5084.
% iteration = 1361, RMSE = 22.1376.
% iteration = 1362, RMSE = 26.7298.
% iteration = 1363, RMSE = 17.0476.
% iteration = 1364, RMSE = 30.9024.
% iteration = 1365, RMSE = 25.2774.
% iteration = 1366, RMSE = 22.0848.
% iteration = 1367, RMSE = 21.608.
% iteration = 1368, RMSE = 23.6055.
% iteration = 1369, RMSE = 20.7353.
% iteration = 1370, RMSE = 26.4061.
% iteration = 1371, RMSE = 24.2783.
% iteration = 1372, RMSE = 27.5668.
% iteration = 1373, RMSE = 23.1042.
% iteration = 1374, RMSE = 17.5387.
% iteration = 1375, RMSE = 15.0282.
% iteration = 1376, RMSE = 19.5932.
% iteration = 1377, RMSE = 29.6464.
% iteration = 1378, RMSE = 27.1261.
% iteration = 1379, RMSE = 25.1456.
% iteration = 1380, RMSE = 21.9615.
% iteration = 1381, RMSE = 26.8849.
% iteration = 1382, RMSE = 26.6963.
% iteration = 1383, RMSE = 29.5257.
% iteration = 1384, RMSE = 21.9757.
% iteration = 1385, RMSE = 22.7902.
% iteration = 1386, RMSE = 18.5566.
% iteration = 1387, RMSE = 22.7285.
% iteration = 1388, RMSE = 18.7591.
% iteration = 1389, RMSE = 17.5956.
% iteration = 1390, RMSE = 17.9808.
% iteration = 1391, RMSE = 19.218.
% iteration = 1392, RMSE = 22.9159.
% iteration = 1393, RMSE = 24.6045.
% iteration = 1394, RMSE = 17.7051.
% iteration = 1395, RMSE = 21.9143.
% iteration = 1396, RMSE = 25.0468.
% iteration = 1397, RMSE = 20.4353.
% iteration = 1398, RMSE = 16.5585.
% iteration = 1399, RMSE = 16.4373.
% iteration = 1400, RMSE = 23.8144.
% iteration = 1401, RMSE = 17.1404.
% iteration = 1402, RMSE = 26.8319.
% iteration = 1403, RMSE = 26.8052.
% iteration = 1404, RMSE = 31.5082.
% iteration = 1405, RMSE = 26.6155.
% iteration = 1406, RMSE = 23.3462.
% iteration = 1407, RMSE = 23.5517.
% iteration = 1408, RMSE = 27.5479.
% iteration = 1409, RMSE = 21.2493.
% iteration = 1410, RMSE = 22.5898.
% iteration = 1411, RMSE = 26.7304.
% iteration = 1412, RMSE = 23.6101.
% iteration = 1413, RMSE = 26.0748.
% iteration = 1414, RMSE = 32.4786.
% iteration = 1415, RMSE = 22.8552.
% iteration = 1416, RMSE = 22.4191.
% iteration = 1417, RMSE = 21.9749.
% iteration = 1418, RMSE = 24.7289.
% iteration = 1419, RMSE = 19.8143.
% iteration = 1420, RMSE = 19.2141.
% iteration = 1421, RMSE = 23.3757.
% iteration = 1422, RMSE = 17.4913.
% iteration = 1423, RMSE = 19.8884.
% iteration = 1424, RMSE = 20.3743.
% iteration = 1425, RMSE = 25.9417.
% iteration = 1426, RMSE = 28.1659.
% iteration = 1427, RMSE = 27.9032.
% iteration = 1428, RMSE = 32.8265.
% iteration = 1429, RMSE = 23.4152.
% iteration = 1430, RMSE = 34.3353.
% iteration = 1431, RMSE = 29.6657.
% iteration = 1432, RMSE = 28.1996.
% iteration = 1433, RMSE = 22.6559.
% iteration = 1434, RMSE = 25.433.
% iteration = 1435, RMSE = 28.1057.
% iteration = 1436, RMSE = 33.4233.
% iteration = 1437, RMSE = 26.4259.
% iteration = 1438, RMSE = 24.2539.
% iteration = 1439, RMSE = 31.8795.
% iteration = 1440, RMSE = 22.283.
% iteration = 1441, RMSE = 20.6652.
% iteration = 1442, RMSE = 24.8257.
% iteration = 1443, RMSE = 34.7512.
% iteration = 1444, RMSE = 29.7508.
% iteration = 1445, RMSE = 25.2681.
% iteration = 1446, RMSE = 28.5289.
% ...
% iteration = 1532, RMSE = 27.3289.
% iteration = 1533, RMSE = 31.9902.
% iteration = 1534, RMSE = 36.4497.
% iteration = 1535, RMSE = 23.3613.
% iteration = 1536, RMSE = 32.0547.
% iteration = 1537, RMSE = 25.22.
% iteration = 1538, RMSE = 33.6707.
% iteration = 1539, RMSE = 25.5372.
% iteration = 1540, RMSE = 22.8755.
% iteration = 1541, RMSE = 32.3527.
% iteration = 1542, RMSE = 25.3587.
% iteration = 1543, RMSE = 30.3932.
% iteration = 1544, RMSE = 29.3165.
% iteration = 1545, RMSE = 32.1536.
% iteration = 1546, RMSE = 41.9068.
% iteration = 1547, RMSE = 39.7508.
% iteration = 1548, RMSE = 29.4624.
% iteration = 1549, RMSE = 18.7567.
% iteration = 1550, RMSE = 25.8721.
% iteration = 1551, RMSE = 22.5459.
% iteration = 1552, RMSE = 19.6484.
% iteration = 1553, RMSE = 20.7853.
% iteration = 1554, RMSE = 26.9626.
% iteration = 1555, RMSE = 21.167.
% iteration = 1556, RMSE = 26.4749.
% iteration = 1557, RMSE = 23.2375.
% iteration = 1558, RMSE = 31.9845.
% iteration = 1559, RMSE = 26.7257.
% iteration = 1560, RMSE = 35.7431.
% iteration = 1561, RMSE = 27.1113.
% iteration = 1562, RMSE = 28.1303.
% iteration = 1563, RMSE = 20.8922.
% iteration = 1564, RMSE = 21.4269.
% iteration = 1565, RMSE = 24.81.
% iteration = 1566, RMSE = 25.9916.
% iteration = 1567, RMSE = 28.6308.
% iteration = 1568, RMSE = 22.3608.
% iteration = 1569, RMSE = 26.4428.
% iteration = 1570, RMSE = 28.9812.
% iteration = 1571, RMSE = 19.5538.
% iteration = 1572, RMSE = 33.0349.
% iteration = 1573, RMSE = 31.3571.
% iteration = 1574, RMSE = 30.1321.
% iteration = 1575, RMSE = 35.8575.
% iteration = 1576, RMSE = 23.8995.
% iteration = 1577, RMSE = 24.9788.
% iteration = 1578, RMSE = 20.1748.
% iteration = 1579, RMSE = 26.8077.
% iteration = 1580, RMSE = 25.5723.
% iteration = 1581, RMSE = 25.476.
% iteration = 1582, RMSE = 25.632.
% iteration = 1583, RMSE = 28.8745.
% iteration = 1584, RMSE = 19.5397.
% iteration = 1585, RMSE = 30.2962.
% iteration = 1586, RMSE = 27.4037.
% iteration = 1587, RMSE = 28.073.
% iteration = 1588, RMSE = 31.4105.
% iteration = 1589, RMSE = 18.4868.
% iteration = 1590, RMSE = 17.6745.
% iteration = 1591, RMSE = 22.739.
% iteration = 1592, RMSE = 25.9584.
% iteration = 1593, RMSE = 27.068.
% iteration = 1594, RMSE = 38.3063.
% iteration = 1595, RMSE = 35.1321.
% iteration = 1596, RMSE = 31.1833.
% iteration = 1597, RMSE = 28.597.
% iteration = 1598, RMSE = 32.5207.
% iteration = 1599, RMSE = 28.2619.
% iteration = 1600, RMSE = 26.6593.
% iteration = 1601, RMSE = 30.8958.
% iteration = 1602, RMSE = 30.8319.
% iteration = 1603, RMSE = 34.4402.
% iteration = 1604, RMSE = 37.6785.
% iteration = 1605, RMSE = 45.627.
% iteration = 1606, RMSE = 33.7064.
% iteration = 1607, RMSE = 28.8348.
% iteration = 1608, RMSE = 37.0909.
% iteration = 1609, RMSE = 30.0783.
% iteration = 1610, RMSE = 27.2065.
% iteration = 1611, RMSE = 29.0937.
% iteration = 1612, RMSE = 45.7928.
% iteration = 1613, RMSE = 41.2731.
% iteration = 1614, RMSE = 31.8513.
% iteration = 1615, RMSE = 27.2341.
% iteration = 1616, RMSE = 26.7832.
% iteration = 1617, RMSE = 28.9051.
% iteration = 1618, RMSE = 20.9185.
% iteration = 1619, RMSE = 11.8301.
% iteration = 1620, RMSE = 21.3869.
% iteration = 1621, RMSE = 25.1234.
% iteration = 1622, RMSE = 22.644.
% iteration = 1623, RMSE = 31.4656.
% iteration = 1624, RMSE = 27.1472.
% iteration = 1625, RMSE = 24.5981.
% iteration = 1626, RMSE = 18.4617.
% iteration = 1627, RMSE = 21.9468.
% iteration = 1628, RMSE = 28.8848.
% iteration = 1629, RMSE = 35.2529.
% iteration = 1630, RMSE = 27.7917.
% iteration = 1631, RMSE = 36.2515.
% iteration = 1632, RMSE = 37.0864.
% iteration = 1633, RMSE = 24.1683.
% iteration = 1634, RMSE = 26.3637.
% iteration = 1635, RMSE = 23.0191.
% iteration = 1636, RMSE = 22.4878.
% iteration = 1637, RMSE = 30.8043.
% iteration = 1638, RMSE = 36.6139.
% iteration = 1639, RMSE = 32.7632.
% iteration = 1640, RMSE = 28.3828.
% iteration = 1641, RMSE = 18.6807.
% iteration = 1642, RMSE = 19.6962.
% iteration = 1643, RMSE = 17.7494.
% iteration = 1644, RMSE = 33.8715.
% iteration = 1645, RMSE = 28.1508.
% iteration = 1646, RMSE = 42.1808.
% iteration = 1647, RMSE = 34.1597.
% iteration = 1648, RMSE = 29.9973.
% iteration = 1649, RMSE = 23.0207.
% iteration = 1650, RMSE = 26.5416.
% iteration = 1651, RMSE = 34.9233.
% iteration = 1652, RMSE = 29.5938.
% iteration = 1653, RMSE = 26.1174.
% iteration = 1654, RMSE = 24.715.
% iteration = 1655, RMSE = 32.887.
% iteration = 1656, RMSE = 27.5549.
% iteration = 1657, RMSE = 36.9004.
% iteration = 1658, RMSE = 33.8546.
% iteration = 1659, RMSE = 20.7678.
% iteration = 1660, RMSE = 32.9867.
% iteration = 1661, RMSE = 27.9766.
% iteration = 1662, RMSE = 33.6467.
% iteration = 1663, RMSE = 32.1558.
% iteration = 1664, RMSE = 29.3208.
% iteration = 1665, RMSE = 28.6681.
% iteration = 1666, RMSE = 30.8606.
% iteration = 1667, RMSE = 29.4843.
% iteration = 1668, RMSE = 26.3444.
% iteration = 1669, RMSE = 27.908.
% iteration = 1670, RMSE = 21.2225.
% iteration = 1671, RMSE = 32.3914.
% iteration = 1672, RMSE = 28.0743.
% iteration = 1673, RMSE = 24.8416.
% iteration = 1674, RMSE = 34.0535.
% iteration = 1675, RMSE = 24.8743.
% iteration = 1676, RMSE = 27.2459.
% iteration = 1677, RMSE = 19.3896.
% iteration = 1678, RMSE = 16.9119.
% iteration = 1679, RMSE = 29.6617.
% iteration = 1680, RMSE = 38.7255.
% iteration = 1681, RMSE = 34.1387.
% iteration = 1682, RMSE = 37.0479.
% iteration = 1683, RMSE = 33.1395.
% iteration = 1684, RMSE = 40.1239.
% iteration = 1685, RMSE = 25.3207.
% iteration = 1686, RMSE = 26.3284.
% iteration = 1687, RMSE = 25.3545.
% iteration = 1688, RMSE = 22.9928.
% iteration = 1689, RMSE = 22.2133.
% iteration = 1690, RMSE = 26.9214.
% iteration = 1691, RMSE = 46.8387.
% iteration = 1692, RMSE = 20.9766.
% iteration = 1693, RMSE = 25.1604.
% iteration = 1694, RMSE = 26.2073.
% iteration = 1695, RMSE = 35.345.
% iteration = 1696, RMSE = 18.6914.
% iteration = 1697, RMSE = 29.1082.
% iteration = 1698, RMSE = 27.3677.
% iteration = 1699, RMSE = 27.5135.
% iteration = 1700, RMSE = 27.6385.
% iteration = 1701, RMSE = 33.2351.
% iteration = 1702, RMSE = 37.0171.
% iteration = 1703, RMSE = 29.6687.
% iteration = 1704, RMSE = 24.6239.
% iteration = 1705, RMSE = 21.2109.
% iteration = 1706, RMSE = 22.7985.
% iteration = 1707, RMSE = 23.2373.
% iteration = 1708, RMSE = 29.2326.
% iteration = 1709, RMSE = 33.3822.
% iteration = 1710, RMSE = 24.6189.
% iteration = 1711, RMSE = 29.437.
% iteration = 1712, RMSE = 24.5501.
% iteration = 1713, RMSE = 33.2908.
% iteration = 1714, RMSE = 29.261.
% iteration = 1715, RMSE = 27.576.
% iteration = 1716, RMSE = 31.0181.
% iteration = 1717, RMSE = 31.8433.
% iteration = 1718, RMSE = 20.5981.
% iteration = 1719, RMSE = 24.2672.
% iteration = 1720, RMSE = 28.9067.
% iteration = 1721, RMSE = 20.7909.
% iteration = 1722, RMSE = 26.4525.
% iteration = 1723, RMSE = 22.8839.
% iteration = 1724, RMSE = 26.5063.
% iteration = 1725, RMSE = 26.5042.
% iteration = 1726, RMSE = 27.469.
% iteration = 1727, RMSE = 38.3156.
% iteration = 1728, RMSE = 23.0554.
% iteration = 1729, RMSE = 22.6156.
% iteration = 1730, RMSE = 23.5156.
% iteration = 1731, RMSE = 17.2374.
% iteration = 1732, RMSE = 27.0491.
% iteration = 1733, RMSE = 21.1767.
% iteration = 1734, RMSE = 27.5488.
% iteration = 1735, RMSE = 35.9783.
% iteration = 1736, RMSE = 30.6537.
% iteration = 1737, RMSE = 17.9827.
% iteration = 1738, RMSE = 22.2399.
% iteration = 1739, RMSE = 30.1195.
% iteration = 1740, RMSE = 21.4338.
% iteration = 1741, RMSE = 30.3384.
% iteration = 1742, RMSE = 30.2899.
% iteration = 1743, RMSE = 32.9791.
% iteration = 1744, RMSE = 25.465.
% iteration = 1745, RMSE = 28.4076.
% iteration = 1746, RMSE = 27.5279.
% iteration = 1747, RMSE = 38.3765.
% iteration = 1748, RMSE = 29.697.
% iteration = 1749, RMSE = 45.0299.
% iteration = 1750, RMSE = 35.4918.
% iteration = 1751, RMSE = 38.5652.
% iteration = 1752, RMSE = 30.2453.
% iteration = 1753, RMSE = 32.2512.
% iteration = 1754, RMSE = 31.1602.
% iteration = 1755, RMSE = 28.9195.
% iteration = 1756, RMSE = 29.8024.
% iteration = 1757, RMSE = 17.7962.
% iteration = 1758, RMSE = 16.1429.
% iteration = 1759, RMSE = 16.5436.
% iteration = 1760, RMSE = 21.7428.
% iteration = 1761, RMSE = 28.1087.
% iteration = 1762, RMSE = 23.7201.
% iteration = 1763, RMSE = 31.5961.
% iteration = 1764, RMSE = 25.2727.
% iteration = 1765, RMSE = 29.0037.
% iteration = 1766, RMSE = 41.9135.
% iteration = 1767, RMSE = 43.0708.
% iteration = 1768, RMSE = 44.2174.
% iteration = 1769, RMSE = 39.1165.
% iteration = 1770, RMSE = 31.2849.
% iteration = 1771, RMSE = 23.4753.
% iteration = 1772, RMSE = 16.4521.
% iteration = 1773, RMSE = 20.7512.
% iteration = 1774, RMSE = 28.3148.
% iteration = 1775, RMSE = 40.1139.
% iteration = 1776, RMSE = 17.4955.
% iteration = 1777, RMSE = 25.1624.
% iteration = 1778, RMSE = 18.3395.
% iteration = 1779, RMSE = 20.0971.
% iteration = 1780, RMSE = 31.3718.
% iteration = 1781, RMSE = 28.8615.
% iteration = 1782, RMSE = 37.5572.
% iteration = 1783, RMSE = 30.3659.
% iteration = 1784, RMSE = 34.4839.
% iteration = 1785, RMSE = 26.7814.
% iteration = 1786, RMSE = 18.8831.
% iteration = 1787, RMSE = 27.7062.
% iteration = 1788, RMSE = 21.5434.
% iteration = 1789, RMSE = 26.6433.
% iteration = 1790, RMSE = 21.1282.
% iteration = 1791, RMSE = 27.2093.
% iteration = 1792, RMSE = 20.491.
% iteration = 1793, RMSE = 17.9635.
% iteration = 1794, RMSE = 18.2385.
% iteration = 1795, RMSE = 19.4147.
% iteration = 1796, RMSE = 25.4347.
% iteration = 1797, RMSE = 26.2967.
% iteration = 1798, RMSE = 25.961.
% iteration = 1799, RMSE = 16.4758.
% iteration = 1800, RMSE = 26.0111.
% iteration = 1801, RMSE = 14.7773.
% iteration = 1802, RMSE = 14.8153.
% iteration = 1803, RMSE = 13.7382.
% iteration = 1804, RMSE = 19.1565.
% iteration = 1805, RMSE = 22.0787.
% iteration = 1806, RMSE = 25.6914.
% iteration = 1807, RMSE = 22.619.
% iteration = 1808, RMSE = 25.8771.
% iteration = 1809, RMSE = 19.9497.
% iteration = 1810, RMSE = 20.8848.
% iteration = 1811, RMSE = 18.2753.
% iteration = 1812, RMSE = 21.6813.
% iteration = 1813, RMSE = 21.2195.
% iteration = 1814, RMSE = 18.777.
% iteration = 1815, RMSE = 16.086.
% iteration = 1816, RMSE = 14.5481.
% iteration = 1817, RMSE = 17.2624.
% iteration = 1818, RMSE = 20.4177.
% iteration = 1819, RMSE = 16.1513.
% iteration = 1820, RMSE = 22.5079.
% iteration = 1821, RMSE = 17.9198.
% iteration = 1822, RMSE = 22.4265.
% iteration = 1823, RMSE = 21.1466.
% iteration = 1824, RMSE = 26.6105.
% iteration = 1825, RMSE = 20.8672.
% iteration = 1826, RMSE = 18.3937.
% iteration = 1827, RMSE = 21.2488.
% iteration = 1828, RMSE = 15.2534.
% iteration = 1829, RMSE = 19.0125.
% iteration = 1830, RMSE = 15.964.
% iteration = 1831, RMSE = 20.5177.
% iteration = 1832, RMSE = 23.3421.
% iteration = 1833, RMSE = 20.1809.
% iteration = 1834, RMSE = 18.1356.
% iteration = 1835, RMSE = 26.0956.
% iteration = 1836, RMSE = 22.6653.
% iteration = 1837, RMSE = 15.0863.
% iteration = 1838, RMSE = 18.4634.
% iteration = 1839, RMSE = 20.1453.
% iteration = 1840, RMSE = 18.7475.
% iteration = 1841, RMSE = 16.8564.
% iteration = 1842, RMSE = 22.505.
% iteration = 1843, RMSE = 23.611.
% iteration = 1844, RMSE = 32.5335.
% iteration = 1845, RMSE = 22.9625.
% iteration = 1846, RMSE = 25.154.
% iteration = 1847, RMSE = 26.7292.
% iteration = 1848, RMSE = 28.6605.
% iteration = 1849, RMSE = 31.6904.
% iteration = 1850, RMSE = 35.8877.
% iteration = 1851, RMSE = 26.7792.
% iteration = 1852, RMSE = 13.8753.
% iteration = 1853, RMSE = 31.234.
% iteration = 1854, RMSE = 21.4948.
% iteration = 1855, RMSE = 19.3927.
% iteration = 1856, RMSE = 26.6647.
% iteration = 1857, RMSE = 25.6853.
% iteration = 1858, RMSE = 40.2188.
% iteration = 1859, RMSE = 43.1446.
% iteration = 1860, RMSE = 45.3889.
% iteration = 1861, RMSE = 39.5984.
% iteration = 1862, RMSE = 21.0914.
% iteration = 1863, RMSE = 32.9205.
% iteration = 1864, RMSE = 34.784.
% iteration = 1865, RMSE = 30.184.
% iteration = 1866, RMSE = 40.9366.
% iteration = 1867, RMSE = 19.2054.
% iteration = 1868, RMSE = 39.2517.
% iteration = 1869, RMSE = 19.4944.
% iteration = 1870, RMSE = 20.6098.
% iteration = 1871, RMSE = 19.1598.
% iteration = 1872, RMSE = 29.3414.
% iteration = 1873, RMSE = 21.6976.
% iteration = 1874, RMSE = 20.0976.
% iteration = 1875, RMSE = 28.7973.
% iteration = 1876, RMSE = 36.8957.
% iteration = 1877, RMSE = 20.3134.
% iteration = 1878, RMSE = 22.2838.
% iteration = 1879, RMSE = 20.9575.
% iteration = 1880, RMSE = 22.5556.
% iteration = 1881, RMSE = 19.7338.
% iteration = 1882, RMSE = 16.7951.
% iteration = 1883, RMSE = 17.9493.
% iteration = 1884, RMSE = 24.2719.
% iteration = 1885, RMSE = 15.2153.
% iteration = 1886, RMSE = 21.0528.
% iteration = 1887, RMSE = 25.0854.
% iteration = 1888, RMSE = 22.8207.
% iteration = 1889, RMSE = 25.4985.
% iteration = 1890, RMSE = 17.5532.
% iteration = 1891, RMSE = 21.282.
% iteration = 1892, RMSE = 27.9442.
% iteration = 1893, RMSE = 19.0438.
% iteration = 1894, RMSE = 26.3612.
% iteration = 1895, RMSE = 20.406.
% iteration = 1896, RMSE = 26.6113.
% iteration = 1897, RMSE = 22.4853.
% iteration = 1898, RMSE = 23.5785.
% iteration = 1899, RMSE = 25.9381.
% iteration = 1900, RMSE = 32.4622.
% iteration = 1901, RMSE = 31.8799.
% iteration = 1902, RMSE = 29.4498.
% iteration = 1903, RMSE = 22.2929.
% iteration = 1904, RMSE = 35.4605.
% iteration = 1905, RMSE = 26.8038.
% iteration = 1906, RMSE = 22.3773.
% iteration = 1907, RMSE = 22.2479.
% iteration = 1908, RMSE = 23.3892.
% iteration = 1909, RMSE = 20.0033.
% iteration = 1910, RMSE = 22.9259.
% iteration = 1911, RMSE = 26.7975.
% iteration = 1912, RMSE = 16.581.
% iteration = 1913, RMSE = 14.4143.
% iteration = 1914, RMSE = 21.1282.
% iteration = 1915, RMSE = 23.1922.
% iteration = 1916, RMSE = 24.6605.
% iteration = 1917, RMSE = 29.4401.
% iteration = 1918, RMSE = 17.429.
% iteration = 1919, RMSE = 17.5699.
% iteration = 1920, RMSE = 18.0673.
% iteration = 1921, RMSE = 22.0075.
% iteration = 1922, RMSE = 30.6597.
% iteration = 1923, RMSE = 45.5437.
% iteration = 1924, RMSE = 44.6647.
% iteration = 1925, RMSE = 44.7254.
% iteration = 1926, RMSE = 33.3506.
% iteration = 1927, RMSE = 28.7874.
% iteration = 1928, RMSE = 25.7169.
% iteration = 1929, RMSE = 13.8172.
% iteration = 1930, RMSE = 13.0276.
% iteration = 1931, RMSE = 21.3083.
% iteration = 1932, RMSE = 17.2936.
% iteration = 1933, RMSE = 31.8522.
% iteration = 1934, RMSE = 26.9075.
% iteration = 1935, RMSE = 28.6605.
% iteration = 1936, RMSE = 31.6399.
% iteration = 1937, RMSE = 35.1073.
% iteration = 1938, RMSE = 21.5431.
% iteration = 1939, RMSE = 21.5005.
% iteration = 1940, RMSE = 29.7036.
% iteration = 1941, RMSE = 34.7246.
% iteration = 1942, RMSE = 39.5506.
% iteration = 1943, RMSE = 24.1466.
% iteration = 1944, RMSE = 28.9208.
% iteration = 1945, RMSE = 39.5096.
% iteration = 1946, RMSE = 30.86.
% iteration = 1947, RMSE = 25.7612.
% iteration = 1948, RMSE = 27.5131.
% iteration = 1949, RMSE = 24.7964.
% iteration = 1950, RMSE = 19.1275.
% iteration = 1951, RMSE = 21.08.
% iteration = 1952, RMSE = 20.681.
% iteration = 1953, RMSE = 27.2063.
% iteration = 1954, RMSE = 28.8423.
% iteration = 1955, RMSE = 19.5996.
% iteration = 1956, RMSE = 27.7605.
% iteration = 1957, RMSE = 22.3036.
% iteration = 1958, RMSE = 25.3759.
% iteration = 1959, RMSE = 24.8737.
% iteration = 1960, RMSE = 31.211.
% iteration = 1961, RMSE = 34.3971.
% iteration = 1962, RMSE = 25.8493.
% iteration = 1963, RMSE = 23.993.
% iteration = 1964, RMSE = 26.807.
% iteration = 1965, RMSE = 26.3068.
% iteration = 1966, RMSE = 21.3598.
% iteration = 1967, RMSE = 21.3453.
% iteration = 1968, RMSE = 32.0486.
% iteration = 1969, RMSE = 32.3526.
% iteration = 1970, RMSE = 28.1671.
% iteration = 1971, RMSE = 28.1908.
% iteration = 1972, RMSE = 37.4997.
% iteration = 1973, RMSE = 31.184.
% iteration = 1974, RMSE = 36.4113.
% iteration = 1975, RMSE = 29.9998.
% iteration = 1976, RMSE = 41.5866.
% iteration = 1977, RMSE = 41.4177.
% iteration = 1978, RMSE = 28.0313.
% iteration = 1979, RMSE = 26.6764.
% iteration = 1980, RMSE = 39.5483.
% iteration = 1981, RMSE = 38.7908.
% iteration = 1982, RMSE = 33.6365.
% iteration = 1983, RMSE = 27.9501.
% iteration = 1984, RMSE = 42.4142.
% iteration = 1985, RMSE = 27.0884.
% iteration = 1986, RMSE = 42.3185.
% iteration = 1987, RMSE = 38.7069.
% iteration = 1988, RMSE = 32.0317.
% iteration = 1989, RMSE = 30.788.
% iteration = 1990, RMSE = 17.0165.
% iteration = 1991, RMSE = 25.1829.
% iteration = 1992, RMSE = 25.6667.
% iteration = 1993, RMSE = 27.7662.
% iteration = 1994, RMSE = 34.4676.
% iteration = 1995, RMSE = 32.3511.
% iteration = 1996, RMSE = 39.2992.
% iteration = 1997, RMSE = 35.4725.
% iteration = 1998, RMSE = 31.0401.
% iteration = 1999, RMSE = 28.5385.
% iteration = 2000, RMSE = 27.5964.
%
% ------Final Result of Bayesian Gaussian CP decomposition------
% Final RMSE = 21.038, MAPE = 0.0859768

% %%
tensor_hat
% Out:
% tensor_hat(:,:,1) =
%
%   169.7288   73.8806  493.2441  367.2362
%   102.2117   47.9834  329.6397  343.4680
%   169.7687   80.0803  546.8681  581.0881
%   173.2416   80.5926  539.4201  550.4525
%   136.5548   64.9221  496.7241  488.5281
%    84.3753   39.9322  304.3534  295.0431
%   124.9345   57.8355  386.5663  390.8482
%
%
% tensor_hat(:,:,2) =
%
%   163.2806   72.5756  577.2114  397.3160
%   100.4564   46.8018  306.4529  327.5689
%   167.0897   78.1510  502.8549  552.0994
%   169.2941   78.4757  520.3087  532.1214
%   139.7732   65.3666  441.2296  467.0010
%    86.0696   40.1059  274.9461  283.4649
%   121.8632   56.2621  375.2541  378.8582
%
%
% tensor_hat(:,:,3) =
%
%   217.6636   92.5035  448.2096  431.3107
%    98.7862   47.0436  357.5936  347.7126
%   161.9017   77.6208  594.7279  584.9739
%   175.7903   82.1743  568.5081  564.3697
%   121.2051   59.8375  574.3130  491.4519
%    76.8258   37.5866  347.5208  298.6150
%   128.2002   59.5646  405.5022  402.0577

% %%
sparse_tensor
% Out:
% sparse_tensor(:,:,1) =
%
%    155    74   493     0
%    108    44     0   359
%      0    78   567   581
%    181     0   517   552
%    137    53   489   485
%      0    44   306   290
%    139    55   398   390
%
%
% sparse_tensor(:,:,2) =
%
%    172    69   590   386
%      0    39   310   304
%    158    74     0   546
%      0    90   525   552
%    150     0   438     0
%      0    32   281     0
%      0    51   358   382
%
%
% sparse_tensor(:,:,3) =
%
%    225    92   443   436
%     94    44   355   356
%    139    77   575   604
%    175    98   574   553
%    126     0   593   484
%     58     0   348   301
%    144    71     0   396

% %%
tensor
% Out:
% tensor(:,:,1) =
%
%    155    74   493   426
%    108    44   350   359
%    175    78   567   581
%    181   111   517   552
%    137    53   489   485
%     90    44   306   290
%    139    55   398   390
%
%
% tensor(:,:,2) =
%
%    172    69   590   386
%    104    39   310   304
%    158    74   505   546
%    176    90   525   552
%    150    64   438   459
%     73    32   281   299
%    127    51   358   382
%
%
% tensor(:,:,3) =
%
%    225    92   443   436
%     94    44   355   356
%    139    77   575   604
%    175    98   574   553
%    126    67   593   484
%     58    49   348   301
%    144    71   444   396
